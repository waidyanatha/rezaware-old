# %% [markdown]
# # OTA Room Price Analysis
#
# ### Execute the cell below once to turn off debugging

# %%
'''
    WARNING CONTROL to display or ignore all warnings
'''
import warnings; warnings.simplefilter('ignore')     #switch betweeb 'default' and 'ignore'
import traceback

''' Set debug flag to view extended error messages; else set it to False to turn off debugging mode '''
debug = True

# %% [markdown]
# ## Defined list of room types

# %%
''' compute the semantic similarity of each trigram to each _axiom_room_types '''

''' assign the room type of _axiom_room_types with the highest semantic similarity '''
# Out:
# ' assign the room type of _axiom_room_types with the highest semantic similarity '

# %% [markdown]
# ## Read data from OTA properties table

# %%
import os
import sys
import pandas as pd
from datetime import datetime, date, timedelta

ROOT_DIR = "/home/nuwan/workspace/rezgate/wrangler/"
UTILS_DIR = "/home/nuwan/workspace/rezgate/utils/"
DATA_DIR = os.path.join(ROOT_DIR,"data/hospitality/bookings/")
sys.path.insert(1, UTILS_DIR)
import sparkWorkLoads as spark

if debug:
    import importlib
    spark = importlib.reload(spark)

kwargs = {
    "UTILS_DIR":UTILS_DIR,
}

clsSparkWL = spark.SparkWorkLoads(desc="ota property room prices", **kwargs)
#_session = clsSparkWL.get_spark_session()
# Out:
# All packages in SparkWorkLoads loaded successfully!
# All packages in SparkWorkLoads loaded successfully!
# 22/09/28 10:00:29 WARN Utils: Your hostname, FarmRaiderTester resolves to a loopback address: 127.0.1.1; using 192.168.124.15 instead (on interface enp2s0)
# 22/09/28 10:00:29 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 22/09/28 10:00:41 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# Initialing SparkWorkLoads class for sparkWorkLoads with instance ota property room prices
# Logging SparkWorkLoads info, warnings, and error to /home/nuwan/workspace/rezgate/utils/logs/app.log

# %%
''' get the dataframe in pandas '''
kwargs = {"TO_PANDAS":True}
_s_tbl_name = "ota_property_prices"
data = clsSparkWL.get_data_from_table(dbTable=_s_tbl_name,**kwargs)
print(data.info())
# Out:
# Wait a moment, retrieving data ...
# Loading complete!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8534 entries, 0 to 8533
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   uuid              0 non-null      float64
#  1   ota_name          5850 non-null   object
#  2   search_dt         8534 non-null   datetime64[ns]
#  3   property_name     8534 non-null   object
#  4   checkin_date      8534 non-null   datetime64[ns]
#  5   checkout_date     0 non-null      datetime64[ns]
#  6   room_type         8534 non-null   object
#  7   room_rate         8207 non-null   float64
#  8   currency          8534 non-null   object
#  9   review_score      8219 non-null   float64
#  10  destination_id    8534 non-null   object
#  11  destination_name  8534 non-null   object
#  12  location_desc     8534 non-null   object
#  13  other_info        8534 non-null   object
#  14  data_source       0 non-null      object
#  15  data_owner        0 non-null      object
#  16  created_dt        8534 non-null   datetime64[ns]
#  17  created_by        8534 non-null   object
#  18  created_proc      8534 non-null   object
#  19  modified_dt       0 non-null      datetime64[ns]
#  20  modified_by       0 non-null      object
#  21  modified_proc     0 non-null      object
#  22  deactivate_dt     0 non-null      datetime64[ns]
# dtypes: datetime64[ns](6), float64(3), object(14)
# memory usage: 1.5+ MB
# None

# %%
import nltk

def remove_adj(sentence):
    
    stop_tags = ["JJ", "JJR", "JJS", "NN"]
    tokens = nltk.word_tokenize(sentence)
    tags = list(reversed(nltk.pos_tag(tokens)))
    noun_located = False
    stop_reached = False
    final_sent = ''

    for word,pos in tags:
        if noun_located == False and pos == 'NN':
            noun_located = True
            final_sent+=f' {word}'
        elif stop_reached == False and pos in stop_tags:
            stop_reached = True
        elif stop_reached == True:
            final_sent+=f' {word}'

    final_sent = ' '.join(reversed(final_sent.split(' ')))      
    return final_sent

x = remove_adj('what is the mean of profit')
print(x)
# Out:
# what is the profit

# %% [markdown]
# ## Prep the data with word reduction

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
import re

_room_rate_df = data.copy()
# _room_rate_df['new_room_type'] = _room_rate_df['room_type']
# _room_rate_df['new_room_type'] = _room_rate_df['room_type']+" "+\
#                                 _room_rate_df['destination_name']+" "+\
#                                 _room_rate_df['location_desc']
''' remove all the stop words'''
_room_rate_df['new_room_type'] = _room_rate_df['room_type']\
                                .apply(lambda x: ' '\
                                       .join([word for word in x.split()\
                                              if word not in (stop)]))
# _room_rate_df['new_room_type'] = _room_rate_df['new_room_type']\
#                                 .apply(lambda x: ' '\
#                                        .join([word for word in x.split()\
#                                               if word not in (stop)]))
''' convert all words to lowercase '''
_room_rate_df['new_room_type']=_room_rate_df['new_room_type'].str.lower()

''' list of values to replace with a space '''
replace_word_dict = [r'-',r'/',r'[0-9]',r'[aA]ccess+',r'[aA]ccessible',r'[bB]ath',\
                     r'[dD]isability', r'[dD]isabilities',r'[fF]ree+',r'[hH]earing',\
                     r'[lL]ot',r'[mM]obility',r'[nN]on',r'[/]non',\
                     r'[sS]hower+',r'[Ss]moke+',r'[sS]moking',r'[sS]ofa',\
                     r'[tT]ub',]
''' remove unnecessary terms and reduce the blank spaces to one'''
_room_rate_df['new_room_type'].replace(to_replace=replace_word_dict, value=' ', regex=True, inplace=True)
''' replace duplicate words with a single word '''
_room_rate_df['new_room_type'].replace(to_replace=r'\b(\w+)(\s+\1)+\b', value=r'\1', inplace=True)
''' TODO replace adjectives wit spaces'''
#_room_rate_df['new_room_type'] = _room_rate_df['new_room_type'].apply(remove_adj)
''' strip the left and right spaces '''
_room_rate_df['new_room_type']=_room_rate_df['new_room_type'].str.strip()
#re.sub('\n+', ' ', (_flight_times[0]).lstrip().rstrip())
print('Processed room rate column for %d rows' % _room_rate_df.shape[0] )
print(_room_rate_df['new_room_type'].unique())
# Out:
# Processed room rate column for 8534 rows
# ['king room' 'double room two double beds'
#  'business king room - smoke free' ... 'one-bedroom king suite pool view'
#  'studio, studio, 1 king' 'ocean view premier king bed']

# %%
double room two double beds = bigram((double room two),(room two double), (two double))

# %% [markdown]
# ## create a set of trigrams for each row

# %%
from nltk import trigrams, bigrams
from collections import Counter
y= 'double room two double beds   parking   view'
L = [x for x in _room_rate_df['new_room_type'].unique() for x in bigrams(x.split())]
c = Counter(L)
print(c)
top = c.most_common(20)
#print(top)
# Out:
# Counter({('king', 'room'): 144, ('queen', 'room'): 118, ('room', 'two'): 88, ('queen', 'beds'): 87, ('two', 'queen'): 80, ('guest', 'room,'): 68, ('city', 'view'): 66, ('double', 'room'): 63, ('double', 'beds'): 63, ('king', 'bed'): 59, ('two', 'double'): 58, ('one', 'bedroom'): 46, ('king', 'suite'): 40, ('queen', 'bed'): 30, ('dormitory', 'room'): 29, ('deluxe', 'king'): 27, ('room,', 'king'): 27, ('suite', 'two'): 25, ('roll', 'in'): 24, ('room', 'ible'): 23, ('queen', 'suite'): 23, ('studio', 'suite'): 23, ('bedroom', 'suite'): 23, ('bed', 'bed'): 20, ('room', 'shared'): 20, ('shared', 'room'): 20, ('deluxe', 'queen'): 19, ('guest', 'room'): 19, ('room,', 'guest'): 19, ('king', 'studio'): 18, ('room', 'king'): 18, ('room', 'city'): 18, ('room', 'roll'): 17, ('room,', 'king,'): 17, ('standard', 'room'): 16, ('ocean', 'view'): 16, ('deluxe', 'room'): 15, ('one', 'king'): 15, ('standard', 'king'): 14, ('queen', 'studio'): 14, ('two', 'bedroom'): 14, ('beds', 'ible'): 14, ('(no', 'resort'): 14, ('single', 'bed'): 14, ('double', 'queen'): 13, ('suite', 'bed'): 13, ('deluxe', 'double'): 13, ('room', 'bed'): 13, ('room', 'one'): 13, ('bed', 'female'): 12, ('view', 'king'): 12, ('resort', 'fee)'): 12, ('room,', 'queen'): 12, ('bedroom', 'queen'): 11, ('female', 'dormitory'): 11, ('beds', 'bed'): 11, ('one', 'queen'): 11, ('twin', 'room'): 11, ('single', 'room'): 11, ('standard', 'queen'): 10, ('courtyard', 'view'): 10, ('double', 'bed'): 10, ('studio', 'queen'): 10, ('room', 'queen'): 10, ('classic', 'king'): 10, ('male', 'dormitory'): 10, ('partial', 'ocean'): 10, ('premium', 'king'): 10, ('bed', 'mixed'): 9, ('bedroom', 'king'): 9, ('superior', 'king'): 9, ('bed', 'room'): 9, ('king,', 'guest'): 9, ('king,', 'city'): 9, ('mixed', 'dormitory'): 8, ('suite', 'king'): 8, ('double', 'suite'): 8, ('quadruple', 'room'): 8, ('bunk', 'bed'): 8, ('room', 'private'): 8, ('private', 'room'): 8, ('high', 'floor'): 8, ('premier', 'king'): 8, ('classic', 'queen'): 8, ('room,', 'double'): 8, ('room', 'double'): 7, ('superior', 'queen'): 7, ('suite', 'ible'): 7, ('bed', 'male'): 7, ('room,', 'double,'): 7, ('pool', 'view'): 7, ('three', 'bedroom'): 7, ('standard', 'double'): 6, ('studio', 'bed'): 6, ('premium', 'queen'): 6, ('deluxe', 'studio'): 6, ('deluxe', 'room,'): 6, ('room,', 'queen,'): 6, ('lake', 'view'): 6, ('room', 'room'): 6, ('beds', 'city'): 6, ('traditional,', 'guest'): 6, ('room', 'balcony'): 6, ('in', 'ible'): 6, ('bedroom', 'house'): 6, ('king', 'bed,'): 5, ('bed', 'dormitory'): 5, ('king', 'guest'): 5, ('beds', '(no'): 5, ('double', 'beds,'): 5, ('bedroom', 'villa'): 5, ('ible', 'roll'): 5, ('bedroom', 'apartment'): 5, ('suite,', 'king'): 5, ('double', 'twin'): 5, ('king', 'queen'): 5, ('ible', 'king'): 5, ('one', 'double'): 5, ('superior', 'studio'): 5, ('view', 'room'): 5, ('full', 'bed'): 5, ('superior', 'room,'): 5, ('king,', 'bed'): 5, ('studio', 'two'): 5, ('resort', 'view'): 5, ('suite', 'queen'): 5, ('walk', 'in'): 5, ('petite', 'room'): 5, ('superior', 'room'): 5, ('standard', 'room,'): 4, ('executive', 'king'): 4, ('full', 'room'): 4, ('king', 'double'): 4, ('bed', 'ible'): 4, ('room', 'no'): 4, ('no', 'view'): 4, ('size', 'bed'): 4, ('deluxe', 'suite'): 4, ('suite', 'one'): 4, ('resort', 'king'): 4, ('waikiki', 'view'): 4, ('room', 'courtyard'): 4, ('double,', 'city'): 4, ('junior', 'suite'): 4, ('suite', 'city'): 4, ('water', 'view'): 4, ('studio', 'one'): 4, ('deluxe', 'city'): 4, ('essential', 'queen'): 4, ('mountain', 'view'): 4, ('bedroom', 'suite,'): 4, ('limited', 'view'): 4, ('standard', 'two'): 4, ('family', 'suite'): 4, ('studio', 'king'): 4, ('atrium', 'view'): 4, ('skyline', 'view'): 4, ('courtyard', 'king'): 4, ('bay', 'view'): 4, ('two', 'queens'): 4, ('queen', '+'): 3, ('view', 'ible'): 3, ('standard', 'full'): 3, ('family', 'room'): 3, ('room', 'bunk'): 3, ('standard', 'one'): 3, ('one', 'full'): 3, ('king', 'ible'): 3, ('essential', 'king'): 3, ('suite,', 'bedroom'): 3, ('luxury', 'king'): 3, ('beds ...

# %%
import nltk
import difflib

_room_desc = pd.read_csv(os.path.join(DATA_DIR,"room_descriptions.csv"), delimiter=',')
_l_result = []

for text in _room_rate_df['new_room_type'][0:99]:
    max_seq_dist = -1
    best_seq_desc = None
    max_edit_dist = 100
    best_edit_desc = None
    for desc in _room_desc['description']:
        seq = difflib.SequenceMatcher(None,text,desc)
        seq_d = seq.ratio()*100
        edit_d = nltk.edit_distance(text,desc)
        if seq_d > max_dist:
            max_seq_dist = seq_d
            best_seq_desc = desc
        if edit_d < max_edit_dist:
            max_edit_dist = edit_d
            best_edit_desc = desc
    _l_result.append({ 'room_type':text,
                      'seq_desc':best_seq_desc,
                      'seq_dist':max_seq_dist,
                      'edit_desc':best_edit_desc,
                      'edit_dist':max_edit_dist,
                     })

# %%
result_df = pd.DataFrame(_l_result)
result_df
# Out:
#                                          room_type  \
# 0                                        king room
# 1                                        king room
# 2                      double room two double beds
# 3                  business king room - smoke free
# 4   double room two double beds - parking lot view
# ..                                             ...
# 94      double suite two double beds - non-smoking
# 95                                       king room
# 96                   studio queen room non-smoking
# 97                                       king room
# 98                    standard king room - smoking
#
#                                 seq_desc   seq_dist                edit_desc  \
# 0                                   None  -1.000000              double room
# 1                                   None  -1.000000              double room
# 2         superior double room king beds  59.649123  double room double beds
# 3                                   None  -1.000000    guest room double bed
# 4   standard double room two double beds  65.853659  double room double beds
# ..                                   ...        ...                      ...
# 94               double room double beds  61.538462  double room double beds
# 95                                  None  -1.000000              double room
# 96                                  None  -1.000000  double room double beds
# 97                                  None  -1.000000              double room
# 98    standard double room two king beds  64.516129   standard room king bed
#
#     edit_dist
# 0           6
# 1           6
# 2           4
# 3          19
# 4          23
# ..        ...
# 94         23
# 95          6
# 96         19
# 97          6
# 98         14
#
# [99 rows x 5 columns]

# %%
from nltk import trigrams, bigrams, word_tokenize
from collections import Counter

for text in _room_rate_df['new_room_type']:
    print(text)
    nltk_tokens = word_tokenize(text)
    L=list(nltk.bigrams(nltk_tokens))
    ''' compute the embedding score '''
    print(L)
# Out:
# king room
# [('king', 'room')]
# king room
# [('king', 'room')]
# double room two double beds
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# business king room
# [('business', 'king'), ('king', 'room')]
# double room two double beds   parking   view
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds'), ('beds', 'parking'), ('parking', 'view')]
# deluxe king room
# [('deluxe', 'king'), ('king', 'room')]
# standard king room
# [('standard', 'king'), ('king', 'room')]
# deluxe king room
# [('deluxe', 'king'), ('king', 'room')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# queen studio
# [('queen', 'studio')]
# standard room two double beds
# [('standard', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# deluxe queen room
# [('deluxe', 'queen'), ('queen', 'room')]
# king room
# [('king', 'room')]
# king suite
# [('king', 'suite')]
# king room
# [('king', 'room')]
# king room
# [('king', 'room')]
# king room      ible
# [('king', 'room'), ('room', 'ible')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# king room roll in
# [('king', 'room'), ('room', 'roll'), ('roll', 'in')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# standard room two double beds
# [('standard', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# standard room two double beds
# [('standard', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# king room
# [('king', 'room')]
# standard room,   king bed,
# [('standard', 'room'), ('room', ','), (',', 'king'), ('king', 'bed'), ('bed', ',')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# king room
# [('king', 'room')]
# bed   bed dormitory room
# [('bed', 'bed'), ('bed', 'dormitory'), ('dormitory', 'room')]
# double room
# [('double', 'room')]
# two bedroom queen + two twins terrace   apartment
# [('two', 'bedroom'), ('bedroom', 'queen'), ('queen', '+'), ('+', 'two'), ('two', 'twins'), ('twins', 'terrace'), ('terrace', 'apartment')]
# queen suite
# [('queen', 'suite')]
# double room two double beds
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# king studio suite
# [('king', 'studio'), ('studio', 'suite')]
# queen room two queen beds      ible
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds'), ('beds', 'ible')]
# standard queen room
# [('standard', 'queen'), ('queen', 'room')]
# king room
# [('king', 'room')]
# standard king room
# [('standard', 'king'), ('king', 'room')]
# guest room two double beds
# [('guest', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# double queen room
# [('double', 'queen'), ('queen', 'room')]
# king suite   bed
# [('king', 'suite'), ('suite', 'bed')]
# king suite courtyard view      ible
# [('king', 'suite'), ('suite', 'courtyard'), ('courtyard', 'view'), ('view', 'ible')]
# king room
# [('king', 'room')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# double room
# [('double', 'room')]
# deluxe room two queen beds
# [('deluxe', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# queen room
# [('queen', 'room')]
# king room roll in
# [('king', 'room'), ('room', 'roll'), ('roll', 'in')]
# king room      ible
# [('king', 'room'), ('room', 'ible')]
# standard double room two double beds
# [('standard', 'double'), ('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# bed   bed mixed dormitory
# [('bed', 'bed'), ('bed', 'mixed'), ('mixed', 'dormitory')]
# business king room
# [('business', 'king'), ('king', 'room')]
# queen room
# [('queen', 'room')]
# executive king room
# [('executive', 'king'), ('king', 'room')]
# queen room
# [('queen', 'room')]
# bed   bed female dormitory room ensuite  room
# [('bed', 'bed'), ('bed', 'female'), ('female', 'dormitory'), ('dormitory', 'room'), ('room', 'ensuite'), ('ensuite', 'room')]
# one bedroom suite
# [('one', 'bedroom'), ('bedroom', 'suite')]
# standard room two double beds
# [('standard', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# deluxe double room two double beds
# [('deluxe', 'double'), ('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# queen room two queen beds   second floor
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds'), ('beds', 'second'), ('second', 'floor')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# double room two queen beds            ible
# [('double', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds'), ('beds', 'ible')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# studio suite king efficiency
# [('studio', 'suite'), ('suite', 'king'), ('king', 'efficiency')]
# king room
# [('king', 'room')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# guestroom   king
# [('guestroom', 'king')]
# bed   bed female dormitory room
# [('bed', 'bed'), ('bed', 'female'), ('female', 'dormitory'), ('dormitory', 'room')]
# queen room   bed
# [('queen', 'room'), ('room', 'bed')]
# city view king bed suite
# [('city', 'view'), ('view', 'king'), ('king', 'bed'), ('bed', 'suite')]
# king studio   bed
# [('king', 'studio'), ('studio', 'bed')]
# king room
# [('king', 'room')]
# one bedroom queen suite two queen beds     bed
# [('one', 'bedroom'), ('bedroom', 'queen'), ('queen', 'suite'), ('suite', 'two'), ('two', 'queen'), ('queen', 'beds'), ('beds', 'bed')]
# queen room    ible
# [('queen', 'room'), ('room', 'ible')]
# king room
# [('king', 'room')]
# standard full room
# [('standard', 'full'), ('full', 'room')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# deluxe room     king bed
# [('deluxe', 'room'), ('room', 'king'), ('king', 'bed')]
# queen room
# [('queen', 'room')]
# king room
# [('king', 'room')]
# queen room city view
# [('queen', 'room'), ('room', 'city'), ('city', 'view')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# king studio
# [('king', 'studio')]
# king room    ible
# [('king', 'room'), ('room', 'ible')]
# king room
# [('king', 'room')]
# deluxe queen room two queen beds (kids eat  )
# [('deluxe', 'queen'), ('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds'), ('beds', '('), ('(', 'kids'), ('kids', 'eat'), ('eat', ')')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# double room two double bed   bed
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'bed'), ('bed', 'bed')]
# studio suite
# [('studio', 'suite')]
# queen studio suite
# [('queen', 'studio'), ('studio', 'suite')]
# double room double beds
# [('double', 'room'), ('room', 'double'), ('double', 'beds')]
# king room
# [('king', 'room')]
# double suite two double beds
# [('double', 'suite'), ('suite', 'two'), ('two', 'double'), ('double', 'beds')]
# king room
# [('king', 'room')]
# studio queen room
# [('studio', 'queen'), ('queen', 'room')]
# king room
# [('king', 'room')]
# standard king room
# [('standard', 'king'), ('king', 'room')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# king suite
# [('king', 'suite')]
# partner offer option
# [('partner', 'offer'), ('offer', 'option')]
# standard queen room two queen beds
# [('standard', 'queen'), ('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# one bedroom suite   double beds   bed
# [('one', 'bedroom'), ('bedroom', 'suite'), ('suite', 'double'), ('double', 'beds'), ('beds', 'bed')]
# king room
# [('king', 'room')]
# king room
# [('king', 'room')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# king guest room
# [('king', 'guest'), ('guest', 'room')]
# suite
# []
# deluxe queen room two queen beds
# [('deluxe', 'queen'), ('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# standard queen room two queen beds
# [('standard', 'queen'), ('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# king studio
# [('king', 'studio')]
# standard double room
# [('standard', 'double'), ('double', 'room')]
# bed   bed female dormitory room
# [('bed', 'bed'), ('bed', 'female'), ('female', 'dormitory'), ('dormitory', 'room')]
# executive king room
# [('executive', 'king'), ('king', 'room')]
# king room
# [('king', 'room')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# leisure king room
# [('leisure', 'king'), ('king', 'room')]
# hill billy cabin
# [('hill', 'billy'), ('billy', 'cabin')]
# double room two double beds
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# queen studio   bed
# [('queen', 'studio'), ('studio', 'bed')]
# queen studio   bed
# [('queen', 'studio'), ('studio', 'bed')]
# king room
# [('king', 'room')]
# double room
# [('double', 'room')]
# king room
# [('king', 'room')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# deluxe queen room two queen beds
# [('deluxe', 'queen'), ('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# standard king room
# [('standard', 'king'), ('king', 'room')]
# standard room two double beds
# [('standard', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# double room two double beds
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# one bedroom king suite
# [('one', 'bedroom'), ('bedroom', 'king'), ('king', 'suite')]
# queen room      ible
# [('queen', 'room'), ('room', 'ible')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# family room
# [('family', 'room')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# deluxe double room
# [('deluxe', 'double'), ('double', 'room')]
# queen room two queen beds (no resort fee)
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds'), ('beds', '('), ('(', 'no'), ('no', 'resort'), ('resort', 'fee'), ('fee', ')')]
# superior king room
# [('superior', 'king'), ('king', 'room')]
# one bedroom king suite   bed
# [('one', 'bedroom'), ('bedroom', 'king'), ('king', 'suite'), ('suite', 'bed')]
# newly re imagined caribe king   bed
# [('newly', 're'), ('re', 'imagined'), ('imagined', 'caribe'), ('caribe', 'king'), ('king', 'bed')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# king room   bed
# [('king', 'room'), ('room', 'bed')]
# standard queen room
# [('standard', 'queen'), ('queen', 'room')]
# interior queen room
# [('interior', 'queen'), ('queen', 'room')]
# deluxe quadruple room
# [('deluxe', 'quadruple'), ('quadruple', 'room')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# queen studio
# [('queen', 'studio')]
# deluxe double room two double beds (wide bay)
# [('deluxe', 'double'), ('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds'), ('beds', '('), ('(', 'wide'), ('wide', 'bay'), ('bay', ')')]
# double beds,       room,    w  grab bars,
# [('double', 'beds'), ('beds', ','), (',', 'room'), ('room', ','), (',', 'w'), ('w', 'grab'), ('grab', 'bars'), ('bars', ',')]
# bed    bed mixed dormitory room
# [('bed', 'bed'), ('bed', 'mixed'), ('mixed', 'dormitory'), ('dormitory', 'room')]
# queen room two queen beds      ible
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds'), ('beds', 'ible')]
# double room two double bed   bed
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'bed'), ('bed', 'bed')]
# double room two double beds
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# king room
# [('king', 'room')]
# queen studio suite
# [('queen', 'studio'), ('studio', 'suite')]
# executive suite
# [('executive', 'suite')]
# king room
# [('king', 'room')]
# standard room two double beds
# [('standard', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# king room
# [('king', 'room')]
# king room
# [('king', 'room')]
# standard room two double beds (pet friendly)
# [('standard', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds'), ('beds', '('), ('(', 'pet'), ('pet', 'friendly'), ('friendly', ')')]
# one bedroom king suite
# [('one', 'bedroom'), ('bedroom', 'king'), ('king', 'suite')]
# king room
# [('king', 'room')]
# standard queen room two queen beds
# [('standard', 'queen'), ('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# standard double room
# [('standard', 'double'), ('double', 'room')]
# classic room   queen bed
# [('classic', 'room'), ('room', 'queen'), ('queen', 'bed')]
# double room two double beds
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# bunk bed female dormitory room
# [('bunk', 'bed'), ('bed', 'female'), ('female', 'dormitory'), ('dormitory', 'room')]
# queen room
# [('queen', 'room')]
# one bedroom villa
# [('one', 'bedroom'), ('bedroom', 'villa')]
# queen room
# [('queen', 'room')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# guest room king bed
# [('guest', 'room'), ('room', 'king'), ('king', 'bed')]
# standard queen room two queen beds
# [('standard', 'queen'), ('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# premium queen
# [('premium', 'queen')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# fairmont queen room   main building
# [('fairmont', 'queen'), ('queen', 'room'), ('room', 'main'), ('main', 'building')]
# double room two double beds
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# queen studio suite
# [('queen', 'studio'), ('studio', 'suite')]
# classic king room city view
# [('classic', 'king'), ('king', 'room'), ('room', 'city'), ('city', 'view')]
# double room
# [('double', 'room')]
# deluxe room two queen beds
# [('deluxe', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# standard quadruple room
# [('standard', 'quadruple'), ('quadruple', 'room')]
# double room two double beds
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# standard queen room two queen beds
# [('standard', 'queen'), ('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# king room
# [('king', 'room')]
# king room
# [('king', 'room')]
# king room      ible roll in
# [('king', 'room'), ('room', 'ible'), ('ible', 'roll'), ('roll', 'in')]
# king suite
# [('king', 'suite')]
# deluxe room two double beds
# [('deluxe', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# one bedroom apartment
# [('one', 'bedroom'), ('bedroom', 'apartment')]
# king room
# [('king', 'room')]
# king room
# [('king', 'room')]
# superior queen room
# [('superior', 'queen'), ('queen', 'room')]
# deluxe king room
# [('deluxe', 'king'), ('king', 'room')]
# double room two double beds
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# executive king room
# [('executive', 'king'), ('king', 'room')]
# king double room city view
# [('king', 'double'), ('double', 'room'), ('room', 'city'), ('city', 'view')]
# queen room
# [('queen', 'room')]
# savvy double
# [('savvy', 'double')]
# double queen room
# [('double', 'queen'), ('queen', 'room')]
# king bed leisure room
# [('king', 'bed'), ('bed', 'leisure'), ('leisure', 'room')]
# queen room
# [('queen', 'room')]
# king room
# [('king', 'room')]
# king double room city view
# [('king', 'double'), ('double', 'room'), ('room', 'city'), ('city', 'view')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# premium queen room bunk bed
# [('premium', 'queen'), ('queen', 'room'), ('room', 'bunk'), ('bunk', 'bed')]
# one queen bed
# [('one', 'queen'), ('queen', 'bed')]
# king room
# [('king', 'room')]
# deluxe studio   queen bed            ible
# [('deluxe', 'studio'), ('studio', 'queen'), ('queen', 'bed'), ('bed', 'ible')]
# queen room
# [('queen', 'room')]
# deluxe studio   queen bed            ible
# [('deluxe', 'studio'), ('studio', 'queen'), ('queen', 'bed'), ('bed', 'ible')]
# queen studio
# [('queen', 'studio')]
# savvy double
# [('savvy', 'double')]
# double room two double beds
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# king room      ible
# [('king', 'room'), ('room', 'ible')]
# queen studio suite         ible
# [('queen', 'studio'), ('studio', 'suite'), ('suite', 'ible')]
# king studio   bed
# [('king', 'studio'), ('studio', 'bed')]
# bed   bed male dormitory room shared hallway  room
# [('bed', 'bed'), ('bed', 'male'), ('male', 'dormitory'), ('dormitory', 'room'), ('room', 'shared'), ('shared', 'hallway'), ('hallway', 'room')]
# double room two double beds
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# double room shared  room
# [('double', 'room'), ('room', 'shared'), ('shared', 'room')]
# king room
# [('king', 'room')]
# small room shared  room
# [('small', 'room'), ('room', 'shared'), ('shared', 'room')]
# premium double room two double beds
# [('premium', 'double'), ('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# king suite   bed
# [('king', 'suite'), ('suite', 'bed')]
# bedroom conference room suite,   king
# [('bedroom', 'conference'), ('conference', 'room'), ('room', 'suite'), ('suite', ','), (',', 'king')]
# standard queen room
# [('standard', 'queen'), ('queen', 'room')]
# standard king room
# [('standard', 'king'), ('king', 'room')]
# king room      ible roll in
# [('king', 'room'), ('room', 'ible'), ('ible', 'roll'), ('roll', 'in')]
# queen room
# [('queen', 'room')]
# king room   bed
# [('king', 'room'), ('room', 'bed')]
# king studio suite
# [('king', 'studio'), ('studio', 'suite')]
# small room shared  room
# [('small', 'room'), ('room', 'shared'), ('shared', 'room')]
# king room
# [('king', 'room')]
# double room two double beds
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# queen room
# [('queen', 'room')]
# double room two double beds
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# king room
# [('king', 'room')]
# standard king suite
# [('standard', 'king'), ('king', 'suite')]
# king room      ible
# [('king', 'room'), ('room', 'ible')]
# bed   bed dormitory room
# [('bed', 'bed'), ('bed', 'dormitory'), ('dormitory', 'room')]
# queen studio
# [('queen', 'studio')]
# queen room shared hallway  room
# [('queen', 'room'), ('room', 'shared'), ('shared', 'hallway'), ('hallway', 'room')]
# standard king suite
# [('standard', 'king'), ('king', 'suite')]
# classic   king
# [('classic', 'king')]
# double room
# [('double', 'room')]
# budget double room
# [('budget', 'double'), ('double', 'room')]
# king room no view
# [('king', 'room'), ('room', 'no'), ('no', 'view')]
# quadruple room
# [('quadruple', 'room')]
# queen room
# [('queen', 'room')]
# king room
# [('king', 'room')]
# king room    ible
# [('king', 'room'), ('room', 'ible')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# classic king room city view
# [('classic', 'king'), ('king', 'room'), ('room', 'city'), ('city', 'view')]
# bed   bed dormitory room
# [('bed', 'bed'), ('bed', 'dormitory'), ('dormitory', 'room')]
# queen room
# [('queen', 'room')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# superior king room
# [('superior', 'king'), ('king', 'room')]
# small queen room
# [('small', 'queen'), ('queen', 'room')]
# single bed   bed dormitory room
# [('single', 'bed'), ('bed', 'bed'), ('bed', 'dormitory'), ('dormitory', 'room')]
# double room two double beds
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# king studio   bed
# [('king', 'studio'), ('studio', 'bed')]
# queen room
# [('queen', 'room')]
# small double twin room
# [('small', 'double'), ('double', 'twin'), ('twin', 'room')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# king room
# [('king', 'room')]
# king room
# [('king', 'room')]
# deluxe king room
# [('deluxe', 'king'), ('king', 'room')]
# deluxe king room
# [('deluxe', 'king'), ('king', 'room')]
# bed   bed male dormitory room private  room
# [('bed', 'bed'), ('bed', 'male'), ('male', 'dormitory'), ('dormitory', 'room'), ('room', 'private'), ('private', 'room')]
# queen studio   queen bed
# [('queen', 'studio'), ('studio', 'queen'), ('queen', 'bed')]
# king room
# [('king', 'room')]
# king room      ible
# [('king', 'room'), ('room', 'ible')]
# standard one full size bed
# [('standard', 'one'), ('one', 'full'), ('full', 'size'), ('size', 'bed')]
# deluxe room two double beds
# [('deluxe', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# queen room   queen beds
# [('queen', 'room'), ('room', 'queen'), ('queen', 'beds')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# king room
# [('king', 'room')]
# king room
# [('king', 'room')]
# premium queen
# [('premium', 'queen')]
# king    ible
# [('king', 'ible')]
# executive king room
# [('executive', 'king'), ('king', 'room')]
# single bed male dormitory room   shared  room
# [('single', 'bed'), ('bed', 'male'), ('male', 'dormitory'), ('dormitory', 'room'), ('room', 'shared'), ('shared', 'room')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# small double twin room
# [('small', 'double'), ('double', 'twin'), ('twin', 'room')]
# king room
# [('king', 'room')]
# studio,   queen,   bed, city view
# [('studio', ','), (',', 'queen'), ('queen', ','), (',', 'bed'), ('bed', ','), (',', 'city'), ('city', 'view')]
# king room
# [('king', 'room')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# king room      ible
# [('king', 'room'), ('room', 'ible')]
# essential king room
# [('essential', 'king'), ('king', 'room')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# king suite
# [('king', 'suite')]
# one king bed        ible roll
# [('one', 'king'), ('king', 'bed'), ('bed', 'ible'), ('ible', 'roll')]
# fabulous suite,   bedroom   room suite,   king   queen
# [('fabulous', 'suite'), ('suite', ','), (',', 'bedroom'), ('bedroom', 'room'), ('room', 'suite'), ('suite', ','), (',', 'king'), ('king', 'queen')]
# queen room
# [('queen', 'room')]
# deluxe masquerade tower,   king,
# [('deluxe', 'masquerade'), ('masquerade', 'tower'), ('tower', ','), (',', 'king'), ('king', ',')]
# king room
# [('king', 'room')]
# queen room shared  room
# [('queen', 'room'), ('room', 'shared'), ('shared', 'room')]
# single room shared  room
# [('single', 'room'), ('room', 'shared'), ('shared', 'room')]
# king studio suite
# [('king', 'studio'), ('studio', 'suite')]
# king room
# [('king', 'room')]
# king room
# [('king', 'room')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# single bed   bed mixed dormitory room shared  room
# [('single', 'bed'), ('bed', 'bed'), ('bed', 'mixed'), ('mixed', 'dormitory'), ('dormitory', 'room'), ('room', 'shared'), ('shared', 'room')]
# mountain tower deluxe room,   queen bed,
# [('mountain', 'tower'), ('tower', 'deluxe'), ('deluxe', 'room'), ('room', ','), (',', 'queen'), ('queen', 'bed'), ('bed', ',')]
# one bedroom suite
# [('one', 'bedroom'), ('bedroom', 'suite')]
# double room two double beds      ible
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds'), ('beds', 'ible')]
# medium queen
# [('medium', 'queen')]
# one bedroom king suite   bed
# [('one', 'bedroom'), ('bedroom', 'king'), ('king', 'suite'), ('suite', 'bed')]
# small queen room
# [('small', 'queen'), ('queen', 'room')]
# single bed female dormitory room shared  room
# [('single', 'bed'), ('bed', 'female'), ('female', 'dormitory'), ('dormitory', 'room'), ('room', 'shared'), ('shared', 'room')]
# bed    bed male dormitory room
# [('bed', 'bed'), ('bed', 'male'), ('male', 'dormitory'), ('dormitory', 'room')]
# standard queen room
# [('standard', 'queen'), ('queen', 'room')]
# venetian luxury king suite
# [('venetian', 'luxury'), ('luxury', 'king'), ('king', 'suite')]
# double room
# [('double', 'room')]
# ible king guest room
# [('ible', 'king'), ('king', 'guest'), ('guest', 'room')]
# king room
# [('king', 'room')]
# king room
# [('king', 'room')]
# courtyard view study
# [('courtyard', 'view'), ('view', 'study')]
# deluxe suite one king + one double bed
# [('deluxe', 'suite'), ('suite', 'one'), ('one', 'king'), ('king', '+'), ('+', 'one'), ('one', 'double'), ('double', 'bed')]
# signature room
# [('signature', 'room')]
# south tower premium room
# [('south', 'tower'), ('tower', 'premium'), ('premium', 'room')]
# deluxe single room
# [('deluxe', 'single'), ('single', 'room')]
# double room
# [('double', 'room')]
# double room two double beds
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# bunk bed   bed female dormitory room
# [('bunk', 'bed'), ('bed', 'bed'), ('bed', 'female'), ('female', 'dormitory'), ('dormitory', 'room')]
# resort two queen
# [('resort', 'two'), ('two', 'queen')]
# small queen room
# [('small', 'queen'), ('queen', 'room')]
# triple room
# [('triple', 'room')]
# classic room,   queen,
# [('classic', 'room'), ('room', ','), (',', 'queen'), ('queen', ',')]
# park premier two queen
# [('park', 'premier'), ('premier', 'two'), ('two', 'queen')]
# king room
# [('king', 'room')]
# standard queen room
# [('standard', 'queen'), ('queen', 'room')]
# king corner room
# [('king', 'corner'), ('corner', 'room')]
# royal tower king
# [('royal', 'tower'), ('tower', 'king')]
# deluxe king room
# [('deluxe', 'king'), ('king', 'room')]
# double room
# [('double', 'room')]
# queen room
# [('queen', 'room')]
# premium queen room two queen beds lake view
# [('premium', 'queen'), ('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds'), ('beds', 'lake'), ('lake', 'view')]
# queen   bedroom  bed corner suite
# [('queen', 'bedroom'), ('bedroom', 'bed'), ('bed', 'corner'), ('corner', 'suite')]
# superior king room
# [('superior', 'king'), ('king', 'room')]
# standard room
# [('standard', 'room')]
# bed   bed female dormitory room
# [('bed', 'bed'), ('bed', 'female'), ('female', 'dormitory'), ('dormitory', 'room')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# run house
# [('run', 'house')]
# economy ensuite male dormitory
# [('economy', 'ensuite'), ('ensuite', 'male'), ('male', 'dormitory')]
# deluxe room
# [('deluxe', 'room')]
# queen room
# [('queen', 'room')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# single room
# [('single', 'room')]
# forum classic,   king bed,
# [('forum', 'classic'), ('classic', ','), (',', 'king'), ('king', 'bed'), ('bed', ',')]
# king room
# [('king', 'room')]
# standard room
# [('standard', 'room')]
# deluxe king room        ible
# [('deluxe', 'king'), ('king', 'room'), ('room', 'ible')]
# standard room   bed type assigned at check in
# [('standard', 'room'), ('room', 'bed'), ('bed', 'type'), ('type', 'assigned'), ('assigned', 'at'), ('at', 'check'), ('check', 'in')]
# double room two double beds
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# deluxe king room
# [('deluxe', 'king'), ('king', 'room')]
# pyramid king
# [('pyramid', 'king')]
# traditional two double room
# [('traditional', 'two'), ('two', 'double'), ('double', 'room')]
# studio
# []
# queen room
# [('queen', 'room')]
# bunk bed female dormitory room
# [('bunk', 'bed'), ('bed', 'female'), ('female', 'dormitory'), ('dormitory', 'room')]
# king suite   high floor city view
# [('king', 'suite'), ('suite', 'high'), ('high', 'floor'), ('floor', 'city'), ('city', 'view')]
# chamber king
# [('chamber', 'king')]
# king room city view
# [('king', 'room'), ('room', 'city'), ('city', 'view')]
# bed eight bedroom
# [('bed', 'eight'), ('eight', 'bedroom')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# skyrise family tower double queen room
# [('skyrise', 'family'), ('family', 'tower'), ('tower', 'double'), ('double', 'queen'), ('queen', 'room')]
# standard queen room two queen beds
# [('standard', 'queen'), ('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# bed   bed female shared room
# [('bed', 'bed'), ('bed', 'female'), ('female', 'shared'), ('shared', 'room')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# blanca king
# [('blanca', 'king')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# salone suite
# [('salone', 'suite')]
# queen beds classic
# [('queen', 'beds'), ('beds', 'classic')]
# deluxe king room
# [('deluxe', 'king'), ('king', 'room')]
# bed    bed female dormitory room
# [('bed', 'bed'), ('bed', 'female'), ('female', 'dormitory'), ('dormitory', 'room')]
# grand deluxe king bed
# [('grand', 'deluxe'), ('deluxe', 'king'), ('king', 'bed')]
# deluxe room
# [('deluxe', 'room')]
# bed male dormitory room
# [('bed', 'male'), ('male', 'dormitory'), ('dormitory', 'room')]
# standard king room
# [('standard', 'king'), ('king', 'room')]
# deluxe room,   queens,
# [('deluxe', 'room'), ('room', ','), (',', 'queens'), ('queens', ',')]
# king studio suite   bed
# [('king', 'studio'), ('studio', 'suite'), ('suite', 'bed')]
# deluxe king room queen room two queen beds
# [('deluxe', 'king'), ('king', 'room'), ('room', 'queen'), ('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# queen room two queen beds      ible
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds'), ('beds', 'ible')]
# essential double room two double beds
# [('essential', 'double'), ('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# queen beds
# [('queen', 'beds')]
# queen studio
# [('queen', 'studio')]
# king room
# [('king', 'room')]
# essential room
# [('essential', 'room')]
# king room
# [('king', 'room')]
# bed   bed mixed dormitory room
# [('bed', 'bed'), ('bed', 'mixed'), ('mixed', 'dormitory'), ('dormitory', 'room')]
# bed    bed male dormitory room
# [('bed', 'bed'), ('bed', 'male'), ('male', 'dormitory'), ('dormitory', 'room')]
# resort king
# [('resort', 'king')]
# bed   bed mixed dormitory room
# [('bed', 'bed'), ('bed', 'mixed'), ('mixed', 'dormitory'), ('dormitory', 'room')]
# executive king room
# [('executive', 'king'), ('king', 'room')]
# standard king room
# [('standard', 'king'), ('king', 'room')]
# one bedroom king suite   bed
# [('one', 'bedroom'), ('bedroom', 'king'), ('king', 'suite'), ('suite', 'bed')]
# deluxe queen room
# [('deluxe', 'queen'), ('queen', 'room')]
# king room      ible
# [('king', 'room'), ('room', 'ible')]
# double beds
# [('double', 'beds')]
# deluxe king room        ible
# [('deluxe', 'king'), ('king', 'room'), ('room', 'ible')]
# studio
# []
# bed quad
# [('bed', 'quad')]
# king room
# [('king', 'room')]
# european petite queen
# [('european', 'petite'), ('petite', 'queen')]
# deluxe full room
# [('deluxe', 'full'), ('full', 'room')]
# fab room,   king,
# [('fab', 'room'), ('room', ','), (',', 'king'), ('king', ',')]
# deluxe king room
# [('deluxe', 'king'), ('king', 'room')]
# queen room shared  room
# [('queen', 'room'), ('room', 'shared'), ('shared', 'room')]
# king room
# [('king', 'room')]
# king room
# [('king', 'room')]
# bed   bed mixed dormitory room
# [('bed', 'bed'), ('bed', 'mixed'), ('mixed', 'dormitory'), ('dormitory', 'room')]
# single bed   bed female dormitory room
# [('single', 'bed'), ('bed', 'bed'), ('bed', 'female'), ('female', 'dormitory'), ('dormitory', 'room')]
# waikiki view   king bed
# [('waikiki', 'view'), ('view', 'king'), ('king', 'bed')]
# standard room
# [('standard', 'room')]
# superior studio partial ocean view
# [('superior', 'studio'), ('studio', 'partial'), ('partial', 'ocean'), ('ocean', 'view')]
# king room   bed
# [('king', 'room'), ('room', 'bed')]
# deluxe king   bed
# [('deluxe', 'king'), ('king', 'bed')]
# standard queen room
# [('standard', 'queen'), ('queen', 'room')]
# kaiulani room double, guest room,   double, kaiulani wing
# [('kaiulani', 'room'), ('room', 'double'), ('double', ','), (',', 'guest'), ('guest', 'room'), ('room', ','), (',', 'double'), ('double', ','), (',', 'kaiulani'), ('kaiulani', 'wing')]
# king room
# [('king', 'room')]
# bed   bed dormitory room  female only
# [('bed', 'bed'), ('bed', 'dormitory'), ('dormitory', 'room'), ('room', 'female'), ('female', 'only')]
# city view
# [('city', 'view')]
# king room   bed   ada
# [('king', 'room'), ('room', 'bed'), ('bed', 'ada')]
# superior queen room
# [('superior', 'queen'), ('queen', 'room')]
# bed   bed dormitory room
# [('bed', 'bed'), ('bed', 'dormitory'), ('dormitory', 'room')]
# king room
# [('king', 'room')]
# room
# []
# king room    ible
# [('king', 'room'), ('room', 'ible')]
# standard business queen room two queen beds
# [('standard', 'business'), ('business', 'queen'), ('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# king room
# [('king', 'room')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# deluxe king room city view
# [('deluxe', 'king'), ('king', 'room'), ('room', 'city'), ('city', 'view')]
# one bedroom suite
# [('one', 'bedroom'), ('bedroom', 'suite')]
# king room
# [('king', 'room')]
# standard queen room
# [('standard', 'queen'), ('queen', 'room')]
# standard queen room two queen beds
# [('standard', 'queen'), ('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# one bedroom suite two twin beds
# [('one', 'bedroom'), ('bedroom', 'suite'), ('suite', 'two'), ('two', 'twin'), ('twin', 'beds')]
# queen room
# [('queen', 'room')]
# moderate room
# [('moderate', 'room')]
# bed mixed dormitory room
# [('bed', 'mixed'), ('mixed', 'dormitory'), ('dormitory', 'room')]
# standard room two double beds
# [('standard', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# king room courtyard view
# [('king', 'room'), ('room', 'courtyard'), ('courtyard', 'view')]
# double room   double beds
# [('double', 'room'), ('room', 'double'), ('double', 'beds')]
# bed   bed dormitory room
# [('bed', 'bed'), ('bed', 'dormitory'), ('dormitory', 'room')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# banyan suite
# [('banyan', 'suite')]
# king bed     room
# [('king', 'bed'), ('bed', 'room')]
# premier king room
# [('premier', 'king'), ('king', 'room')]
# quad room  room down hall
# [('quad', 'room'), ('room', 'room'), ('room', 'down'), ('down', 'hall')]
# queen room
# [('queen', 'room')]
# room selected check in
# [('room', 'selected'), ('selected', 'check'), ('check', 'in')]
# standard king room
# [('standard', 'king'), ('king', 'room')]
# premium king  ible
# [('premium', 'king'), ('king', 'ible')]
# city view room one king kitchen
# [('city', 'view'), ('view', 'room'), ('room', 'one'), ('one', 'king'), ('king', 'kitchen')]
# wicked small queen room
# [('wicked', 'small'), ('small', 'queen'), ('queen', 'room')]
# deluxe king room
# [('deluxe', 'king'), ('king', 'room')]
# king room
# [('king', 'room')]
# bed    bed mixed dormitory room
# [('bed', 'bed'), ('bed', 'mixed'), ('mixed', 'dormitory'), ('dormitory', 'room')]
# waikiki city view, guest room,   double, city view, balcony
# [('waikiki', 'city'), ('city', 'view'), ('view', ','), (',', 'guest'), ('guest', 'room'), ('room', ','), (',', 'double'), ('double', ','), (',', 'city'), ('city', 'view'), ('view', ','), (',', 'balcony')]
# king room
# [('king', 'room')]
# king room
# [('king', 'room')]
# full bed
# [('full', 'bed')]
# king room
# [('king', 'room')]
# two queen beds partial ocean view
# [('two', 'queen'), ('queen', 'beds'), ('beds', 'partial'), ('partial', 'ocean'), ('ocean', 'view')]
# standard queen room
# [('standard', 'queen'), ('queen', 'room')]
# deluxe king queen room
# [('deluxe', 'king'), ('king', 'queen'), ('queen', 'room')]
# city view room two doubles kitchen
# [('city', 'view'), ('view', 'room'), ('room', 'two'), ('two', 'doubles'), ('doubles', 'kitchen')]
# *newly renovated* city view doubles, guest room,   double, city view
# [('*newly', 'renovated*'), ('renovated*', 'city'), ('city', 'view'), ('view', 'doubles'), ('doubles', ','), (',', 'guest'), ('guest', 'room'), ('room', ','), (',', 'double'), ('double', ','), (',', 'city'), ('city', 'view')]
# standard studio kitchen
# [('standard', 'studio'), ('studio', 'kitchen')]
# kona tower city view   resort fee included
# [('kona', 'tower'), ('tower', 'city'), ('city', 'view'), ('view', 'resort'), ('resort', 'fee'), ('fee', 'included')]
# beach view coral suite    ible   bedroom
# [('beach', 'view'), ('view', 'coral'), ('coral', 'suite'), ('suite', 'ible'), ('ible', 'bedroom')]
# one king bed
# [('one', 'king'), ('king', 'bed')]
# standard queen
# [('standard', 'queen')]
# classic   doubles
# [('classic', 'doubles')]
# apartment sea view
# [('apartment', 'sea'), ('sea', 'view')]
# superior room,   queen beds
# [('superior', 'room'), ('room', ','), (',', 'queen'), ('queen', 'beds')]
# queen room
# [('queen', 'room')]
# room city view
# [('room', 'city'), ('city', 'view')]
# double room two double beds
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# waikiki view   twin beds
# [('waikiki', 'view'), ('view', 'twin'), ('twin', 'beds')]
# superior king room
# [('superior', 'king'), ('king', 'room')]
# king room
# [('king', 'room')]
# king studio suite
# [('king', 'studio'), ('studio', 'suite')]
# studio
# []
# queen room
# [('queen', 'room')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# two bedroom apartment
# [('two', 'bedroom'), ('bedroom', 'apartment')]
# standard double room
# [('standard', 'double'), ('double', 'room')]
# standard king room
# [('standard', 'king'), ('king', 'room')]
# studio ocean view
# [('studio', 'ocean'), ('ocean', 'view')]
# standard king room
# [('standard', 'king'), ('king', 'room')]
# standard room
# [('standard', 'room')]
# room double beds
# [('room', 'double'), ('double', 'beds')]
# luxury junior suite city view kitchen
# [('luxury', 'junior'), ('junior', 'suite'), ('suite', 'city'), ('city', 'view'), ('view', 'kitchen')]
# independence suite
# [('independence', 'suite')]
# standard room
# [('standard', 'room')]
# king suite
# [('king', 'suite')]
# two double beds
# [('two', 'double'), ('double', 'beds')]
# standard twin room
# [('standard', 'twin'), ('twin', 'room')]
# deluxe king room
# [('deluxe', 'king'), ('king', 'room')]
# king suite
# [('king', 'suite')]
# queen room two double beds
# [('queen', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# king studio
# [('king', 'studio')]
# large pod female room
# [('large', 'pod'), ('pod', 'female'), ('female', 'room')]
# partial ocean view, full bed balcony
# [('partial', 'ocean'), ('ocean', 'view'), ('view', ','), (',', 'full'), ('full', 'bed'), ('bed', 'balcony')]
# standard room two doubles
# [('standard', 'room'), ('room', 'two'), ('two', 'doubles')]
# deluxe double room (  adults +   child)
# [('deluxe', 'double'), ('double', 'room'), ('room', '('), ('(', 'adults'), ('adults', '+'), ('+', 'child'), ('child', ')')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# deluxe double room two double beds
# [('deluxe', 'double'), ('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# king room
# [('king', 'room')]
# double queen cabin   no window
# [('double', 'queen'), ('queen', 'cabin'), ('cabin', 'no'), ('no', 'window')]
# superior double room two double beds
# [('superior', 'double'), ('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# one bedroom suite
# [('one', 'bedroom'), ('bedroom', 'suite')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# room murphy bed
# [('room', 'murphy'), ('murphy', 'bed')]
# queen room    ible
# [('queen', 'room'), ('room', 'ible')]
# standard suite
# [('standard', 'suite')]
# double room two double beds      ible
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds'), ('beds', 'ible')]
# king room
# [('king', 'room')]
# standard room
# [('standard', 'room')]
# double room
# [('double', 'room')]
# double room
# [('double', 'room')]
# standard double room
# [('standard', 'double'), ('double', 'room')]
# queen room
# [('queen', 'room')]
# standard bunk bed room
# [('standard', 'bunk'), ('bunk', 'bed'), ('bed', 'room')]
# queen room
# [('queen', 'room')]
# soho king
# [('soho', 'king')]
# queen room
# [('queen', 'room')]
# standard king room
# [('standard', 'king'), ('king', 'room')]
# small queen room
# [('small', 'queen'), ('queen', 'room')]
# standard queen room
# [('standard', 'queen'), ('queen', 'room')]
# king room
# [('king', 'room')]
# queen room
# [('queen', 'room')]
# king room
# [('king', 'room')]
# standard bunk bed room shared  room
# [('standard', 'bunk'), ('bunk', 'bed'), ('bed', 'room'), ('room', 'shared'), ('shared', 'room')]
# queen room
# [('queen', 'room')]
# double bed
# [('double', 'bed')]
# standard double
# [('standard', 'double')]
# king room
# [('king', 'room')]
# room city view
# [('room', 'city'), ('city', 'view')]
# double room shared  room
# [('double', 'room'), ('room', 'shared'), ('shared', 'room')]
# single room shared   toilet
# [('single', 'room'), ('room', 'shared'), ('shared', 'toilet')]
# queen room
# [('queen', 'room')]
# studio kitchenette
# [('studio', 'kitchenette')]
# premium queen
# [('premium', 'queen')]
# standard king room
# [('standard', 'king'), ('king', 'room')]
# standard queen room
# [('standard', 'queen'), ('queen', 'room')]
# premier king room
# [('premier', 'king'), ('king', 'room')]
# single room
# [('single', 'room')]
# social city view doubles
# [('social', 'city'), ('city', 'view'), ('view', 'doubles')]
# king studio suite
# [('king', 'studio'), ('studio', 'suite')]
# executive king room
# [('executive', 'king'), ('king', 'room')]
# deluxe king room
# [('deluxe', 'king'), ('king', 'room')]
# bed   bed dormitory room
# [('bed', 'bed'), ('bed', 'dormitory'), ('dormitory', 'room')]
# double room
# [('double', 'room')]
# king room
# [('king', 'room')]
# king room water view
# [('king', 'room'), ('room', 'water'), ('water', 'view')]
# bed mixed dormitory room
# [('bed', 'mixed'), ('mixed', 'dormitory'), ('dormitory', 'room')]
# single room
# [('single', 'room')]
# leisure king room
# [('leisure', 'king'), ('king', 'room')]
# graduate king
# [('graduate', 'king')]
# urban king room roll in     ada   visual
# [('urban', 'king'), ('king', 'room'), ('room', 'roll'), ('roll', 'in'), ('in', 'ada'), ('ada', 'visual')]
# king corner room
# [('king', 'corner'), ('corner', 'room')]
# small queen room
# [('small', 'queen'), ('queen', 'room')]
# small single room
# [('small', 'single'), ('single', 'room')]
# queen kitchenette –     full payment   refundable
# [('queen', 'kitchenette'), ('kitchenette', '–'), ('–', 'full'), ('full', 'payment'), ('payment', 'refundable')]
# standard studio
# [('standard', 'studio')]
# king room
# [('king', 'room')]
# king room
# [('king', 'room')]
# premium queen view
# [('premium', 'queen'), ('queen', 'view')]
# park lane king
# [('park', 'lane'), ('lane', 'king')]
# double room two double beds
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# room city view
# [('room', 'city'), ('city', 'view')]
# queen studio
# [('queen', 'studio')]
# classic   queen bed
# [('classic', 'queen'), ('queen', 'bed')]
# deluxe king room
# [('deluxe', 'king'), ('king', 'room')]
# deluxe double room (  adults +   child)
# [('deluxe', 'double'), ('double', 'room'), ('room', '('), ('(', 'adults'), ('adults', '+'), ('+', 'child'), ('child', ')')]
# queen room   bed
# [('queen', 'room'), ('room', 'bed')]
# king room
# [('king', 'room')]
# standard room two double beds
# [('standard', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# deluxe double room
# [('deluxe', 'double'), ('double', 'room')]
# deluxe king studio
# [('deluxe', 'king'), ('king', 'studio')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# one bedroom king suite
# [('one', 'bedroom'), ('bedroom', 'king'), ('king', 'suite')]
# deluxe king room
# [('deluxe', 'king'), ('king', 'room')]
# king room
# [('king', 'room')]
# deluxe queen room
# [('deluxe', 'queen'), ('queen', 'room')]
# queen room
# [('queen', 'room')]
# queen studio
# [('queen', 'studio')]
# standard room two double beds
# [('standard', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# king room
# [('king', 'room')]
# standard room two double beds
# [('standard', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# deluxe queen room two queen beds
# [('deluxe', 'queen'), ('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# cozy standard king
# [('cozy', 'standard'), ('standard', 'king')]
# large king studio
# [('large', 'king'), ('king', 'studio')]
# king room
# [('king', 'room')]
# king room
# [('king', 'room')]
# one bedroom suite
# [('one', 'bedroom'), ('bedroom', 'suite')]
# standard room
# [('standard', 'room')]
# newly re imagined caribe king   bed
# [('newly', 're'), ('re', 'imagined'), ('imagined', 'caribe'), ('caribe', 'king'), ('king', 'bed')]
# standard full room
# [('standard', 'full'), ('full', 'room')]
# ada king
# [('ada', 'king')]
# king room roll   in
# [('king', 'room'), ('room', 'roll'), ('roll', 'in')]
# queen studio
# [('queen', 'studio')]
# double room two double beds
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# king room
# [('king', 'room')]
# studio one king bed
# [('studio', 'one'), ('one', 'king'), ('king', 'bed')]
# king room
# [('king', 'room')]
# king room
# [('king', 'room')]
# king suite
# [('king', 'suite')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# king room
# [('king', 'room')]
# deluxe queen room
# [('deluxe', 'queen'), ('queen', 'room')]
# king room
# [('king', 'room')]
# queen room city view
# [('queen', 'room'), ('room', 'city'), ('city', 'view')]
# king room
# [('king', 'room')]
# king room    ible
# [('king', 'room'), ('room', 'ible')]
# standard room two double beds
# [('standard', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# standard room two double beds (no resort fee)
# [('standard', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds'), ('beds', '('), ('(', 'no'), ('no', 'resort'), ('resort', 'fee'), ('fee', ')')]
# standard double room
# [('standard', 'double'), ('double', 'room')]
# standard room
# [('standard', 'room')]
# guest room,   queen
# [('guest', 'room'), ('room', ','), (',', 'queen')]
# studio queen suite
# [('studio', 'queen'), ('queen', 'suite')]
# king room   bed
# [('king', 'room'), ('room', 'bed')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# studio queen room
# [('studio', 'queen'), ('queen', 'room')]
# king room   bed
# [('king', 'room'), ('room', 'bed')]
# studio queen room
# [('studio', 'queen'), ('queen', 'room')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# studio queen room
# [('studio', 'queen'), ('queen', 'room')]
# one bedroom suite king bed
# [('one', 'bedroom'), ('bedroom', 'suite'), ('suite', 'king'), ('king', 'bed')]
# double room two double beds
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# king room
# [('king', 'room')]
# king studio suite
# [('king', 'studio'), ('studio', 'suite')]
# queen suite two queen beds
# [('queen', 'suite'), ('suite', 'two'), ('two', 'queen'), ('queen', 'beds')]
# standard king suite
# [('standard', 'king'), ('king', 'suite')]
# king room
# [('king', 'room')]
# deluxe king room
# [('deluxe', 'king'), ('king', 'room')]
# king room
# [('king', 'room')]
# standard room two double beds
# [('standard', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# standard queen room
# [('standard', 'queen'), ('queen', 'room')]
# queen suite two queen beds
# ...
# room selected check in
# [('room', 'selected'), ('selected', 'check'), ('check', 'in')]
# deluxe double room two double beds
# [('deluxe', 'double'), ('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# king room
# [('king', 'room')]
# king suite   bed
# [('king', 'suite'), ('suite', 'bed')]
# king room
# [('king', 'room')]
# studio
# []
# guestroom two queens
# [('guestroom', 'two'), ('two', 'queens')]
# fab room,   king,
# [('fab', 'room'), ('room', ','), (',', 'king'), ('king', ',')]
# double room
# [('double', 'room')]
# deluxe queen room two queen beds
# [('deluxe', 'queen'), ('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# signature room
# [('signature', 'room')]
# bunk bed   bed female dormitory room
# [('bunk', 'bed'), ('bed', 'bed'), ('bed', 'female'), ('female', 'dormitory'), ('dormitory', 'room')]
# guest room,   king, city view
# [('guest', 'room'), ('room', ','), (',', 'king'), ('king', ','), (',', 'city'), ('city', 'view')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# standard room two double beds
# [('standard', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# chamber king
# [('chamber', 'king')]
# klondike standard room
# [('klondike', 'standard'), ('standard', 'room')]
# one bedroom king suite
# [('one', 'bedroom'), ('bedroom', 'king'), ('king', 'suite')]
# king room
# [('king', 'room')]
# king studio suite
# [('king', 'studio'), ('studio', 'suite')]
# fairway queen
# [('fairway', 'queen')]
# queen room
# [('queen', 'room')]
# king studio suite
# [('king', 'studio'), ('studio', 'suite')]
# deluxe king suite (no resort fees +   parking)
# [('deluxe', 'king'), ('king', 'suite'), ('suite', '('), ('(', 'no'), ('no', 'resort'), ('resort', 'fees'), ('fees', '+'), ('+', 'parking'), ('parking', ')')]
# king bed standard
# [('king', 'bed'), ('bed', 'standard')]
# king studio suite
# [('king', 'studio'), ('studio', 'suite')]
# standard king room
# [('standard', 'king'), ('king', 'room')]
# deluxe room,   doubles,
# [('deluxe', 'room'), ('room', ','), (',', 'doubles'), ('doubles', ',')]
# burgundy room,   queen beds,
# [('burgundy', 'room'), ('room', ','), (',', 'queen'), ('queen', 'beds'), ('beds', ',')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# deluxe room
# [('deluxe', 'room')]
# bed   bed female dormitory room ensuite  room
# [('bed', 'bed'), ('bed', 'female'), ('female', 'dormitory'), ('dormitory', 'room'), ('room', 'ensuite'), ('ensuite', 'room')]
# single bed female dormitory room shared  room
# [('single', 'bed'), ('bed', 'female'), ('female', 'dormitory'), ('dormitory', 'room'), ('room', 'shared'), ('shared', 'room')]
# deluxe room two queen beds
# [('deluxe', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# deluxe king room
# [('deluxe', 'king'), ('king', 'room')]
# single bed   bed female dormitory room
# [('single', 'bed'), ('bed', 'bed'), ('bed', 'female'), ('female', 'dormitory'), ('dormitory', 'room')]
# standard one full size bed
# [('standard', 'one'), ('one', 'full'), ('full', 'size'), ('size', 'bed')]
# double room
# [('double', 'room')]
# double room shared
# [('double', 'room'), ('room', 'shared')]
# double room two double beds
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# single bed female dormitory room   private  room
# [('single', 'bed'), ('bed', 'female'), ('female', 'dormitory'), ('dormitory', 'room'), ('room', 'private'), ('private', 'room')]
# junior suite
# [('junior', 'suite')]
# standard queen room
# [('standard', 'queen'), ('queen', 'room')]
# standard room
# [('standard', 'room')]
# queen room
# [('queen', 'room')]
# deluxe king room
# [('deluxe', 'king'), ('king', 'room')]
# queen room shared  room
# [('queen', 'room'), ('room', 'shared'), ('shared', 'room')]
# double room
# [('double', 'room')]
# king room
# [('king', 'room')]
# one king bed
# [('one', 'king'), ('king', 'bed')]
# king room
# [('king', 'room')]
# one queen bed
# [('one', 'queen'), ('queen', 'bed')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# bed   bed mixed dormitory room
# [('bed', 'bed'), ('bed', 'mixed'), ('mixed', 'dormitory'), ('dormitory', 'room')]
# wonderful, guest room,   king   renovated
# [('wonderful', ','), (',', 'guest'), ('guest', 'room'), ('room', ','), (',', 'king'), ('king', 'renovated')]
# queen room bay view
# [('queen', 'room'), ('room', 'bay'), ('bay', 'view')]
# standard king room
# [('standard', 'king'), ('king', 'room')]
# deluxe queen room two queen beds
# [('deluxe', 'queen'), ('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# deluxe king room
# [('deluxe', 'king'), ('king', 'room')]
# premier studio suite
# [('premier', 'studio'), ('studio', 'suite')]
# deluxe king room
# [('deluxe', 'king'), ('king', 'room')]
# traditional king room
# [('traditional', 'king'), ('king', 'room')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# superior king room
# [('superior', 'king'), ('king', 'room')]
# king room kitchenette
# [('king', 'room'), ('room', 'kitchenette')]
# king suite walk in        ible
# [('king', 'suite'), ('suite', 'walk'), ('walk', 'in'), ('in', 'ible')]
# luxury suite
# [('luxury', 'suite')]
# one bedroom suite beachfront ocean view     queen bed     bed
# [('one', 'bedroom'), ('bedroom', 'suite'), ('suite', 'beachfront'), ('beachfront', 'ocean'), ('ocean', 'view'), ('view', 'queen'), ('queen', 'bed'), ('bed', 'bed')]
# four bedroom house
# [('four', 'bedroom'), ('bedroom', 'house')]
# standard double queen room
# [('standard', 'double'), ('double', 'queen'), ('queen', 'room')]
# deluxe double room
# [('deluxe', 'double'), ('double', 'room')]
# premium double room two double beds
# [('premium', 'double'), ('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# one bedroom king suite pool view
# [('one', 'bedroom'), ('bedroom', 'king'), ('king', 'suite'), ('suite', 'pool'), ('pool', 'view')]
# king room
# [('king', 'room')]
# superior king room
# [('superior', 'king'), ('king', 'room')]
# double room two double beds
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# standard room two queen beds
# [('standard', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# standard two double beds
# [('standard', 'two'), ('two', 'double'), ('double', 'beds')]
# studio, studio,   king
# [('studio', ','), (',', 'studio'), ('studio', ','), (',', 'king')]
# ocean view premier king bed
# [('ocean', 'view'), ('view', 'premier'), ('premier', 'king'), ('king', 'bed')]
# standard king room
# [('standard', 'king'), ('king', 'room')]
# deluxe queen room two queen beds
# [('deluxe', 'queen'), ('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# deluxe king room
# [('deluxe', 'king'), ('king', 'room')]
# premier studio suite
# [('premier', 'studio'), ('studio', 'suite')]
# deluxe king room
# [('deluxe', 'king'), ('king', 'room')]
# traditional king room
# [('traditional', 'king'), ('king', 'room')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# superior king room
# [('superior', 'king'), ('king', 'room')]
# king room kitchenette
# [('king', 'room'), ('room', 'kitchenette')]
# king suite walk in        ible
# [('king', 'suite'), ('suite', 'walk'), ('walk', 'in'), ('in', 'ible')]
# luxury suite
# [('luxury', 'suite')]
# one bedroom suite beachfront ocean view     queen bed     bed
# [('one', 'bedroom'), ('bedroom', 'suite'), ('suite', 'beachfront'), ('beachfront', 'ocean'), ('ocean', 'view'), ('view', 'queen'), ('queen', 'bed'), ('bed', 'bed')]
# four bedroom house
# [('four', 'bedroom'), ('bedroom', 'house')]
# standard double queen room
# [('standard', 'double'), ('double', 'queen'), ('queen', 'room')]
# deluxe double room
# [('deluxe', 'double'), ('double', 'room')]
# premium double room two double beds
# [('premium', 'double'), ('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# one bedroom king suite pool view
# [('one', 'bedroom'), ('bedroom', 'king'), ('king', 'suite'), ('suite', 'pool'), ('pool', 'view')]
# superior king room
# [('superior', 'king'), ('king', 'room')]
# king room
# [('king', 'room')]
# superior king room
# [('superior', 'king'), ('king', 'room')]
# double room two double beds
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# standard room two queen beds
# [('standard', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# standard two double beds
# [('standard', 'two'), ('two', 'double'), ('double', 'beds')]
# studio, studio,   king
# [('studio', ','), (',', 'studio'), ('studio', ','), (',', 'king')]
# ocean view premier king bed
# [('ocean', 'view'), ('view', 'premier'), ('premier', 'king'), ('king', 'bed')]
# standard king room
# [('standard', 'king'), ('king', 'room')]
# deluxe queen room two queen beds
# [('deluxe', 'queen'), ('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# deluxe king room
# [('deluxe', 'king'), ('king', 'room')]
# premier studio suite
# [('premier', 'studio'), ('studio', 'suite')]
# deluxe king room
# [('deluxe', 'king'), ('king', 'room')]
# traditional king room
# [('traditional', 'king'), ('king', 'room')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# superior king room
# [('superior', 'king'), ('king', 'room')]
# king room kitchenette
# [('king', 'room'), ('room', 'kitchenette')]
# king suite walk in        ible
# [('king', 'suite'), ('suite', 'walk'), ('walk', 'in'), ('in', 'ible')]
# luxury suite
# [('luxury', 'suite')]
# one bedroom suite beachfront ocean view     queen bed     bed
# [('one', 'bedroom'), ('bedroom', 'suite'), ('suite', 'beachfront'), ('beachfront', 'ocean'), ('ocean', 'view'), ('view', 'queen'), ('queen', 'bed'), ('bed', 'bed')]
# four bedroom house
# [('four', 'bedroom'), ('bedroom', 'house')]
# standard double queen room
# [('standard', 'double'), ('double', 'queen'), ('queen', 'room')]
# deluxe double room
# [('deluxe', 'double'), ('double', 'room')]
# premium double room two double beds
# [('premium', 'double'), ('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# one bedroom king suite pool view
# [('one', 'bedroom'), ('bedroom', 'king'), ('king', 'suite'), ('suite', 'pool'), ('pool', 'view')]
# superior king room
# [('superior', 'king'), ('king', 'room')]
# king room
# [('king', 'room')]
# superior king room
# [('superior', 'king'), ('king', 'room')]
# double room two double beds
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# standard room two queen beds
# [('standard', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# standard two double beds
# [('standard', 'two'), ('two', 'double'), ('double', 'beds')]
# studio, studio,   king
# [('studio', ','), (',', 'studio'), ('studio', ','), (',', 'king')]
# ocean view premier king bed
# [('ocean', 'view'), ('view', 'premier'), ('premier', 'king'), ('king', 'bed')]
# single bed   bed dormitory room
# [('single', 'bed'), ('bed', 'bed'), ('bed', 'dormitory'), ('dormitory', 'room')]
# double room two double beds
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# king studio
# [('king', 'studio')]
# deluxe room
# [('deluxe', 'room')]
# queen suite two queen beds
# [('queen', 'suite'), ('suite', 'two'), ('two', 'queen'), ('queen', 'beds')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# bed   bed mixed dormitory room
# [('bed', 'bed'), ('bed', 'mixed'), ('mixed', 'dormitory'), ('dormitory', 'room')]
# double room two double beds
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# king room
# [('king', 'room')]
# deluxe studio   queen bed
# [('deluxe', 'studio'), ('studio', 'queen'), ('queen', 'bed')]
# king room
# [('king', 'room')]
# king room   bed
# [('king', 'room'), ('room', 'bed')]
# king room
# [('king', 'room')]
# king room      ible
# [('king', 'room'), ('room', 'ible')]
# classic king room city view
# [('classic', 'king'), ('king', 'room'), ('room', 'city'), ('city', 'view')]
# double room two double beds
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# double room private  room
# [('double', 'room'), ('room', 'private'), ('private', 'room')]
# savvy double
# [('savvy', 'double')]
# superior king room city view
# [('superior', 'king'), ('king', 'room'), ('room', 'city'), ('city', 'view')]
# standard king room
# [('standard', 'king'), ('king', 'room')]
# standard room
# [('standard', 'room')]
# king room
# [('king', 'room')]
# superior king room
# [('superior', 'king'), ('king', 'room')]
# king room
# [('king', 'room')]
# queen room two queen beds      ible
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds'), ('beds', 'ible')]
# single bed   bed dormitory room
# [('single', 'bed'), ('bed', 'bed'), ('bed', 'dormitory'), ('dormitory', 'room')]
# double room two double beds
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# king studio
# [('king', 'studio')]
# deluxe room
# [('deluxe', 'room')]
# queen suite two queen beds
# [('queen', 'suite'), ('suite', 'two'), ('two', 'queen'), ('queen', 'beds')]
# queen room two queen beds
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds')]
# bed   bed mixed dormitory room
# [('bed', 'bed'), ('bed', 'mixed'), ('mixed', 'dormitory'), ('dormitory', 'room')]
# double room two double beds
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# king room
# [('king', 'room')]
# deluxe studio   queen bed
# [('deluxe', 'studio'), ('studio', 'queen'), ('queen', 'bed')]
# king room
# [('king', 'room')]
# king room   bed
# [('king', 'room'), ('room', 'bed')]
# king room
# [('king', 'room')]
# king room      ible
# [('king', 'room'), ('room', 'ible')]
# classic king room city view
# [('classic', 'king'), ('king', 'room'), ('room', 'city'), ('city', 'view')]
# double room private  room
# [('double', 'room'), ('room', 'private'), ('private', 'room')]
# double room two double beds
# [('double', 'room'), ('room', 'two'), ('two', 'double'), ('double', 'beds')]
# savvy double
# [('savvy', 'double')]
# superior king room city view
# [('superior', 'king'), ('king', 'room'), ('room', 'city'), ('city', 'view')]
# standard king room
# [('standard', 'king'), ('king', 'room')]
# standard room
# [('standard', 'room')]
# king room
# [('king', 'room')]
# superior king room
# [('superior', 'king'), ('king', 'room')]
# king room
# [('king', 'room')]
# queen room two queen beds      ible
# [('queen', 'room'), ('room', 'two'), ('two', 'queen'), ('queen', 'beds'), ('beds', 'ible')]
# studio   queen bed
# [('studio', 'queen'), ('queen', 'bed')]
# single bed mixed standard dormitory
# [('single', 'bed'), ('bed', 'mixed'), ('mixed', 'standard'), ('standard', 'dormitory')]
# larger deluxe king room   bed
# [('larger', 'deluxe'), ('deluxe', 'king'), ('king', 'room'), ('room', 'bed')]
# standard double room
# [('standard', 'double'), ('double', 'room')]
# city view king
# [('city', 'view'), ('view', 'king')]
# full room
# [('full', 'room')]
# deluxe king studio
# [('deluxe', 'king'), ('king', 'studio')]
# guest room,   king
# [('guest', 'room'), ('room', ','), (',', 'king')]
# standard cabin shared  room
# [('standard', 'cabin'), ('cabin', 'shared'), ('shared', 'room')]
# king room
# [('king', 'room')]
# deluxe queen room balcony
# [('deluxe', 'queen'), ('queen', 'room'), ('room', 'balcony')]
# queen bed
# [('queen', 'bed')]
# queen room
# [('queen', 'room')]
# double room
# [('double', 'room')]
# bunk bed room
# [('bunk', 'bed'), ('bed', 'room')]
# standard queen room
# [('standard', 'queen'), ('queen', 'room')]
# standard bunk bed room shared  room
# [('standard', 'bunk'), ('bunk', 'bed'), ('bed', 'room'), ('room', 'shared'), ('shared', 'room')]
# king room
# [('king', 'room')]
# standard queen room
# [('standard', 'queen'), ('queen', 'room')]
# artist twin
# [('artist', 'twin')]
# two double beds standard
# [('two', 'double'), ('double', 'beds'), ('beds', 'standard')]
# king room
# [('king', 'room')]
# traditional king, guest room,   king
# [('traditional', 'king'), ('king', ','), (',', 'guest'), ('guest', 'room'), ('room', ','), (',', 'king')]
# king studio kitchenette
# [('king', 'studio'), ('studio', 'kitchenette')]
# king room
# [('king', 'room')]

# %%
from sematch.semantic.similarity import WordNetSimilarity
wns = WordNetSimilarity()
wns.word_similarity('dog', 'cat', 'li')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [289], in <cell line: 1>()
# ----> 1 from sematch.semantic.similarity import WordNetSimilarity
#       2 wns = WordNetSimilarity()
#       3 wns.word_similarity('dog', 'cat', 'li')
#
# ModuleNotFoundError: No module named 'sematch'

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

c_df = pd.DataFrame(sorted(c.items(),key=lambda x:x[1],reverse=False), columns = ['trigram','count'])
c_df['trigram'] = list(c_df['trigram'].astype(str))
c_df['trigram'] = c_df['trigram'].str.replace('(','')
c_df['trigram'] = c_df['trigram'].str.replace(')','')
c_df['trigram'] = c_df['trigram'].str.replace(',','')
c_df['trigram'] = c_df['trigram'].str.replace("'","")
# c_df['trigram'] = c_df['trigram'].apply(lambda x: ' '.join(sorted(x.split())))
gc_df = c_df.groupby('trigram').aggregate(np.sum)
gc_df.sort_values(by='count', ascending=False, inplace=True)
top_df = gc_df.loc[gc_df['count']>10]
top_df.to_csv(os.path.join(ROOT_DIR,'data/tmp/','room_types'))

# %%
top_df.plot.bar()
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ## Initialize OTA Scraper Class
# Required to extract the data from the Wrangler

# %%
import sys
sys.path.insert(1, '../../lib/wrangler')
import otaWebScraper as otaws
import clean as clean
import enrich as enrich
import datetime

dataDirPath="../../data/hospitality/bookings/scraper/"

if debug:
    import importlib
    otaws = importlib.reload(otaws)
    clean = importlib.reload(clean)
    enrich = importlib.reload(enrich)

_dataName = "booking_search_data"

clsScraper = otaws.OTAWebScraper(name=_dataName)
clsCleaner = clean.DataClensing(name=_dataName)
clsEnrich = enrich.DataEnrichment(name=_dataName)
# Out:
# All packages in OTAWebScraper loaded successfully!
# All packages in DataClensing loaded successfully!
# All packages in OTAWebScraper loaded successfully!
# Initialing OTAWebScraper class for  booking_search_data
# Initialing DataEnrichment class for  booking_search_data
# Initialing DataEnrichment class for  booking_search_data

# %% [markdown]
# ## Load the data

# %%
#../../data/hospitality/bookings/scraper/rates/2022-9-7-9-0/
#dirPath = _current_search_data_dir
dirPath = dataDirPath+"rates/2022-9-7-9-0/"
removed_files = clsScraper.remove_empty_files(dirPath)
if len(removed_files) > 0:
    print("%d files removed" %len(removed_files))
kwargs = {"columns" : ["search_datetime",
                       "checkin_date",
                       "propery_name",
                       "room_type",
                       "room_rate",
                       "review_score",
                       "destination_id",
                       "location",
                       "other"]}

rates_df = clsScraper.read_folder_csv_to_df(dirPath, **kwargs)
dtype_dict = {"search_datetime": "datetime64[ns]",
              "checkin_date": "datetime64[D]",
              "propery_name": "string",
              "room_type": "string",
              "room_rate": "string",
              "review_score": "float64",
              "destination_id": "string",
              "location": "string",
              "other" : "string"
             }
''' set the desired data types '''
rates_df = rates_df.astype(dtype_dict)
#rates_df.info()

# %%
''' drop duplicate rows '''
import pandas as pd

#print(rates_df.shape)

_distinct_df = pd.DataFrame()
_distinct_df = clsCleaner.drop_duplicates(rates_df)
#print(_distinct_df.shape)
''' round search datetime to nearest 30 min'''
_distinct_df['search_datetime']=_distinct_df['search_datetime'].dt.round('30min')

# %% [markdown]
# ## Augment with datetime columns

# %%
''' Augment the DateTime columns with listed new columns '''
_dict_col_to_aug = {"DateTime" :   # type of datetime columns to augment the dataframe
                    ["YYYY",       # 4 digit year (int)
                     "DD",         # day as 1 digit and 2 digit if abbreviation = true
                     "MM",         # month as 1 digit and 2 digit if abbreviation = true
                     "MMM",        # month as name or 3 letters if abbreviation = True
                     "DOW",        # day-of-week name or 3 letter if abbreviation = True
                     "MMM-DD",     # three letter two digit month and two digit day (e.g. [09]Sep-10)
                     "HH-mm",      # two digit hour and minute
                    ]
                   }
_kwargs = {"dt_col_name" : "search_datetime",    # identifies the datetime column in the dataframe
           "pad_lead_zeros" : True,   # truncates the string to give 3 character names for year, month, dow
           "abbreviate" : True,
           "sorted_by" : ["YYYY","MM","DD"]
          }
_enriched_df = clsEnrich.get_enriched_data(_distinct_df,
                                           col_augment_dict = _dict_col_to_aug,
                                           **_kwargs
                                          )
_aug_cols = _dict_col_to_aug["DateTime"]
_distinct_df[_aug_cols] = _enriched_df[_aug_cols]

''' sort by date '''
_distinct_df = _distinct_df.sort_values(by=["YYYY","MM","DD"],kind='quicksort')
#print(_distinct_df.head())
print("\nEnrichment Complete!")
print(_distinct_df.shape)
print(_distinct_df.info())
# Out:
# Columns to augment to dataframe:
#  {'DateTime': ['YYYY', 'DD', 'MM', 'MMM', 'DOW', 'MMM-DD', 'HH-mm']}
#
# Enrichment Complete!
# (2258, 16)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2258 entries, 0 to 2257
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   search_datetime  2258 non-null   datetime64[ns]
#  1   checkin_date     2258 non-null   datetime64[ns]
#  2   propery_name     2258 non-null   string
#  3   room_type        2258 non-null   string
#  4   room_rate        2258 non-null   string
#  5   review_score     2258 non-null   float64
#  6   destination_id   2258 non-null   string
#  7   location         2258 non-null   string
#  8   other            2258 non-null   string
#  9   YYYY             2258 non-null   int64
#  10  DD               2258 non-null   object
#  11  MM               2258 non-null   object
#  12  MMM              2258 non-null   object
#  13  DOW              2258 non-null   object
#  14  MMM-DD           2258 non-null   object
#  15  HH-mm            2258 non-null   object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(6), string(6)
# memory usage: 299.9+ KB
# None

# %%
_distinct_df['room_rate'].unique()
#_distinct_df['search_datetime'].unique()
# Out:
# <StringArray>
# [  'US$629',   'US$409',   'US$659',   'US$599',   'US$589',   'US$524',
#    'US$665',   'US$749',   'US$469',   'US$559',
#  ...
#  'US$2,960',   'US$223',    'US$40',   'US$232',   'US$280', 'US$1,051',
#    'US$430',   'US$112',   'US$300',   'US$310']
# Length: 451, dtype: string

# %% [markdown]
# * [Consider clustering with SOM](https://www.kaggle.com/code/izzettunc/introduction-to-time-series-clustering/notebook)
# * [Time-series segmentation](https://www.kaggle.com/code/zonnalobo/timeseries-segmentation-and-forecasting/notebook)

# %%
import matplotlib.pyplot as plt

plt.scatter(_distinct_df['room_rate'],_distinct_df['HH-mm'])
plt.ylabel('rating')
plt.show()

# %% [markdown]
# # Scrape Online Travel Agent (OTA) Property Prices
#
# ___Changes in this notebook must be migrated to the ```dags/modules/ota/etlotaPropertyPrices.py```___
#
# @Nileka add a description here as to what this notebook offers
#
# ### Execute the cell below once to turn off debugging

# %%
'''
    WARNING CONTROL to display or ignore all warnings
'''
import warnings; warnings.simplefilter('ignore')     #switch betweeb 'default' and 'ignore'
import traceback

''' Set debug flag to view extended error messages; else set it to False to turn off debugging mode '''
debug = True

# %% [markdown]
# ## Initialize the OTA scrape class

# %%
import os
import sys
from datetime import datetime, date, timedelta

# ROOT_DIR = "/home/nuwan/workspace/rezgate/wrangler"
# UTILS_DIR = "/home/nuwan/workspace/rezgate/utils/"
# MODULE_DIR = os.path.join(ROOT_DIR, 'modules/ota/')
# DATA_DIR = os.path.join(ROOT_DIR, 'data/hospitality/bookings/scraper')
sys.path.insert(1,"/home/nuwan/workspace/rezgate/")
from wrangler.modules.ota.scraper import propertyScrapers as ps, scraperUtils as otasu
# sys.path.insert(1,MODULE_DIR)
# import otasutils as otasu
# import propertyScrapers as ps
# sys.path.insert(1,UTILS_DIR)
from utils import sparkwls as spark, nlp as nlp
# import nlp

''' restart initiate classes '''
if debug:
    import importlib
    ps = importlib.reload(ps)
    otasu = importlib.reload(otasu)
    spark = importlib.reload(spark)
    nlp = importlib.reload(nlp)
    
''' optional - if not specified class will use the default values '''
kwargs = {
    "ROOT_DIR":ROOT_DIR,   # absolute path to the wrangler dir
    "UTILS_DIR":UTILS_DIR, # abslute path to the generic utils
    "MODULE_DIR":MODULE_DIR,   # absolute path to the ota module
    "DATA_DIR":DATA_DIR, # absolute path to the scraper data dir
}
clsScraper = ps.PropertyScraper(desc='scrape hotel prices data from OTAs', **kwargs)
clsSparkWL = spark.SparkWorkLoads(desc="ota prices", **kwargs)
print("/nClass initialization and load complete!")
# Out:
# All scraper software packages loaded successfully!
# All otaUtils in modules/ota/ software packages loaded successfully!
# All packages in SparkWorkLoads loaded successfully!
# All packages in nlp loaded successfully!
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [11], in <cell line: 33>()
#      26 ''' optional - if not specified class will use the default values '''
#      27 kwargs = {
#      28     "ROOT_DIR":ROOT_DIR,   # absolute path to the wrangler dir
#      29     "UTILS_DIR":UTILS_DIR, # abslute path to the generic utils
#      30     "MODULE_DIR":MODULE_DIR,   # absolute path to the ota module
#      31     "DATA_DIR":DATA_DIR, # absolute path to the scraper data dir
#      32 }
# ---> 33 clsScraper = ps.PropertyScraper(desc='scrape hotel prices data from OTAs', **kwargs)
#      34 clsSparkWL = spark.SparkWorkLoads(desc="ota prices", **kwargs)
#      35 print("/nClass initialization and load complete!")
#
# File ~/workspace/rezgate/wrangler/modules/ota/scraper/propertyScrapers.py:68, in PropertyScraper.__init__(self, desc, **kwargs)
#      66         import scraperUtils as otau
#      67 #     sys.path.insert(1,__utils_dir__)
# ---> 68         import nlp
#      69         import sparkwls as spark
#      71         ''' initialize util class to use common functions '''
#
# ModuleNotFoundError: No module named 'nlp'

# %% [markdown]
# ## Initialize the set of OTA URL for Scraping

# %%
file = "otaInputURLs.json"
start_date = date.today()
end_date = start_date + timedelta(days=1)

try:
    if start_date < date.today():
        raise ValueError("Start date must be greater than today: %s" % str(date.today()))
    if end_date <= start_date:
        raise ValueError("End date %s is invalid. It must be greater than Start Date: %s" % (str(end_date),str(start_date)))
    kwargs = {"pageOffset":10,
              "pageUpperLimit":550,
              "startDate": start_date,
              "endDate" : end_date,
             }

    _otaURLfilePath, _ota_url_parameterized_list  = clsScraper.build_scrape_url_list(
                                                    file_name=file,  # mandatory to give the inputs json file
                                                    dir_path=None,   # optional to be used iff required
                                                    **kwargs
                                                    )
    if _otaURLfilePath:
        print("Data in: %s" % _otaURLfilePath)
    if len(_ota_url_parameterized_list)>0:
        print("Completed parameterizing urls with %d instances." 
              % (len(_ota_url_parameterized_list)))

except Exception as err:
    _s_fn_id = "Class <WebScraper> Function <read_folder_csv_to_df>"
    print("[Error]"+_s_fn_id, err)
    print(traceback.format_exc())
# Out:
# Loaded 1 properties to begin scraping OTA data.
# Processing booking.com ...
# Data in: /home/nuwan/workspace/rezgate/wrangler/data/tmp/PropertyScraper-build-scrape-url-list.csv
# Completed parameterizing urls with 784 instances.

# %% [markdown]
# ## Prepare folder & file structure

# %%
from datetime import datetime, timezone

dirPath = None
_search_dt = datetime.now()
_search_dt = _search_dt + (datetime.min - _search_dt) % timedelta(minutes=15)
''' include the timezone '''
_search_dt = (_search_dt.replace(tzinfo=timezone.utc)).isoformat()

kwargs = {
#    'SEARCH_DATETIME': _search_dt,
    'STORAGE_METHOD': "local",   # values can be "local" or "AWS_S3"
}

_current_search_data_store_dir = clsScraper.make_storage_dir(**kwargs)
print("Extracting data into %s for search datetime: %s" 
      % (_current_search_data_store_dir,str(_search_dt)))
# Out:
# Extracting data into /home/nuwan/workspace/rezgate/wrangler/data/hospitality/bookings/scraper/rates/2022-10-4-13-0/ for search datetime: 2022-10-04T13:00:00+00:00

# %% [markdown]
# ## Scrape data into CSVs
# ___TODO:___ hault if internet connection times out; might be possible with airflow.

# %%
import pandas as pd

''' TODO change to read csv using utils/sparkwls class '''
if _otaURLfilePath:
    urlDF = pd.read_csv(_otaURLfilePath, sep=",")
    _otaURLParamDictList = urlDF.to_dict('records')

''' TODO change the function parameter names to camel format '''
_l_saved_files = clsScraper.scrape_url_list(
    otaURLlist =_otaURLParamDictList,
    searchDT = _search_dt,
    data_store_dir =_current_search_data_store_dir)
print("Scraping completed and data saved in %s!" % _current_search_data_store_dir)
# Out:
# loading parameterized urls from list 784 records
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=230
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=230
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=240
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=240
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=250
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=250
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=260
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=260
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=270
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=270
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=280
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=280
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=290
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=290
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=300
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=300
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=310
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=310
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=320
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=320
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=330
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=330
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=340
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=340
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=350
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=350
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=360
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=360
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=370
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=370
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=380
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=380
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=390
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=390
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=400
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=400
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=410
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=410
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=420
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=420
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=430
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=430
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=440
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=440
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=450
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=450
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=460
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=460
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=470
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=470
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=480
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=480
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=490
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=490
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=500
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=500
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=510
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=510
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=520
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=520
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=530
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=530
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=540
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=540
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=550
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20079110&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=550
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20088325&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=400
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20088325&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=400
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20088325&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=410
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20088325&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=410
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20088325&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=420
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20088325&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=420
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20088325&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=430
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20088325&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=430
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20088325&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=440
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20088325&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=440
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20088325&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=450
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20088325&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=450
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20088325&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=460
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ...
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20021296&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=460
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20021296&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=470
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20021296&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=470
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20021296&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=480
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20021296&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=480
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20021296&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=490
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20021296&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=490
#
# [Error]function <_scrape_bookings_to_csv> HTTPSConnectionPool(host='www.booking.com', port=443): Max retries exceeded with url: /searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20021296&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=500 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f04d525d730>: Failed to establish a new connection: [Errno 110] Connection timed out'))
# Traceback (most recent call last):
#   File "/home/nuwan/.local/lib/python3.8/site-packages/urllib3/connection.py", line 174, in _new_conn
#     conn = connection.create_connection(
#   File "/home/nuwan/.local/lib/python3.8/site-packages/urllib3/util/connection.py", line 95, in create_connection
#     raise err
#   File "/home/nuwan/.local/lib/python3.8/site-packages/urllib3/util/connection.py", line 85, in create_connection
#     sock.connect(sa)
# TimeoutError: [Errno 110] Connection timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nuwan/.local/lib/python3.8/site-packages/urllib3/connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "/home/nuwan/.local/lib/python3.8/site-packages/urllib3/connectionpool.py", line 386, in _make_request
#     self._validate_conn(conn)
#   File "/home/nuwan/.local/lib/python3.8/site-packages/urllib3/connectionpool.py", line 1042, in _validate_conn
#     conn.connect()
#   File "/home/nuwan/.local/lib/python3.8/site-packages/urllib3/connection.py", line 358, in connect
#     self.sock = conn = self._new_conn()
#   File "/home/nuwan/.local/lib/python3.8/site-packages/urllib3/connection.py", line 186, in _new_conn
#     raise NewConnectionError(
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x7f04d525d730>: Failed to establish a new connection: [Errno 110] Connection timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nuwan/.local/lib/python3.8/site-packages/requests/adapters.py", line 489, in send
#     resp = conn.urlopen(
#   File "/home/nuwan/.local/lib/python3.8/site-packages/urllib3/connectionpool.py", line 787, in urlopen
#     retries = retries.increment(
#   File "/home/nuwan/.local/lib/python3.8/site-packages/urllib3/util/retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='www.booking.com', port=443): Max retries exceeded with url: /searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20021296&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=500 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f04d525d730>: Failed to establish a new connection: [Errno 110] Connection timed out'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 457, in _scrape_bookings_to_csv
#     response = requests.get(url, headers=headers)
#   File "/home/nuwan/.local/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/home/nuwan/.local/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/nuwan/.local/lib/python3.8/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/nuwan/.local/lib/python3.8/site-packages/requests/sessions.py", line 701, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/nuwan/.local/lib/python3.8/site-packages/requests/adapters.py", line 565, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='www.booking.com', port=443): Max retries exceeded with url: /searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20021296&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=500 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f04d525d730>: Failed to establish a new connection: [Errno 110] Connection timed out'))
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20021296&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=510
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20021296&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=510
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20021296&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=520
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20021296&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=520
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20021296&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=530
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20021296&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=530
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20021296&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=540
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20021296&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=540
#
# [Error]function <_scrape_bookings_to_csv> No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20021296&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=550
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/propertyScrapers.py", line 471, in _scrape_bookings_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.booking.com/searchresults.en-gb.html?ss=Las+Vegas&label=gen173nr-1DCAEoggI46AdIM1gEaIUBiAEBmAEJuAEXyAEM2AED6AEBiAIBqAIDuAK_g7aYBsACAdICJDFiNWFiNzM3LTQ0YmItNDIzOC04NDM0LWRjMDFlNmZhYTUwM9gCBOACAQ&sid=36e124997ccdbec4823b6c98d5931c2e&aid=304142&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=20021296&dest_type=city&checkin=2022-10-04&checkout=2022-10-05&group_adults=1&no_rooms=1&group_children=0&selected_currency=USD&offset=550
#
# Scraping completed and data saved in /home/nuwan/workspace/rezgate/wrangler/data/hospitality/bookings/scraper/rates/2022-10-4-13-0/!

# %% [markdown]
# ## Read CSV into spark dataframe

# %%
spark_kwargs = {"TO_PANDAS":True,   # change spark dataframe to pandas
                "IS_FOLDER":True,   # if folder then check if folder is empty
               }
# _current_search_data_store_dir = "../../data/hospitality/bookings/scraper/rates/2022-10-5-21-0/"
# _current_search_data_store_dir = os.path.join(DATA_DIR, "rates/2022-10-6-0-30/")
# dirPath = _current_search_data_store_dir
_search_sdf, traceback = clsSparkWL.read_csv_to_sdf(filesPath=_current_search_data_store_dir, **spark_kwargs)
if not traceback:
    print("Spark loaded %d rows" % _search_sdf.shape[0])
else:
    print("No data loaded by spark; process failed!")
# Out:
# [Error]Class <SparkWorkLoads> Function <read_folder_csv_to_sdf> No data files found in director: /home/nuwan/workspace/rezgate/wrangler/data/hospitality/bookings/scraper/rates/2022-10-6-0-30/
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/utils/sparkwls.py", line 418, in read_csv_to_sdf
#     raise ValueError("No data files found in director: %s" % (filesPath))
# ValueError: No data files found in director: /home/nuwan/workspace/rezgate/wrangler/data/hospitality/bookings/scraper/rates/2022-10-6-0-30/
#
# No data loaded by spark

# %% [markdown]
# ## Transform the data
# augment the dataframe with:
# 1. exctract the room rate decimal numbers
# 1. matching city names to the codes
# 1. categorizing the room types based on the taxonomy
# 1. setting the data types of the columns
# using a transform function in the properties class
#
# ### Extract room rate decimal value

# %%
''' define room price column to extrac number'''
rate_col_name = "room_rate"
aug_col_name = "room_price"
''' extract the price value from room rate'''
_search_sdf = clsScraper.extract_room_rate(_search_sdf,rate_col_name,aug_col_name)

# %% [markdown]
# ### Categorize room type by similarity mappring

# %%
_save_rcate_to = os.path.join(ROOT_DIR,'data/tmp/similarity_categorized_rooms.csv')
''' categorize the room types '''
emb_kwargs = {
    'LOWER':True,
    'NO_STOP_WORDS':False,
    'METRIC':"COSIN",
    'MAX_SCORES':2,
    'TOLERANCE':0.7,
    'ROOM_CATE_FNAME':"room_descriptions.csv",
}
print("wait a moment this may take a while categorizing %d room type" % (_search_sdf.shape[0]))
_categorized_room_df = clsScraper.merge_similar_room_cate(_search_sdf,emb_kwargs)
_room_cate_count = len(_categorized_room_df.room_cate.unique())
print("Assigned %d room categories" % _room_cate_count)
# Out:
# wait a moment this may take a while categorizing 1084 room type
# Assigned 51 room categories

# %% [markdown]
# ### Assign location city names

# %%
_aug_dest_df = clsScraper.assign_lx_name(data_df=_categorized_room_df)
print("merged %d rows with destination name and type" % _aug_dest_df.shape[0])
# Out:
# merged 18912 rows with destination name and type

# %% [markdown]
# ## Save cleaned SDF to Tmp File

# %%
''' convert dataframe from panas to spark '''
_tmp_fname = clsSparkWL.save_sdf_to_csv(_aug_dest_df)
print("transformed data saved to %s" % _tmp_fname)
# Out:
# 22/10/04 20:54:09 WARN TaskSetManager: Stage 4 contains a task of very large size (1023 KiB). The maximum recommended task size is 1000 KiB.
# 22/10/04 20:54:11 WARN TaskSetManager: Stage 7 contains a task of very large size (1023 KiB). The maximum recommended task size is 1000 KiB.
# 22/10/04 20:54:12 WARN TaskSetManager: Stage 10 contains a task of very large size (1023 KiB). The maximum recommended task size is 1000 KiB.
# 22/10/04 20:54:14 WARN TaskSetManager: Stage 11 contains a task of very large size (1023 KiB). The maximum recommended task size is 1000 KiB.
# transformed data saved to /home/nuwan/workspace/rezgate/utils/data/tmp/SparkWorkLoads_save_sdf_to.csv

# %% [markdown]
# ## Read CSV from Tmp and Save to DB Table

# %%
''' Save dataframe to table '''
_s_tbl_name = "ota_property_prices"
_get_tmp_sdf = clsSparkWL.read_csv_to_sdf(filesPath=_tmp_fname)
_get_tmp_sdf.printSchema()
count, saved_df = clsScraper.save_to_db(data_df=_aug_dest_df,table_name = _s_tbl_name)
# count = clsSparkWL.insert_sdf_into_table(save_sdf=_get_tmp_sdf, dbTable=_s_tbl_name)
print("%d Data saved to %s" % (count,_s_tbl_name))
# Out:
# root
#  |-- ota_name: string (nullable = true)
#  |-- search_dt: timestamp (nullable = true)
#  |-- checkin_date: timestamp (nullable = true)
#  |-- destination_id: integer (nullable = true)
#  |-- property_name: string (nullable = true)
#  |-- room_type: string (nullable = true)
#  |-- room_rate: string (nullable = true)
#  |-- review_score: double (nullable = true)
#  |-- location_desc: string (nullable = true)
#  |-- other_info: string (nullable = true)
#  |-- currency: string (nullable = true)
#  |-- room_price: double (nullable = true)
#  |-- room_cate: string (nullable = true)
#  |-- similarity: double (nullable = true)
#  |-- dest_lx_name: string (nullable = true)
#  |-- dest_lx_type: string (nullable = true)
#
# 22/10/04 20:55:03 WARN TaskSetManager: Stage 18 contains a task of very large size (1086 KiB). The maximum recommended task size is 1000 KiB.
# Wait a moment while we insert data int ota_property_prices
# 22/10/04 20:55:06 WARN TaskSetManager: Stage 21 contains a task of very large size (1086 KiB). The maximum recommended task size is 1000 KiB.
# Save to ota_property_prices complete!
# 22/10/04 20:55:09 WARN TaskSetManager: Stage 22 contains a task of very large size (1086 KiB). The maximum recommended task size is 1000 KiB.
# 18912 Data saved to ota_property_prices

# %% [markdown]
# ## Read data from table

# %%
_s_tbl_name = "ota_property_prices"
data = clsSparkWL.get_data_from_table(dbTable=_s_tbl_name)
print("%d records loaded from %s" %(data.count(),_s_tbl_name))

data.select("*").distinct().where(date('created_dt') >= date.today()).sort("search_dt").show(2, vertical=True)
# Out:
# Wait a moment, retrieving data ...
# Loading complete!
# 82338 records loaded from ota_property_prices
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [16], in <cell line: 5>()
#       2 data = clsSparkWL.get_data_from_table(dbTable=_s_tbl_name)
#       3 print("%d records loaded from %s" %(data.count(),_s_tbl_name))
# ----> 5 data.select("*").distinct().where(date('created_dt') >= date.today()).sort("search_dt").show(2, vertical=True)
#
# TypeError: an integer is required (got type str)

# %%
''' DEPRECATED -- moved as a function in otaPropertyScraper class '''

''' Get destination id dictionary '''
destDirPath = os.path.join(DATA_PATH, 'destinations/')
destinations_sdf = clsSparkWL.read_csv_to_sdf(filesPath=destDirPath)
destinations_sdf = destinations_sdf.selectExpr("city as destination_name", \
                                                "destinationID as destination_id")
# destinations_sdf = destinations_sdf.withColumn("destination_name",col("destination_name").cast(StringType())) \
#                                 .withColumn("destination_id",col("destination_id").cast(StringType()))
if debug:
    destinations_sdf.printSchema()
    destinations_sdf.show(n=2, vertical=True, truncate=False)
    print("Destination dictionary loarded!")

''' Lookup & augment destination name '''
#aug_search_sdf = destinations_sdf.join(_search_sdf,on='destination_id',how='rightouter')
aug_search_sdf = _search_sdf.join(destinations_sdf,
                                  _search_sdf.destination_id == destinations_sdf.destination_id,
                                  how='leftouter').drop(_search_sdf.destination_id)

if debug:
    print("%d destination names augmented to dataframe!" % (aug_search_sdf.count()))
    aug_search_sdf.show(n=2, vertical=True, truncate=False)
# Out:
# root
#  |-- destination_name: string (nullable = true)
#  |-- destination_id: integer (nullable = true)
#
# -RECORD 0-------------------------
#  destination_name | Las Vegas
#  destination_id   | 20079110
# -RECORD 1-------------------------
#  destination_name | New York City
#  destination_id   | 20088325
# only showing top 2 rows
#
# Destination dictionary loarded!
# 2095 destination names augmented to dataframe!
# -RECORD 0-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  search_dt        | 2022-09-24 02:45:00
#  checkin_date     | 2022-09-23 00:00:00
#  property_name    | Extended Stay America Suites - Orlando - Lake Buena Vista
#  room_type        | Deluxe King Studio - Non-Smoking
#  room_rate        | 90.0
#  review_score     | 7.2
#  location_desc    | Lake Buena Vista, OrlandoShow on map12.1 miles from centre
#  other_info       | Deluxe King Studio - Non-SmokingPrivate studio • 1 bathroom • 301.4feet²1 extra-large double bedBreakfast includedFREE cancellation • No prepayment neededYou can cancel later, so lock in this great price today.Only 1 left at this price on our site
#  currency         | US$
#  destination_name | Orlando
#  destination_id   | 20023488
# -RECORD 1-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  search_dt        | 2022-09-24 02:45:00
#  checkin_date     | 2022-09-23 00:00:00
#  property_name    | Holiday Inn Express Orlando-Ocoee East, an IHG Hotel
#  room_type        | Queen Room with Two Queen Beds - Non-Smoking
#  room_rate        | 190.0
#  review_score     | 7.9
#  location_desc    | OrlandoShow on map6.2 miles from centre
#  other_info       | Queen Room with Two Queen Beds - Non-Smoking2 large double bedsBreakfast includedOnly 6 rooms left at this price on our site
#  currency         | US$
#  destination_name | Orlando
#  destination_id   | 20023488
# only showing top 2 rows

# %%
''' DEPRECATED - replaced with a function on otaPropertyScrpaer calss '''

from pyspark.sql.functions import substring,lit,col
from pyspark.sql.types import StringType,BooleanType,DateType,DecimalType,FloatType, IntegerType,LongType, ShortType, TimestampType

# _search_sdf=_search_sdf.withColumn("currency", lit("US$"))
# _search_sdf=_search_sdf.withColumn('room_rate', substring('room_rate', 4,10))

# ''' reset data types to match table '''
# _search_sdf = _search_sdf.withColumn("destination_id",col("destination_id").cast(StringType())) \
#     .withColumn("room_rate",col("room_rate").cast(FloatType()))
# #    .withColumn("search_datetime",col("search_datetime").cast(DateType()))

if debug:
    _search_sdf.printSchema()
    _search_sdf.show(n=2, vertical=True, truncate=False)
print("Split and Extraction complete!")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [8], in <cell line: 14>()
#       6 # _search_sdf=_search_sdf.withColumn("currency", lit("US$"))
#       7 # _search_sdf=_search_sdf.withColumn('room_rate', substring('room_rate', 4,10))
#       8
#    (...)
#      11 #     .withColumn("room_rate",col("room_rate").cast(FloatType()))
#      12 # #    .withColumn("search_datetime",col("search_datetime").cast(DateType()))
#      14 if debug:
# ---> 15     _search_sdf.printSchema()
#      16     _search_sdf.show(n=2, vertical=True, truncate=False)
#      17 print("Split and Extraction complete!")
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'printSchema'

# %%
''' DEPRECATED -- merge moved to the function in otaPropScraper '''

_categorized_room_df = _search_sdf.merge(_room_type_assign, how='left', left_on=['room_type'], right_on=['room_type'])
print("Merged %d rows with categorized room type information" % _categorized_room_df.shape[0])

_categorized_room_df = new_df
#_categorized_room_df.to_csv(_save_rcate_to)
#_save_rcate_to=clsSparkWL.save_sdf_to_csv(_save_rcate_to)
print("Merged data saved to %s" % (_save_rcate_to))
print("Room type categorization complete!")
# Out:
# Merged data saved to None
# Room type categorization complete!

# %%
''' DEPRECATED '''
_categorized_room_df = _search_sdf.merge(_room_type_assign, how='left', left_on=['room_type'], right_on=['room_type'])
_categorized_room_df.to_csv(os.path.join(ROOT_DIR,'data/tmp/similarity_scores.csv'))

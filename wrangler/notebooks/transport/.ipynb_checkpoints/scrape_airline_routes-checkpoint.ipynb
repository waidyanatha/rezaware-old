# %% [markdown]
# # Scrape Airline Routes and Times from OTAs
#
# @Nileka add a description here as to what this notebook offers
#
# ### Execute the cell below once to turn off debugging

# %%
'''
    WARNING CONTROL to display or ignore all warnings
'''
import warnings; warnings.simplefilter('ignore')     #switch betweeb 'default' and 'ignore'
import traceback

''' Set debug flag to view extended error messages; else set it to False to turn off debugging mode '''
debug = True

# %% [markdown]
# ## Initialize the OTA scrape class

# %%
import os
import sys
from datetime import datetime, date, timedelta
#import configparser

ROOT_DIR = "/home/nuwan/workspace/rezgate/wrangler"
MODULE_PATH = os.path.join(ROOT_DIR, 'modules/ota/')
sys.path.insert(1,MODULE_PATH)
import airlineScrapers as airWS

DATA_PATH = os.path.join(ROOT_DIR, 'data/transport/airlines/scraper/')

if debug:
    import importlib
    airWS = importlib.reload(airWS)
    
kwargs = {
    "ROOT_DIR":ROOT_DIR,
    "DATA_PATH":DATA_PATH,
}
clsScraper = airWS.AirlineScraper(name="kayak and momondo ota scrapes",**kwargs)
# Out:
# All AirlineScraper software packages loaded successfully!
# Initialing AirlineScraper class for airlineScrapers with instance data

# %% [markdown]
# ## Initialize the set of OTA URL for Scraping

# %%
#path = DATA_PATH
file = "airOTAInputURLs.json"
start_date = date.today()
end_date = start_date + timedelta(days=1)
airportCodefile = "airportUSACities.csv"
filePath=os.path.join(DATA_PATH, airportCodefile)

try:
    if start_date < date.today():
        raise ValueError("Start date must be greater than today: %s" % str(date.today()))
    if end_date <= start_date:
        raise ValueError("End date %s is invalid. It must be greater than Start Date: %s" % (str(end_date),str(start_date)))

    kwargs = {
        "startDate": start_date,
        "endDate" : end_date,
        'airportsFile' : airportCodefile,
        'codeColName' : 'airportCode',
#        'departAirportCode': ['LAX','NYC','BOS'],
        'arriveAirportCode': ['LAS'],
    }

    _otaURLfilePath, _ota_url_parameterized_list  = clsScraper.build_scrape_url_info(\
                                                        fileName=file,\
                                                        dirPath=DATA_PATH,\
#                                                         **scrape_crietia_dict,\
                                                        **kwargs\
                                                        )
    if _otaURLfilePath:
        print("Data in: %s" % _otaURLfilePath)
    if len(_ota_url_parameterized_list)>0:
        print("Completed parameterizing urls with %d instances." 
              % (len(_ota_url_parameterized_list)))

except Exception as err:
    _s_fn_id = "Class <WebScraper> Function <read_folder_csv_to_df>"
    print("[Error]"+_s_fn_id, err)
    print(traceback.format_exc())
# Out:
# Loaded 2 properties to begin scraping OTA data.
# ['LAX', 'NYC', 'BOS', 'ORL', 'MSY', 'HNL', 'CHI', 'AEX', 'SAT', 'AVL', 'MIA', 'LAX', 'SFO', 'WAS', 'PHX', 'HOU', 'PHL', 'DFW', 'SJC', 'AUS', 'JAX', 'CMH', 'IND', 'CLT', 'SEA', 'DEN', 'BNA', 'OKC', 'ELP', 'PDX', 'DTT', 'MEM', 'SDF', 'BWI', 'MKE', 'TUS', 'FAT', 'SAC', 'MCI', 'OAK'] ['LAS']
# Processing kayak.com ...
# Processing momondo.com ...
# Data in: /home/nuwan/workspace/rezgate/wrangler/data/tmp/AirlineScraper-build-scrape-url-list.csv
# Completed parameterizing urls with 80 instances.

# %% [markdown]
# ## Prepare folder & file structure

# %%
from datetime import datetime, timezone

#dirPath = None
dirPath=os.path.join(DATA_PATH, "itinerary/")
_search_dt = datetime.now()
_search_dt = _search_dt + (datetime.min - _search_dt) % timedelta(minutes=15)
kwargs = {'searchDateTime': _search_dt,
          'storageLocation': "local",   # values can be "local" or "AWS_S3"
         }
''' include the timezone '''
_search_dt = (_search_dt.replace(tzinfo=timezone.utc)).isoformat()

_current_search_data_dir = clsScraper.get_search_data_dir_path(dirPath, **kwargs)
print("Extracting data into %s for search datetime: %s" % (_current_search_data_dir,str(_search_dt)))
# Out:
# Extracting data into /home/nuwan/workspace/rezgate/wrangler/data/transport/airlines/scraper/itinerary/2022-9-19-16-0/ for search datetime: 2022-09-19T16:15:00+00:00

# %% [markdown]
# ## Scrape data into CSVs
# ___TODO:___ pause if internet connection times out; might be possible with airflow.

# %%
import pandas as pd

if _otaURLfilePath:
    urlDF = pd.read_csv(_otaURLfilePath, sep=",")
    _otaURLParamDictList = urlDF.to_dict('records')

_l_saved_files = clsScraper.scrape_url_info(
    otaURLlist =_otaURLParamDictList,
#    otaURLfile = None,
    searchDT = _search_dt,
    dirPath =_current_search_data_dir)
print("Scraping completed and data saved in %s!" % _current_search_data_dir)
# Out:
# loading parameterized urls from list 80 records
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-LAX/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-LAX/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-ORL/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-ORL/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-MSY/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-MSY/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-CHI/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-CHI/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-AEX/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-AEX/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-SAT/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-SAT/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-AVL/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-AVL/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-MIA/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-MIA/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-LAX/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-LAX/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-SFO/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-SFO/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-WAS/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-WAS/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-PHX/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-PHX/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-HOU/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-HOU/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-PHL/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-PHL/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-DFW/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-DFW/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-SJC/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-SJC/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-AUS/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-AUS/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-JAX/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-JAX/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-CMH/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-CMH/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-IND/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-IND/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-CLT/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-CLT/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-SEA/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-SEA/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-DEN/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-DEN/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-BNA/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-BNA/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-OKC/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-OKC/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-ELP/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-ELP/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-PDX/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-PDX/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-DTT/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-DTT/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-MEM/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-MEM/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-SDF/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-SDF/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-BWI/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-BWI/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-MKE/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-MKE/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-TUS/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-TUS/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-FAT/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-FAT/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-SAC/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-SAC/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-MCI/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-MCI/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.kayak.com/flights/LAS-OAK/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.kayak.com/flights/LAS-OAK/2022-09-19/1adults?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-LAX/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-LAX/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-NYC/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-NYC/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-BOS/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-BOS/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-ORL/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-ORL/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-MSY/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-MSY/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-HNL/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-HNL/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-CHI/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-CHI/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-AEX/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-AEX/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-SAT/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-SAT/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-AVL/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-AVL/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-MIA/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-MIA/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-LAX/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-LAX/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-SFO/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-SFO/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-WAS/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-WAS/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-PHX/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-PHX/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-HOU/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-HOU/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-PHL/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-PHL/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-DFW/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-DFW/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-SJC/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-SJC/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-AUS/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-AUS/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-JAX/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-JAX/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-CMH/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-CMH/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-IND/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-IND/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-CLT/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-CLT/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-SEA/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-SEA/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-DEN/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-DEN/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-BNA/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-BNA/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-OKC/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-OKC/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-ELP/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-ELP/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-PDX/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-PDX/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-DTT/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-DTT/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-MEM/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-MEM/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-SDF/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-SDF/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-BWI/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-BWI/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-MKE/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-MKE/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-TUS/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-TUS/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-FAT/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-FAT/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-SAC/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-SAC/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-MCI/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-MCI/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# [Error]function <_scrape_kayak_to_csv> No data received for https://www.momondo.com/flight-search/LAS-OAK/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/modules/ota/airlineScrapers.py", line 708, in _scrape_kayak_to_csv
#     raise ValueError("No data received for %s" % (url))
# ValueError: No data received for https://www.momondo.com/flight-search/LAS-OAK/2022-09-19?a&fs=cfc=1;bfc=1;transportation=transportation_plane
#
# Scraping completed and data saved in /home/nuwan/workspace/rezgate/wrangler/data/transport/airlines/scraper/itinerary/2022-9-19-16-0/!

# %% [markdown]
# ## Use Spark to Load Data into Database
#
# ### Declare sparkworkload class

# %%
import os
import sys
from datetime import datetime, date, timedelta

ROOT_DIR = "/home/nuwan/workspace/rezgate/wrangler/"
UTILS_PATH = os.path.join(ROOT_DIR, 'utils/')
sys.path.insert(1, UTILS_PATH)
import sparkWorkLoads as spark

if debug:
    import importlib
    spark = importlib.reload(spark)

kwargs = {
    "ROOT_DIR":ROOT_DIR,
}

clsSparkWL = spark.SparkWorkLoads(name="ota prices", **kwargs)
#_session = clsSparkWL.get_spark_session()
# Out:
# All packages in SparkWorkLoads loaded successfully!

# %% [markdown]
# ### Read CSV into spark dataframe

# %%
#dirPath = _current_search_data_dir
dirPath = "/home/nuwan/workspace/rezgate/wrangler/data/transport/airlines/scraper/itinerary/2022-9-19-22-30/"
_search_sdf = clsSparkWL.read_csv_to_sdf(filesPath=dirPath)
_search_sdf = _search_sdf.distinct()
print("Spark loaded %d rows" % _search_sdf.count())
# Out:
# [Error]Class <SparkWorkLoads> Function <read_folder_csv_to_sdf> No data files found in director: /home/nuwan/workspace/rezgate/wrangler/data/transport/airlines/scraper/itinerary/2022-9-19-22-30/
# Traceback (most recent call last):
#   File "/home/nuwan/workspace/rezgate/wrangler/utils/sparkWorkLoads.py", line 387, in read_csv_to_sdf
#     raise ValueError("No data files found in director: %s" % (filesPath))
# ValueError: No data files found in director: /home/nuwan/workspace/rezgate/wrangler/data/transport/airlines/scraper/itinerary/2022-9-19-22-30/
#
# Spark loaded 0 rows

# %% [markdown]
# ### Extract flight itinerary info

# %%
from pyspark.sql.functions import substring,lit,col, trim
from pyspark.sql.types import StringType,BooleanType,DateType,DecimalType,FloatType, IntegerType,LongType, ShortType, TimestampType

#_search_sdf=_search_sdf.withColumn("currency", lit("US$"))
#_search_sdf=_search_sdf.withColumn('room_rate', substring('room_rate', 4,10))

''' reset data types to match table '''
_search_sdf = _search_sdf.withColumn("booking_price",col("booking_price").cast(FloatType())) \
    .withColumn("search_dt",col("search_dt").cast(DateType()))
#    .withColumn("depart_time",col("depart_time").cast(TimestampType())) \
#    .withColumn("arrive_time",col("arrive_time").cast(TimestampType())) \
''' drop redundant columns '''
columns_to_drop = ['flight_times','flight_type','booking_rate','airline']
_search_sdf=_search_sdf.drop(*columns_to_drop)

_search_sdf.printSchema()
_search_sdf.show(n=2, vertical=True, truncate=False)
print("Split and Extraction complete!")
# Out:
# root
#  |-- search_dt: date (nullable = true)
#  |-- depart_port_code: string (nullable = true)
#  |-- arrive_port_code: string (nullable = true)
#  |-- num_stops: string (nullable = true)
#  |-- duration: string (nullable = true)
#  |-- num_passengers: integer (nullable = true)
#  |-- depart_time: timestamp (nullable = true)
#  |-- arrive_time: timestamp (nullable = true)
#  |-- booking_price: float (nullable = true)
#  |-- currency: string (nullable = true)
#
# -RECORD 0----------------------------------
#  search_dt        | 2022-09-20
#  depart_port_code | LAX
#  arrive_port_code | LAS
#  num_stops        | nonstop
#  duration         | 1h 09m  LAS &dash; LAX
#  num_passengers   | 1
#  depart_time      | 2022-09-19 09:21:00
#  arrive_time      | 2022-09-19 10:30:00
#  booking_price    | 629.0
#  currency         | US$
# -RECORD 1----------------------------------
#  search_dt        | 2022-09-20
#  depart_port_code | CMH
#  arrive_port_code | LAS
#  num_stops        | nonstop
#  duration         | 3h 56m  LAS &dash; CMH
#  num_passengers   | 1
#  depart_time      | 2022-09-19 23:54:00
#  arrive_time      | 2022-09-19 06:50:00
#  booking_price    | 354.0
#  currency         | US$
# only showing top 2 rows
#
# Split and Extraction complete!

# %% [markdown]
# ## Cleanup and Save data to table

# %%
import os
''' Get airport codes dictionary '''
airportCodefile = "airportUSACities.csv"
airportsPath = os.path.join(DATA_PATH,'airports/')
airports_sdf = clsSparkWL.read_csv_to_sdf(filesPath=airportsPath)
airports_sdf = airports_sdf.withColumn("airportCode", trim(airports_sdf.airportCode))

_search_sdf = _search_sdf.withColumn("arrive_port_code", trim(_search_sdf.arrive_port_code)) \
                        .withColumn("depart_port_code", trim(_search_sdf.depart_port_code))\

''' first do the departure codes and names '''
dep_airports_sdf = airports_sdf.selectExpr("city as depart_port_name", \
                                       "airportCode as depart_port_code", \
                                      )
''' Lookup & augment departure name '''
aug_depart_sdf = dep_airports_sdf.join(_search_sdf,"depart_port_code")

''' next do the same for arrival codes and names '''
arr_airports_sdf = airports_sdf.selectExpr("city as arrive_port_name", \
                                       "airportCode as arrive_port_code", \
                                      )
''' Lookup & augment arrival name '''
aug_arr_sdf = arr_airports_sdf.join(aug_depart_sdf,on="arrive_port_code")

# aug_arr_sdf = _search_sdf.join(arr_airports_sdf,
#                                     trim(arr_airports_sdf['arrive_port_code']) == trim(_search_sdf['arrive_port_code'])
#                        ,'inner')
#                                    ).select(_search_sdf['arrive_port_name'].alias('arrive_port_name')
#                    ,arr_airports_sdf['users_count'])

arr_airports_sdf.printSchema()
#destinations_sdf.show(n=2, vertical=True, truncate=False)
print("airports dictionary loarded!")

#aug_search_sdf = airports_sdf.join(_search_sdf,"arrive_port_code")
#aug_search_sdf.show(n=2, vertical=True, truncate=False)
print("Destination names augmented to dataframe!")
# Out:
# root
#  |-- arrive_port_name: string (nullable = true)
#  |-- arrive_port_code: string (nullable = true)
#
# airports dictionary loarded!
# Destination names augmented to dataframe!

# %%
arr_airports_sdf.show(n=2, vertical=True, truncate=False)
aug_arr_sdf.show(n=2, vertical=True, truncate=False)
# Out:
# -RECORD 0---------------------
#  arrive_port_name | Las Vegas
#  arrive_port_code | LAX
# -RECORD 1---------------------
#  arrive_port_name | New York
#  arrive_port_code | NYC
# only showing top 2 rows
#
# (0 rows)

# %% [markdown]
# ## Save cleaned SDF to Tmp File

# %%
_tmp_fname = clsSparkWL.save_sdf_to_csv(aug_depart_sdf)
print("%d rows saved to %s" % (aug_depart_sdf.count(), _tmp_fname))
# Out:
# 37 rows saved to /home/nuwan/workspace/rezgate/wrangler/data/tmp/save_sdf_to_csv.csv

# %% [markdown]
# ## Read CSV from Tmp and Save to DB Table

# %%
''' Save dataframe to table '''
_s_tbl_name = "ota_airline_routes"
_get_tmp_sdf = clsSparkWL.read_csv_to_sdf(filesPath=_tmp_fname)
_get_tmp_sdf.printSchema()
count = clsSparkWL.insert_sdf_into_table(save_sdf=_get_tmp_sdf, dbTable=_s_tbl_name)
print("%d Data saved to %s" % (count,_s_tbl_name))
# Out:
# root
#  |-- depart_port_code: string (nullable = true)
#  |-- depart_port_name: string (nullable = true)
#  |-- search_dt: timestamp (nullable = true)
#  |-- arrive_port_code: string (nullable = true)
#  |-- num_stops: string (nullable = true)
#  |-- duration: string (nullable = true)
#  |-- num_passengers: integer (nullable = true)
#  |-- depart_time: timestamp (nullable = true)
#  |-- arrive_time: timestamp (nullable = true)
#  |-- booking_price: double (nullable = true)
#  |-- currency: string (nullable = true)
#
# Wait a moment while we insert data int ota_airline_routes
# Save to ota_airline_routes complete!
# 37 Data saved to ota_airline_routes

# %% [markdown]
# ## Read data from table

# %%
_s_tbl_name = "ota_airline_routes"
data = clsSparkWL.get_data_from_table(dbTable=_s_tbl_name)
print("%d records loaded from %s" %(data.count(),_s_tbl_name))
data.select("*").distinct().sort("search_dt").show(3, vertical=True, truncate=False)
# Out:
# Wait a moment, retrieving data ...
# Loading complete!
# 37 records loaded from ota_airline_routes
# -RECORD 0--------------------------------------
#  uuid             | null
#  ota_name         | null
#  search_dt        | 2022-09-20 00:00:00
#  agent_name       | null
#  depart_port_name | Las Vegas
#  depart_port_code | LAX
#  arrive_port_name | null
#  arrive_port_code | LAS
#  depart_time      | 2022-09-19 19:43:00
#  arrive_time      | 2022-09-19 20:59:00
#  num_stops        | nonstop
#  duration         | 1h 16m  LAS &dash; LAX
#  cabin_type       | null
#  booking_price    | 389.0
#  currency         | US$
#  num_passengers   | 1
#  airline_name     | null
#  data_source      | null
#  data_owner       | null
#  created_dt       | 2022-09-19 21:16:43.476739
#  created_by       | postgres
#  created_proc     | Unknown
#  modified_dt      | null
#  modified_by      | null
#  modified_proc    | null
#  deactivate_dt    | null
# -RECORD 1--------------------------------------
#  uuid             | null
#  ota_name         | null
#  search_dt        | 2022-09-20 00:00:00
#  agent_name       | null
#  depart_port_name | Los Angeles
#  depart_port_code | LAX
#  arrive_port_name | null
#  arrive_port_code | LAS
#  depart_time      | 2022-09-19 19:43:00
#  arrive_time      | 2022-09-19 20:59:00
#  num_stops        | nonstop
#  duration         | 1h 16m  LAS &dash; LAX
#  cabin_type       | null
#  booking_price    | 359.0
#  currency         | US$
#  num_passengers   | 1
#  airline_name     | null
#  data_source      | null
#  data_owner       | null
#  created_dt       | 2022-09-19 21:16:43.476739
#  created_by       | postgres
#  created_proc     | Unknown
#  modified_dt      | null
#  modified_by      | null
#  modified_proc    | null
#  deactivate_dt    | null
# -RECORD 2--------------------------------------
#  uuid             | null
#  ota_name         | null
#  search_dt        | 2022-09-20 00:00:00
#  agent_name       | null
#  depart_port_name | Fresno
#  depart_port_code | FAT
#  arrive_port_name | null
#  arrive_port_code | LAS
#  depart_time      | 2022-09-19 07:05:00
#  arrive_time      | 2022-09-19 08:19:00
#  num_stops        | nonstop
#  duration         | 1h 14m  LAS &dash; FAT
#  cabin_type       | null
#  booking_price    | 309.0
#  currency         | US$
#  num_passengers   | 1
#  airline_name     | null
#  data_source      | null
#  data_owner       | null
#  created_dt       | 2022-09-19 21:16:43.476739
#  created_by       | postgres
#  created_proc     | Unknown
#  modified_dt      | null
#  modified_by      | null
#  modified_proc    | null
#  deactivate_dt    | null
# only showing top 3 rows

# %%
_tmp_sdf = data.select("*").distinct().sort("search_dt")
_tmp_fname = clsSparkWL.save_sdf_to_csv(_tmp_sdf, filesPath='/tmp/ota_prices.csv')
print(_tmp_fname)
# Out:
# [Stage 756:>                                                        (0 + 1) / 1]
# /tmp/ota_prices.csv

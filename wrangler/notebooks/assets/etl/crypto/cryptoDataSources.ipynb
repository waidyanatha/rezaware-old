# %% [markdown]
# # Document the Data Sources
# * [Coingecko python code](https://github.com/man-c/pycoingecko)

# %%
'''
    WARNING CONTROL to display or ignore all warnings
'''
import warnings; warnings.simplefilter('ignore')     #switch betweeb 'default' and 'ignore'
import traceback

''' Set debug flag to view extended error messages; else set it to False to turn off debugging mode '''
debug = True

# %% [markdown]
# ## Initialize classes

# %%
import os
import sys
import configparser
from datetime import datetime, date, timedelta

sys.path.insert(1,"/home/nuwan/workspace/rezaware/")
import rezaware as reza
from wrangler.modules.assets.etl import cryptoMCExtractor as crypto
# from utils.modules.etl.load import noSQLwls as nosql
from utils.modules.etl.load import sparkNoSQLwls as nosql

''' restart initiate classes '''
if debug:
    import importlib
    reza = importlib.reload(reza)
    crypto = importlib.reload(crypto)
    nosql = importlib.reload(nosql)

clsNoSQL = nosql.NoSQLWorkLoads(desc="get crypto macket capitalization data")
''' optional - if not specified class will use the default values '''
prop_kwargs = {"WRITE_TO_TMP":True,   # necessary to emulate the etl dag
              }
clsMC = crypto.CryptoMarkets(
    desc='get crypto macket capitalization data', **prop_kwargs)
print("\nClass initialization and load complete!")
# Out:
# All python packages in rezaware loaded successfully!
# All assets-module etl-packages in function-CryptoMarket imported successfully!
# All etl-module load-packages in function-mongodbwls imported successfully!
# mongodbwls Class initialization complete
# mongodbwls Class initialization complete
# CryptoMarket Class initialization complete
#
# Class initialization and load complete!

# %% [markdown]
# ## Transform & Load into Postgresql

# %%
_data_owner='coingecko'
_from_dt=date(2022,1,1)
_to_dt=date(2022,3,31)

_data = clsMC.trasnform_mcap(
    data_owner=_data_owner,
    from_date=_from_dt,
    to_date=_to_dt,
)
print(type(_data))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [138], in <cell line: 5>()
#       2 _from_dt=date(2022,4,1)
#       3 _to_dt=date(2022,6,30)
# ----> 5 _data = clsMC.trasnform_mcap(
#       6     data_owner=_data_owner,
#       7     from_date=_from_dt,
#       8     to_date=_to_dt,
#       9 )
#      10 print(type(_data))
#
# File ~/workspace/rezaware/wrangler/modules/assets/etl/cryptoMCExtractor.py:962, in CryptoMarkets.trasnform_mcap(self, data_owner, from_date, to_date, **kwargs)
#     955         tmp_df = pd.DataFrame()
#     956         tmp_df = clsNoSQL.read_documents(
#     957             as_type = __as_type__,
#     958             db_name = _source_db,
#     959             db_coll = _coll_name,
#     960             doc_find = {}
#     961         )
# --> 962         _hist_mcap_df = pd.concat([_hist_mcap_df,tmp_df])
#     963     self._data = _hist_mcap_df.drop_duplicates()
#     965 except Exception as err:
#
# KeyboardInterrupt:

# %%
_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1126940 entries, 0 to 90
# Data columns (total 10 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   _id          1126940 non-null  object
#  1   source       1126940 non-null  object
#  2   symbol       1126940 non-null  object
#  3   date         1126940 non-null  object
#  4   marketcap    1126940 non-null  float64
#  5   id           14 non-null       object
#  6   name         14 non-null       object
#  7   price        14 non-null       float64
#  8   totalvolume  14 non-null       float64
#  9   unit         14 non-null       object
# dtypes: float64(3), object(7)
# memory usage: 94.6+ MB

# %% [markdown]
# ## Extract Historic Marketcap

# %%
import time

_data_owner='coingecko'
kwargs = {}

# kwargs = {"ASSETS":[
#     {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bf0a5"
#     },
#     "source": "coingecko",
#     "name": "Bitcoin",
#     "symbol": "btc",
#     "lastupdated": {
#       "$date": "2022-11-30T19:43:19.855Z"
#     },
#     "asset.id": "bitcoin",
#     "asset.isactive": 0,
#     "asset.tokenaddress": '',
#     "asset.platforms": {},
#     "asset": {
#       "id": "bitcoin",
#       "isactive": 1.0,
#       "platforms": {},
#       "tokenaddress": ''
#     }
#   }]
#          }

_from_dt=date(2021,10,1)
_to_dt=date(2021,12,31)

_results=None
_results, _failed = clsMC.extract_historic_mcap(
    data_owner=_data_owner,
    from_date = _from_dt,
    to_date = _to_dt,
    **kwargs,
)
if _results is None:
    print("No results but process completed")
else:
    print("Process completed with %d historic extractions" %len(_results))
# Out:
# Now processing COINGECKO from 2021-10-01 to 2021-12-31
# Total 91 documents, successful insert count = 0 & modify count = 91
# Total 91 documents, successful insert count = 0 & modify count = 91
# Total 91 documents, successful insert count = 0 & modify count = 91
# Total 91 documents, successful insert count = 0 & modify count = 91
# Total 86 documents, successful insert count = 0 & modify count = 86
# Total 91 documents, successful insert count = 0 & modify count = 91
# Total 91 documents, successful insert count = 0 & modify count = 91
# Total 91 documents, successful insert count = 0 & modify count = 91

# %% [markdown]
# ## Read catalog data
# * Distinct API categories: "asset.metadata", "historic.prices", "latest.prices"

# %%
from datetime import datetime
from bson.json_util import dumps

__now_dt__ = str(datetime.utcnow().isoformat())
__as_type__ = 'dict'
__database__ = "tip-asset-metadata"
__collection__ = "coingecko.asset.list"
__find__ = {"source":
            {"$regex":'coin'},
            "symbol":{"$in":['realt-s-10604-somerset-ave-detroit-mi', 'realt-s-10612-somerset-ave-detroit-mi', 'realt-s-10617-hathaway-ave-cleveland-oh', 'realt-s-11078-wayburn-st-detroit-mi', 'realt-s-11300-roxbury-st-detroit-mi', 'realt-s-11653-nottingham-rd-detroit-mi', 'realt-s-12334-lansdowne-street-detroit-mi', 'realt-s-1244-s.avers-st-chicago-il', 'realt-s-12866-lauder-st-detroit-mi', 'realt-s-13045-wade-st-detroit-mi', 'realt-s-13114-glenfield-ave-detroit-mi', 'realt-s-14078-carlisle-st-detroit-mi', 'realt-s-14231-strathmoor-st-detroit-mi', 'realt-s-14319-rosemary-st-detroit-mi', 'realt-s-14882-troester-st-detroit-mi', 'realt-s-15039-ward-ave-detroit-mi', 'realt-s-1542-s.ridgeway-ave-chicago-il', 'realt-s-15777-ardmore-st-detroit-mi', 'realt-s-15860-hartwell-st-detroit-mi', 'realt-s-17500-evergreen-rd-detroit-mi', 'realt-s-17809-charest-st-detroit-mi', 'realt-s-17813-bradford-st-detroit-mi', 'realt-s-18983-alcoy-ave-detroit-mi', 'realt-s-19136-tracey-st-detroit-mi', 'realt-s-19200-strasburg-st-detroit-mi', 'realt-s-19201-westphalia-st-detroit-mi', 'realt-s-20200-lesure-st-detroit-mi', 'realt-s-4680-buckingham-ave-detroit-mi', 'realt-s-581-587-jefferson-ave-rochester-ny', 'realt-s-5942-audubon-rd-detroit-mi', 'realt-s-9165-kensington-ave-detroit-mi', 'realt-s-9336-patton-st-detroit-mi', 'aammbptwbtcweth', 'adai', 'amusdc', 'amusdt', 'amwbtc', 'amweth', 'amwmatic', 'arai', 'aren', 'aren', 'asnx', 'asnx', 'asusd', 'asusd', 'atusd', 'atusd', 'auni', 'ausdc', 'ausdc', 'aera', 'aero-v2', 'arnx', 'aet', 'atyne', 'aero', 'ae', 'aeth', 'ath', 'aeur', 'azr', 'afen', 'afnty', 'fyn', 'afin', 'afk', 'afrep', 'afr', 'algf', 'alnr', 'xalnr', 'mara', 'apex', 'aqua', 'anft', 'ath', 'atmup']},
            'asset.isactive':{"$gte":1.0},
#             "asset.isactive":{"$gt" : 0}
           }

clsNoSQL.connect={'DBAUTHSOURCE':__database__}
_data = clsNoSQL.read_documents(
    as_type=__as_type__,
    db_name = __database__,
    db_coll=__collection__,
    doc_find=__find__
)
print(dumps(_data, indent=2))
# Out:
# [
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beaa8"
#     },
#     "source": "coingecko",
#     "name": "RealT - 10604 Somerset Ave, Detroit, MI 48224",
#     "symbol": "realt-s-10604-somerset-ave-detroit-mi",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "10604-somerset",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0x8626b38267e4fc0d8c92e0bb86f97acab3f6aa05",
#       "xdai": "0x8626b38267e4fc0d8c92e0bb86f97acab3f6aa05"
#     },
#     "asset": {
#       "id": "10604-somerset",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beaa9"
#     },
#     "source": "coingecko",
#     "name": "RealT - 10612 Somerset Ave, Detroit, MI 48224",
#     "symbol": "realt-s-10612-somerset-ave-detroit-mi",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "10612-somerset",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0xd1c15cebfdcd16f00d91666bf64c8b66cbf5e9b5",
#       "xdai": "0xd1c15cebfdcd16f00d91666bf64c8b66cbf5e9b5"
#     },
#     "asset": {
#       "id": "10612-somerset",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beaaa"
#     },
#     "source": "coingecko",
#     "name": "RealT - 10617 Hathaway Ave, Cleveland, OH 44108",
#     "symbol": "realt-s-10617-hathaway-ave-cleveland-oh",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "10617-hathaway",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0x06d0e5aee443093ac5635b709c8a01342e59df19",
#       "xdai": "0x06d0e5aee443093ac5635b709c8a01342e59df19"
#     },
#     "asset": {
#       "id": "10617-hathaway",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beaad"
#     },
#     "source": "coingecko",
#     "name": "RealT - 11078 Wayburn St, Detroit, MI 48224",
#     "symbol": "realt-s-11078-wayburn-st-detroit-mi",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "11078-wayburn",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "xdai": "0xb8403b7730368942a5bfe5aac04a31b44015b1cc",
#       "ethereum": "0xb8403b7730368942a5bfe5aac04a31b44015b1cc"
#     },
#     "asset": {
#       "id": "11078-wayburn",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beaae"
#     },
#     "source": "coingecko",
#     "name": "RealT - 11300 Roxbury St, Detroit, MI 48224",
#     "symbol": "realt-s-11300-roxbury-st-detroit-mi",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "11300-roxbury",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "xdai": "0x9b5b4886033b4abc5eb0552fff7c15a67c3c47c7",
#       "ethereum": "0x9b5b4886033b4abc5eb0552fff7c15a67c3c47c7"
#     },
#     "asset": {
#       "id": "11300-roxbury",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beaaf"
#     },
#     "source": "coingecko",
#     "name": "RealT - 11653 Nottingham Rd, Detroit, MI 48224",
#     "symbol": "realt-s-11653-nottingham-rd-detroit-mi",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "11653-nottingham",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "xdai": "0x31820af2d43c08bd82bd94b08974062482bd98d3",
#       "ethereum": "0x31820af2d43c08bd82bd94b08974062482bd98d3"
#     },
#     "asset": {
#       "id": "11653-nottingham",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beab1"
#     },
#     "source": "coingecko",
#     "name": "RealT - 12334 Lansdowne Street, Detroit, MI 48224",
#     "symbol": "realt-s-12334-lansdowne-street-detroit-mi",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "12334-lansdowne",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0xee2f2212a64ec3f6bc0f7580e10c53cb38b57508",
#       "xdai": "0xee2f2212a64ec3f6bc0f7580e10c53cb38b57508"
#     },
#     "asset": {
#       "id": "12334-lansdowne",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beab3"
#     },
#     "source": "coingecko",
#     "name": "RealT - 1244 S. Avers St, Chicago, IL 60623",
#     "symbol": "realt-s-1244-s.avers-st-chicago-il",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "1244-s-avers",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0x94fa7f8cb8453ad57cd133363b3012044647078c",
#       "xdai": "0x94fa7f8cb8453ad57cd133363b3012044647078c"
#     },
#     "asset": {
#       "id": "1244-s-avers",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beab4"
#     },
#     "source": "coingecko",
#     "name": "RealT - 12866 Lauder St, Detroit, MI 48227",
#     "symbol": "realt-s-12866-lauder-st-detroit-mi",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "12866-lauder",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "xdai": "0xb5dd2b6e0a0422e069e1d2cc3ed16533488a05e3",
#       "ethereum": "0xb5dd2b6e0a0422e069e1d2cc3ed16533488a05e3"
#     },
#     "asset": {
#       "id": "12866-lauder",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beab6"
#     },
#     "source": "coingecko",
#     "name": "RealT - 13045 Wade St, Detroit, MI 48213",
#     "symbol": "realt-s-13045-wade-st-detroit-mi",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "13045-wade",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "xdai": "0x5600e25b4f24c63afa655c3bd96e3c178b654fa1",
#       "ethereum": "0x5600e25b4f24c63afa655c3bd96e3c178b654fa1"
#     },
#     "asset": {
#       "id": "13045-wade",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beab7"
#     },
#     "source": "coingecko",
#     "name": "RealT - 13114 Glenfield Ave, Detroit, MI 48213",
#     "symbol": "realt-s-13114-glenfield-ave-detroit-mi",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "13114-glenfield",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0x9f923653a19537b5a1b003854a1920fe67a8ffeb",
#       "xdai": "0x9f923653a19537b5a1b003854a1920fe67a8ffeb"
#     },
#     "asset": {
#       "id": "13114-glenfield",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beaba"
#     },
#     "source": "coingecko",
#     "name": "RealT - 14078 Carlisle St, Detroit, MI 48205",
#     "symbol": "realt-s-14078-carlisle-st-detroit-mi",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "14078-carlisle",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0x315699f1ba88383cff2f2f30fcad187adb2e4d72",
#       "xdai": "0x315699f1ba88383cff2f2f30fcad187adb2e4d72"
#     },
#     "asset": {
#       "id": "14078-carlisle",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beabb"
#     },
#     "source": "coingecko",
#     "name": "RealT - 14231 Strathmoor St, Detroit, MI 48227",
#     "symbol": "realt-s-14231-strathmoor-st-detroit-mi",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "14231-strathmoor",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "xdai": "0x9528a7402c0fe85b817aa6e106eafa03a02924c4",
#       "ethereum": "0x9528a7402c0fe85b817aa6e106eafa03a02924c4"
#     },
#     "asset": {
#       "id": "14231-strathmoor",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beabc"
#     },
#     "source": "coingecko",
#     "name": "RealT - 14319 Rosemary St, Detroit, MI 48213",
#     "symbol": "realt-s-14319-rosemary-st-detroit-mi",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "14319-rosemary",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0x41599149f1b52035392402f9e311b1edb0c9f699",
#       "xdai": "0x41599149f1b52035392402f9e311b1edb0c9f699"
#     },
#     "asset": {
#       "id": "14319-rosemary",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beabd"
#     },
#     "source": "coingecko",
#     "name": "RealT - 14882 Troester St, Detroit, MI 48205",
#     "symbol": "realt-s-14882-troester-st-detroit-mi",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "14882-troester",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "xdai": "0xff1b4d71ae12538d86777a954b136cf723fccefd",
#       "ethereum": "0x31aa5fa895fd186fde12347a6fcaf540875b6434"
#     },
#     "asset": {
#       "id": "14882-troester",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beabe"
#     },
#     "source": "coingecko",
#     "name": "RealT - 15039 Ward Ave, Detroit, MI 48227",
#     "symbol": "realt-s-15039-ward-ave-detroit-mi",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "15039-ward",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0x7e95b310724334ff74537dc08bfd3377d25e65ce",
#       "xdai": "0x7e95b310724334ff74537dc08bfd3377d25e65ce"
#     },
#     "asset": {
#       "id": "15039-ward",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beabf"
#     },
#     "source": "coingecko",
#     "name": "RealT - 1542 S Ridgeway Ave, Chicago, IL 60623",
#     "symbol": "realt-s-1542-s.ridgeway-ave-chicago-il",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "1542-s-ridgeway",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "xdai": "0x69d1b42b20f3ded07bec322253d0140b04cbb6f5",
#       "ethereum": "0x69d1b42b20f3ded07bec322253d0140b04cbb6f5"
#     },
#     "asset": {
#       "id": "1542-s-ridgeway",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beac0"
#     },
#     "source": "coingecko",
#     "name": "RealT - 15777 Ardmore St, Detroit, MI 48227",
#     "symbol": "realt-s-15777-ardmore-st-detroit-mi",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "15777-ardmore",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0xfe17c3c0b6f38cf3bd8ba872bee7a18ab16b43fb",
#       "xdai": "0xfe17c3c0b6f38cf3bd8ba872bee7a18ab16b43fb"
#     },
#     "asset": {
#       "id": "15777-ardmore",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beac1"
#     },
#     "source": "coingecko",
#     "name": "RealT - 15860 Hartwell St, Detroit, MI 48227",
#     "symbol": "realt-s-15860-hartwell-st-detroit-mi",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "15860-hartwell",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "xdai": "0xa9f30c907321718e655b74463ca665b690b78894",
#       "ethereum": "0xa9f30c907321718e655b74463ca665b690b78894"
#     },
#     "asset": {
#       "id": "15860-hartwell",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beac3"
#     },
#     "source": "coingecko",
#     "name": "RealT - 17500 Evergreen Rd, Detroit, MI 48219",
#     "symbol": "realt-s-17500-evergreen-rd-detroit-mi",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "17500-evergreen",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "xdai": "0x1fdb4015fd5e031c5641752c1e03b973ad5ea168",
#       "ethereum": "0x1fdb4015fd5e031c5641752c1e03b973ad5ea168"
#     },
#     "asset": {
#       "id": "17500-evergreen",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beac4"
#     },
#     "source": "coingecko",
#     "name": "RealT - 17809 Charest St, Detroit, MI 48212",
#     "symbol": "realt-s-17809-charest-st-detroit-mi",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "17809-charest",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "xdai": "0x31aa5fa895fd186fde12347a6fcaf540875b6434",
#       "ethereum": "0xba07997f594a52df179620284b52b50a4e66227d"
#     },
#     "asset": {
#       "id": "17809-charest",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beac5"
#     },
#     "source": "coingecko",
#     "name": "RealT - 17813 Bradford St, Detroit, MI 48205",
#     "symbol": "realt-s-17813-bradford-st-detroit-mi",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "17813-bradford",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0x499a6c19f5537dd6005e2b5c6e1263103f558ba4",
#       "xdai": "0x499a6c19f5537dd6005e2b5c6e1263103f558ba4"
#     },
#     "asset": {
#       "id": "17813-bradford",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beac7"
#     },
#     "source": "coingecko",
#     "name": "RealT - 18983 Alcoy Ave, Detroit, MI 48205",
#     "symbol": "realt-s-18983-alcoy-ave-detroit-mi",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "18983-alcoy",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "xdai": "0xad91999f534f4075b00ba4231c018e57bdebb342",
#       "ethereum": "0xad91999f534f4075b00ba4231c018e57bdebb342"
#     },
#     "asset": {
#       "id": "18983-alcoy",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beac8"
#     },
#     "source": "coingecko",
#     "name": "RealT - 19136 Tracey St, Detroit MI 48235",
#     "symbol": "realt-s-19136-tracey-st-detroit-mi",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "19136-tracey",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0x33722ea778df197f1b7b1cf0b124d7a962181d65",
#       "xdai": "0x33722ea778df197f1b7b1cf0b124d7a962181d65"
#     },
#     "asset": {
#       "id": "19136-tracey",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beac9"
#     },
#     "source": "coingecko",
#     "name": "RealT - 19200 Strasburg St, Detroit, MI 48205",
#     "symbol": "realt-s-19200-strasburg-st-detroit-mi",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "19200-strasburg",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "xdai": "0x211618fa0934910666f2c2731101f5a3ac013fd8",
#       "ethereum": "0x211618fa0934910666f2c2731101f5a3ac013fd8"
#     },
#     "asset": {
#       "id": "19200-strasburg",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beaca"
#     },
#     "source": "coingecko",
#     "name": "RealT - 19201 Westphalia St, Detroit, MI 48205",
#     "symbol": "realt-s-19201-westphalia-st-detroit-mi",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "19201-westphalia",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0x830b0e9a5ecf36d0a886d21e1c20043cd2d16515",
#       "xdai": "0x830b0e9a5ecf36d0a886d21e1c20043cd2d16515"
#     },
#     "asset": {
#       "id": "19201-westphalia",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beafa"
#     },
#     "source": "coingecko",
#     "name": "RealT - 20200 Lesure St, Detroit, MI 48235",
#     "symbol": "realt-s-20200-lesure-st-detroit-mi",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "20200-lesure",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0xeedc2f5f4d1226759b1acf9efa23a99661de6663",
#       "xdai": "0xeedc2f5f4d1226759b1acf9efa23a99661de6663"
#     },
#     "asset": {
#       "id": "20200-lesure",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beb57"
#     },
#     "source": "coingecko",
#     "name": "RealT - 4680 Buckingham Ave, Detroit, MI 48224",
#     "symbol": "realt-s-4680-buckingham-ave-detroit-mi",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "4680-buckingham",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0xefe82d6baf0db71f92889eb9d00721bd49121316",
#       "xdai": "0xefe82d6baf0db71f92889eb9d00721bd49121316"
#     },
#     "asset": {
#       "id": "4680-buckingham",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beb63"
#     },
#     "source": "coingecko",
#     "name": "RealT - 581-587 Jefferson Ave, Rochester, NY 14611",
#     "symbol": "realt-s-581-587-jefferson-ave-rochester-ny",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "581-587-jefferson",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0xa29ae272bc89e5f315b2793925f700045f845d82",
#       "xdai": "0xa29ae272bc89e5f315b2793925f700045f845d82"
#     },
#     "asset": {
#       "id": "581-587-jefferson",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beb64"
#     },
#     "source": "coingecko",
#     "name": "RealT - 5942 Audubon Rd, Detroit, MI 48224",
#     "symbol": "realt-s-5942-audubon-rd-detroit-mi",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "5942-audubon",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0x6db6d540f5614e6bab7475af3f430f46a0b083e2",
#       "xdai": "0x6db6d540f5614e6bab7475af3f430f46a0b083e2"
#     },
#     "asset": {
#       "id": "5942-audubon",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beb70"
#     },
#     "source": "coingecko",
#     "name": "RealT - 9165 Kensington Ave, Detroit, MI 48224",
#     "symbol": "realt-s-9165-kensington-ave-detroit-mi",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "9165-kensington",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0x3c56d5e887d8fa7ae1ba65bf7eccc25ec09eaf18",
#       "xdai": "0x3c56d5e887d8fa7ae1ba65bf7eccc25ec09eaf18"
#     },
#     "asset": {
#       "id": "9165-kensington",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beb71"
#     },
#     "source": "coingecko",
#     "name": "RealT - 9336 Patton St, Detroit, MI 48228",
#     "symbol": "realt-s-9336-patton-st-detroit-mi",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "9336-patton",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0x23684569c0636c9aea246551879d457d0a0e6f58",
#       "xdai": "0x23684569c0636c9aea246551879d457d0a0e6f58"
#     },
#     "asset": {
#       "id": "9336-patton",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beb7c"
#     },
#     "source": "coingecko",
#     "name": "Aave AMM BptWBTCWETH",
#     "symbol": "aammbptwbtcweth",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "aave-amm-bptwbtcweth",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0x358bd0d980e031e23eba9aa793926857703783bd"
#     },
#     "asset": {
#       "id": "aave-amm-bptwbtcweth",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beb97"
#     },
#     "source": "coingecko",
#     "name": "Aave DAI",
#     "symbol": "adai",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "aave-dai",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0x028171bca77440897b824ca71d1c56cac55b68a3",
#       "fantom": "0x82e64f49ed5ec1bc6e43dad4fc8af9bb3a2312ee",
#       "arbitrum-one": "0x82e64f49ed5ec1bc6e43dad4fc8af9bb3a2312ee",
#       "harmony-shard-0": "0x82e64f49ed5ec1bc6e43dad4fc8af9bb3a2312ee",
#       "avalanche": "0x82e64f49ed5ec1bc6e43dad4fc8af9bb3a2312ee",
#       "polygon-pos": "0x82e64f49ed5ec1bc6e43dad4fc8af9bb3a2312ee",
#       "optimistic-ethereum": "0x82e64f49ed5ec1bc6e43dad4fc8af9bb3a2312ee"
#     },
#     "asset": {
#       "id": "aave-dai",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beb98"
#     },
#     "source": "coingecko",
#     "name": "Aave DAI v1",
#     "symbol": "adai",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "aave-dai-v1",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0xfc1e690f61efd961294b3e1ce3313fbd8aa4f85d"
#     },
#     "asset": {
#       "id": "aave-dai-v1",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beb9b"
#     },
#     "source": "coingecko",
#     "name": "Aave ETH v1",
#     "symbol": "aeth",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "aave-eth-v1",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0x3a3a65aab0dd2a17e3f1947ba16138cd37d08c04"
#     },
#     "asset": {
#       "id": "aave-eth-v1",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bebad"
#     },
#     "source": "coingecko",
#     "name": "Aave Polygon USDC",
#     "symbol": "amusdc",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "aave-polygon-usdc",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "polygon-pos": "0x1a13f4ca1d028320a707d99520abfefca3998b7f"
#     },
#     "asset": {
#       "id": "aave-polygon-usdc",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bebae"
#     },
#     "source": "coingecko",
#     "name": "Aave Polygon USDT",
#     "symbol": "amusdt",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "aave-polygon-usdt",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "polygon-pos": "0x60d55f02a771d515e077c9c2403a1ef324885cec"
#     },
#     "asset": {
#       "id": "aave-polygon-usdt",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bebaf"
#     },
#     "source": "coingecko",
#     "name": "Aave Polygon WBTC",
#     "symbol": "amwbtc",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "aave-polygon-wbtc",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "polygon-pos": "0x5c2ed810328349100a66b82b78a1791b101c9d61"
#     },
#     "asset": {
#       "id": "aave-polygon-wbtc",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bebb0"
#     },
#     "source": "coingecko",
#     "name": "Aave Polygon WETH",
#     "symbol": "amweth",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "aave-polygon-weth",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "polygon-pos": "0x28424507fefb6f7f8e9d3860f56504e4e5f5f390"
#     },
#     "asset": {
#       "id": "aave-polygon-weth",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bebb1"
#     },
#     "source": "coingecko",
#     "name": "Aave Polygon WMATIC",
#     "symbol": "amwmatic",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "aave-polygon-wmatic",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "polygon-pos": "0x8df3aad3a84da6b69a4da8aec3ea40d9091b2ac4"
#     },
#     "asset": {
#       "id": "aave-polygon-wmatic",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bebb2"
#     },
#     "source": "coingecko",
#     "name": "Aave RAI",
#     "symbol": "arai",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "aave-rai",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0xc9bc48c72154ef3e5425641a3c747242112a46af"
#     },
#     "asset": {
#       "id": "aave-rai",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bebb3"
#     },
#     "source": "coingecko",
#     "name": "Aave REN",
#     "symbol": "aren",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.348Z"
#     },
#     "asset.id": "aave-ren",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0xcc12abe4ff81c9378d670de1b57f8e0dd228d77a"
#     },
#     "asset": {
#       "id": "aave-ren",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bebb4"
#     },
#     "source": "coingecko",
#     "name": "Aave REN v1",
#     "symbol": "aren",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.349Z"
#     },
#     "asset.id": "aave-ren-v1",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0x69948cc03f478b95283f7dbf1ce764d0fc7ec54c"
#     },
#     "asset": {
#       "id": "aave-ren-v1",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bebb5"
#     },
#     "source": "coingecko",
#     "name": "Aave SNX",
#     "symbol": "asnx",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.349Z"
#     },
#     "asset.id": "aave-snx",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0x35f6b052c598d933d69a4eec4d04c73a191fe6c2"
#     },
#     "asset": {
#       "id": "aave-snx",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bebb6"
#     },
#     "source": "coingecko",
#     "name": "Aave SNX v1",
#     "symbol": "asnx",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.349Z"
#     },
#     "asset.id": "aave-snx-v1",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0x328c4c80bc7aca0834db37e6600a6c49e12da4de"
#     },
#     "asset": {
#       "id": "aave-snx-v1",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bebb7"
#     },
#     "source": "coingecko",
#     "name": "Aave SUSD",
#     "symbol": "asusd",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.349Z"
#     },
#     "asset.id": "aave-susd",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0x6c5024cd4f8a59110119c56f8933403a539555eb",
#       "optimistic-ethereum": "0x6d80113e533a2c0fe82eabd35f1875dcea89ea97"
#     },
#     "asset": {
#       "id": "aave-susd",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bebb8"
#     },
#     "source": "coingecko",
#     "name": "Aave SUSD v1",
#     "symbol": "asusd",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.349Z"
#     },
#     "asset.id": "aave-susd-v1",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0x625ae63000f46200499120b906716420bd059240"
#     },
#     "asset": {
#       "id": "aave-susd-v1",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bebb9"
#     },
#     "source": "coingecko",
#     "name": "Aave TUSD",
#     "symbol": "atusd",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.349Z"
#     },
#     "asset.id": "aave-tusd",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0x101cc05f4a51c0319f570d5e146a8c625198e636"
#     },
#     "asset": {
#       "id": "aave-tusd",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bebba"
#     },
#     "source": "coingecko",
#     "name": "Aave TUSD v1",
#     "symbol": "atusd",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.349Z"
#     },
#     "asset.id": "aave-tusd-v1",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0x4da9b813057d04baef4e5800e36083717b4a0341"
#     },
#     "asset": {
#       "id": "aave-tusd-v1",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bebbb"
#     },
#     "source": "coingecko",
#     "name": "Aave UNI",
#     "symbol": "auni",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.349Z"
#     },
#     "asset.id": "aave-uni",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0xb9d7cb55f463405cdfbe4e90a6d2df01c2b92bf1"
#     },
#     "asset": {
#       "id": "aave-uni",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bebbc"
#     },
#     "source": "coingecko",
#     "name": "Aave USDC",
#     "symbol": "ausdc",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.349Z"
#     },
#     "asset.id": "aave-usdc",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0xbcca60bb61934080951369a648fb03df4f96263c",
#       "arbitrum-one": "0x625e7708f30ca75bfd92586e17077590c60eb4cd",
#       "harmony-shard-0": "0x625e7708f30ca75bfd92586e17077590c60eb4cd",
#       "avalanche": "0x625e7708f30ca75bfd92586e17077590c60eb4cd",
#       "fantom": "0x625e7708f30ca75bfd92586e17077590c60eb4cd",
#       "polygon-pos": "0x625e7708f30ca75bfd92586e17077590c60eb4cd",
#       "optimistic-ethereum": "0x625e7708f30ca75bfd92586e17077590c60eb4cd"
#     },
#     "asset": {
#       "id": "aave-usdc",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bebbd"
#     },
#     "source": "coingecko",
#     "name": "Aave USDC v1",
#     "symbol": "ausdc",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.349Z"
#     },
#     "asset.id": "aave-usdc-v1",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0x9ba00d6856a4edf4665bca2c2309936572473b7e"
#     },
#     "asset": {
#       "id": "aave-usdc-v1",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bec1e"
#     },
#     "source": "coingecko",
#     "name": "Aerarium Fi",
#     "symbol": "aera",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.349Z"
#     },
#     "asset.id": "aerarium-fi",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "metis-andromeda": "0xfe540d6dbad8c68928778aaf2be828efa4b44fa2"
#     },
#     "asset": {
#       "id": "aerarium-fi",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bec21"
#     },
#     "source": "coingecko",
#     "name": "Aerochain Coin V2",
#     "symbol": "aero-v2",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.349Z"
#     },
#     "asset.id": "aerochain",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "binance-smart-chain": "0x6b992d72bda6a5463aefa01e4790ea3767af91c2"
#     },
#     "asset": {
#       "id": "aerochain",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bec22"
#     },
#     "source": "coingecko",
#     "name": "Aeron",
#     "symbol": "arnx",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.349Z"
#     },
#     "asset.id": "aeron",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0x0c37bcf456bc661c14d596683325623076d7e283"
#     },
#     "asset": {
#       "id": "aeron",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bec23"
#     },
#     "source": "coingecko",
#     "name": "AEROTOKEN",
#     "symbol": "aet",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.349Z"
#     },
#     "asset.id": "aerotoken",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0x8c9e4cf756b9d01d791b95bc2d0913ef2bf03784"
#     },
#     "asset": {
#       "id": "aerotoken",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bec24"
#     },
#     "source": "coingecko",
#     "name": "Aerotyne",
#     "symbol": "atyne",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.349Z"
#     },
#     "asset.id": "aerotyne",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "binance-smart-chain": "0x71e1611075800e89a460463fcdfba3d0fea8c01d"
#     },
#     "asset": {
#       "id": "aerotyne",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bec25"
#     },
#     "source": "coingecko",
#     "name": "Aerovek Aviation",
#     "symbol": "aero",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.349Z"
#     },
#     "asset.id": "aerovek-aviation",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "elrond": "AERO-458bbf"
#     },
#     "asset": {
#       "id": "aerovek-aviation",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bec26"
#     },
#     "source": "coingecko",
#     "name": "Aeternity",
#     "symbol": "ae",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.349Z"
#     },
#     "asset.id": "aeternity",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0x5ca9a71b1d01849c0a95490cc00559717fcf0d1d"
#     },
#     "asset": {
#       "id": "aeternity",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bec27"
#     },
#     "source": "coingecko",
#     "name": "Aetherius",
#     "symbol": "aeth",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.349Z"
#     },
#     "asset.id": "aetherius",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "binance-smart-chain": "0x5a3b6f18dc79d50ab208af2fcd61d10bf7e4896f"
#     },
#     "asset": {
#       "id": "aetherius",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bec28"
#     },
#     "source": "coingecko",
#     "name": "AetherV2",
#     "symbol": "ath",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.349Z"
#     },
#     "asset.id": "aetherv2",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "binance-smart-chain": "0x6d3a0fb0070ea61f901ebc0b675c30450acac737"
#     },
#     "asset": {
#       "id": "aetherv2",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bec29"
#     },
#     "source": "coingecko",
#     "name": "AEUR",
#     "symbol": "aeur",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.349Z"
#     },
#     "asset.id": "aeur",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ardor": ""
#     },
#     "asset": {
#       "id": "aeur",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bec2a"
#     },
#     "source": "coingecko",
#     "name": "Azzure",
#     "symbol": "azr",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.349Z"
#     },
#     "asset.id": "aezora",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "qtum": ""
#     },
#     "asset": {
#       "id": "aezora",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bec2b"
#     },
#     "source": "coingecko",
#     "name": "AFEN Blockchain",
#     "symbol": "afen",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.349Z"
#     },
#     "asset.id": "afen-blockchain",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "binance-smart-chain": "0xd0840d5f67206f865aee7cce075bd4484cd3cc81"
#     },
#     "asset": {
#       "id": "afen-blockchain",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bec2c"
#     },
#     "source": "coingecko",
#     "name": "Affinity",
#     "symbol": "afnty",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.349Z"
#     },
#     "asset.id": "affinity",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "binance-smart-chain": "0xface67c5ce2bb48c29779b0dede5360cc9ef5fd5"
#     },
#     "asset": {
#       "id": "affinity",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bec2d"
#     },
#     "source": "coingecko",
#     "name": "Affyn",
#     "symbol": "fyn",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.349Z"
#     },
#     "asset.id": "affyn",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "polygon-pos": "0x3b56a704c01d650147ade2b8cee594066b3f9421"
#     },
#     "asset": {
#       "id": "affyn",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bec2e"
#     },
#     "source": "coingecko",
#     "name": "Asian Fintech",
#     "symbol": "afin",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.349Z"
#     },
#     "asset.id": "afin-coin",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0xee9e5eff401ee921b138490d00ca8d1f13f67a72",
#       "binance-smart-chain": "0xb955b4cab9aa3b49e23aeb5204ebc5ff6678e86d"
#     },
#     "asset": {
#       "id": "afin-coin",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bec2f"
#     },
#     "source": "coingecko",
#     "name": "AFKDAO",
#     "symbol": "afk",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.349Z"
#     },
#     "asset.id": "afkdao",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {},
#     "asset": {
#       "id": "afkdao",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bec30"
#     },
#     "source": "coingecko",
#     "name": "Afrep",
#     "symbol": "afrep",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.349Z"
#     },
#     "asset.id": "afrep",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "binance-smart-chain": "0x3d49d6f854620057fd4408b8daa8c0b15c48fce0"
#     },
#     "asset": {
#       "id": "afrep",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bec31"
#     },
#     "source": "coingecko",
#     "name": "Afreum",
#     "symbol": "afr",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.349Z"
#     },
#     "asset.id": "afreum",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "stellar": "GBX6YI45VU7WNAAKA3RBFDR3I3UKNFHTJPQ5F6KOOKSGYIAM4TRQN54W"
#     },
#     "asset": {
#       "id": "afreum",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bec98"
#     },
#     "source": "coingecko",
#     "name": "AlgoFund",
#     "symbol": "algf",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.349Z"
#     },
#     "asset.id": "algofund",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "algorand": "463554836"
#     },
#     "asset": {
#       "id": "algofund",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899becc4"
#     },
#     "source": "coingecko",
#     "name": "All Time High",
#     "symbol": "ath",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.349Z"
#     },
#     "asset.id": "all-time-high",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0xaa3573cc3761133375b0c504146b93f6827f945a"
#     },
#     "asset": {
#       "id": "all-time-high",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899becc9"
#     },
#     "source": "coingecko",
#     "name": "Alnair Finance",
#     "symbol": "alnr",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.349Z"
#     },
#     "asset.id": "alnair-finance",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {},
#     "asset": {
#       "id": "alnair-finance",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beccb"
#     },
#     "source": "coingecko",
#     "name": "Alnair Finance xALNR",
#     "symbol": "xalnr",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.349Z"
#     },
#     "asset.id": "alnair-finance-xalnr",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {},
#     "asset": {
#       "id": "alnair-finance-xalnr",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899becf9"
#     },
#     "source": "coingecko",
#     "name": "Amara Finance",
#     "symbol": "mara",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.349Z"
#     },
#     "asset.id": "amara-finance",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "moonriver": "0x0d2faa2064129ecbfaccd45be33dea3bcd3f8863"
#     },
#     "asset": {
#       "id": "amara-finance",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bed7c"
#     },
#     "source": "coingecko",
#     "name": "Apex Foundation",
#     "symbol": "apex",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.350Z"
#     },
#     "asset.id": "apex-foundation",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "avalanche": "0x2e768e86f691afe8a6f9277bbcd9c570ab868fc0"
#     },
#     "asset": {
#       "id": "apex-foundation",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bed7d"
#     },
#     "source": "coingecko",
#     "name": "ApeXit Finance",
#     "symbol": "apex",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.350Z"
#     },
#     "asset.id": "apexit-finance",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "solana": "51tMb3zBKDiQhNwGqpgwbavaGH54mk8fXFzxTc1xnasg"
#     },
#     "asset": {
#       "id": "apexit-finance",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bed7e"
#     },
#     "source": "coingecko",
#     "name": "Apex Predator",
#     "symbol": "apex",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.350Z"
#     },
#     "asset.id": "apex-predator",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0x579e5eafabae696aad762ad36e77a16ae9f0ef91"
#     },
#     "asset": {
#       "id": "apex-predator",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bed80"
#     },
#     "source": "coingecko",
#     "name": "ApeX",
#     "symbol": "apex",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.350Z"
#     },
#     "asset.id": "apex-token-2",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0x52a8845df664d76c69d2eea607cd793565af42b8"
#     },
#     "asset": {
#       "id": "apex-token-2",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beda8"
#     },
#     "source": "coingecko",
#     "name": "Aquarius",
#     "symbol": "aqua",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.350Z"
#     },
#     "asset.id": "aquarius",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "stellar": "GBNZILSTVQZ4R7IKQDGHYGY2QXL5QOFJYQMXPKWRRM5PAV7Y4M67AQUA"
#     },
#     "asset": {
#       "id": "aquarius",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bedab"
#     },
#     "source": "coingecko",
#     "name": "AquaTank",
#     "symbol": "aqua",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.350Z"
#     },
#     "asset.id": "aquatank",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "binance-smart-chain": "0xf59a047b8a7aa114f03448362d56936693c00635"
#     },
#     "asset": {
#       "id": "aquatank",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bedac"
#     },
#     "source": "coingecko",
#     "name": "Aqua Unicorn",
#     "symbol": "auni",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.350Z"
#     },
#     "asset.id": "aqua-unicorn",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "binance-smart-chain": "0xf9e5994d257102ca973db682adf435a0f78c5b4d"
#     },
#     "asset": {
#       "id": "aqua-unicorn",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bee22"
#     },
#     "source": "coingecko",
#     "name": "Artwork NFT",
#     "symbol": "anft",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.350Z"
#     },
#     "asset.id": "artwork-nft",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "binance-smart-chain": "0x4ad871d02415717f55adb23def23faec98e7bba8"
#     },
#     "asset": {
#       "id": "artwork-nft",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bee64"
#     },
#     "source": "coingecko",
#     "name": "Atheios",
#     "symbol": "ath",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.350Z"
#     },
#     "asset.id": "atheios",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {},
#     "asset": {
#       "id": "atheios",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bee65"
#     },
#     "source": "coingecko",
#     "name": "Athena Crypto Bank",
#     "symbol": "ath",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.350Z"
#     },
#     "asset.id": "athena-crypto-bank",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "binance-smart-chain": "0x5597d204118436b5bca397aded5ac6923a26033d"
#     },
#     "asset": {
#       "id": "athena-crypto-bank",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bee69"
#     },
#     "source": "coingecko",
#     "name": "Athens",
#     "symbol": "ath",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.350Z"
#     },
#     "asset.id": "athens",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "ethereum": "0x2f9411088cef82fd9fb904eb8092f28eb485c8f6"
#     },
#     "asset": {
#       "id": "athens",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899bee6c"
#     },
#     "source": "coingecko",
#     "name": "Athos Finance",
#     "symbol": "ath",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.350Z"
#     },
#     "asset.id": "athos-finance",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "moonbeam": "0xcbabee0658725b5b21e1512244734a5d5c6b51d6"
#     },
#     "asset": {
#       "id": "athos-finance",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beea3"
#     },
#     "source": "coingecko",
#     "name": "aUSDC",
#     "symbol": "ausdc",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.350Z"
#     },
#     "asset.id": "ausdc",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "polygon-pos": "0xe87ba1bd11ee6e0d3c7dd6932e6a038e38627f65"
#     },
#     "asset": {
#       "id": "ausdc",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beead"
#     },
#     "source": "coingecko",
#     "name": "AutoMaticUp",
#     "symbol": "atmup",
#     "lastupdated": {
#       "$date": "2022-12-01T12:12:24.350Z"
#     },
#     "asset.id": "automaticup",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "binance-smart-chain": "0xd8e4f8b3adc0dc6ccd90efe8b1ed706d398f81bc"
#     },
#     "asset": {
#       "id": "automaticup",
#       "isactive": 1.0,
#       "platforms": null,
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899beff0"
#     },
#     "source": "coingecko",
#     "name": "Bela Aqua",
#     "symbol": "aqua",
#     "lastupdated": {
#       "$date": "2022-11-30T19:43:19.854Z"
#     },
#     "asset.id": "bela",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "binance-smart-chain": "0x9fb677928dd244befcd0bbebdf6068dd4bef559c"
#     },
#     "asset": {
#       "id": "bela",
#       "isactive": 1.0,
#       "platforms": {
#         "binance-smart-chain": "0x9fb677928dd244befcd0bbebdf6068dd4bef559c"
#       },
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899c00e0"
#     },
#     "source": "coingecko",
#     "name": "Idle Cyber",
#     "symbol": "afk",
#     "lastupdated": {
#       "$date": "2022-11-30T19:43:19.865Z"
#     },
#     "asset.id": "idle-cyber",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "binance-smart-chain": "0xba0b46f556633bd742546e4f37d66d416753003b"
#     },
#     "asset": {
#       "id": "idle-cyber",
#       "isactive": 1.0,
#       "platforms": {
#         "binance-smart-chain": "0xba0b46f556633bd742546e4f37d66d416753003b"
#       },
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   },
#   {
#     "_id": {
#       "$oid": "638740c7d8ab1a48899c0d76"
#     },
#     "source": "coingecko",
#     "name": "Planet Finance",
#     "symbol": "aqua",
#     "lastupdated": {
#       "$date": "2022-11-30T19:43:19.877Z"
#     },
#     "asset.id": "planet-finance",
#     "asset.isactive": null,
#     "asset.tokenaddress": null,
#     "asset.platforms": {
#       "binance-smart-chain": "0x72b7d61e8fc8cf971960dd9cfa59b8c829d91991"
#     },
#     "asset": {
#       "id": "planet-finance",
#       "isactive": 1.0,
#       "platforms": {
#         "binance-smart-chain": "0x72b7d61e8fc8cf971960dd9cfa59b8c829d91991"
#       },
#       "tokenaddress": null,
#       "type": "altcoin"
#     }
#   }
# ]

# %% [markdown]
# ## Get Crypto List

# %%
_data_owner='coinmarketcap'

_results, _collection = clsMC.update_asset_metadata(data_owner=_data_owner)

print(_collection)
print(len(_results))
# Out:
# coinmarketcap.asset.list
# 5000

# %% [markdown]
# ## Direct DB update datasource

# %%
db.coingecko.asset.list.updateMany(
   {
       "source" :  {"$eq":'coingecko'},
       "asset.id":{"$in":['safemoon-2', 'safutitano', 'samsunspor-fan-token', 'santos-fc-fan-token', 'sao-paulo-fc-fan-token', 'savage', 'savanna', 'save-baby-doge', 'scarecrow', 's-c-corinthians-fan-token', 'seba', 'seeds', 'sekuya', 'shibamax', 'shoot', 'shuey-rhon-inu', 'silva-token', 'smartlink', 'snovio', 'solana-ecosystem-index', 'solape-token', 'solcial', 'solidex', 'solootbox-dao', 'songbird', 'spacecowboy', 'spacerat', 'sphere-finance', 'spiritdao-ghost', 'sporkdao', 'stacktical', 'stader', 'starbots', 'stargaze', 'stobox-token', 'ston', 'straitsx-indonesia-rupiah', 'streamr', 'sugarbounce', 'swapxi-token', 'talecraft', 'team-vitality-fan-token', 'tectonic', 'temple', 'tethys-finance', 'the-crypto-you', 'the-dynasty', 'thetan-coin', 'thorus', 'timeleap-finance', 'tip-blue', 'tokenplace', 'toko', 'toucan-protocol-base-carbon-tonne', 'tradao', 'transhuman-coin', 'transient', 'travel-care-2', 'treasure-sl', 'tzbtc', 'ufc-fan-token', 'unbound-finance', 'unique-utility-token', 'unitedcrowd', 'universidad-de-chile-fan-token', 'uxd-stablecoin', 'value-finance', 'varen', 'vcgamers', 'vedao', 'vee-finance', 'veraone', 'verve', 'vesta-finance', 'vicewrld', 'visor', 'vitall-markets', 'wagmi', 'wagmi-on-solana', 'wam', 'wasder', 'weentar', 'wegro', 'we-love-gm', 'whole-network', 'wicrypt', 'world-of-defish', 'wrapped-usdt', 'xbn-community-token', 'x-consoles', 'xmooney', 'xp-network', 'xtblock-token', 'xy-finance', 'yoshi-exchange', 'zenlink-network-token', 'zignaly', 'ziot', 'zone']},
   },
   [
     { "$set": 
      { "asset.isactive": 0.0 },
     }
   ],
    {
        "upsert":true
    }
)

# %%
db.coingecko.asset.list.updateMany(
   {
       "source" :  {"$eq":'coingecko'},
       "asset.isactive": {"$eq":-1.0},
   },
   [
     { "$set": 
      { "asset.isactive": 1.0 },
     }
   ],
    {
        "upsert":true
    }
)

# %%
db.marketcap.api.update(
   { "category" :  'crypto.metadata'},
   [
     { "$set": 
      { "api.parameters.localization": "" },
     }
   ],
    {
        "upsert":true
    }
)

# %% [markdown]
# ## Insert/Update new datasource

# %%
__data__ = [
## CMC
#     {
#         "owner":'coinmarketcap',
#         "category":'historic.prices',
#         "resource.info":'https://coinmarketcap.com/api/documentation/v1/#tag/cryptocurrency',
#         "api.url":'https://pro-api.coinmarketcap.com/v1/cryptocurrency/quotes/historical',
#         "api.endpoint":'/cryptocurrency/quotes/historical',
#         "api.headers.accepts":'application/json',
#         "api.headers.method":'',
#         "api.headers.key":'',
#         "api.headers.X-CMC_PRO_API_KEY":'2f2845f0-581b-46f7-9a27-51d507826675',
#         "api.parameters.localization" :'false',
#         "api.parameters.date" :'{date}',
#         "api.parameters.cryptocurrency_type" :'all',
#         "api.parameters.start" :'1',
#         "api.parameters.limit":'5000',
#         "api.parameters.convert":'USD',
#         "api.parameters.sort":'symbol',
#     },
#     {
#         "owner":'coinmarketcap',
#         "category":'latest.prices',
#         "resource.info":'https://coinmarketcap.com/api/documentation/v1/#tag/cryptocurrency',
#         "api.url":'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest',
#         "api.endpoint":'/cryptocurrency/*',
#         "api.headers.accepts":'application/json',
#         "api.headers.method":'',
#         "api.headers.key":'',
#         "api.headers.X-CMC_PRO_API_KEY":'2f2845f0-581b-46f7-9a27-51d507826675',
#         "api.parameters.localization" :'false',
#         "api.parameters.start" :'1',
#         "api.parameters.limit":'5000',
#         "api.parameters.convert":'USD',
#         "api.parameters.sort":'symbol',
#     },
#     {
#         "owner":'coinmarketcap',
#         "category":'asset.metadata',
#         "resource.info":'https://coinmarketcap.com/api/documentation/v1/#tag/cryptocurrency',
#         "api.url":'https://pro-api.coinmarketcap.com/v1/cryptocurrency/map',
#         "api.endpoint":'/api/v3/coins/list',
#         "api.headers.accepts":'application/json',
#         "api.headers.method":'',
#         "api.headers.X-CMC_PRO_API_KEY":'2f2845f0-581b-46f7-9a27-51d507826675',
#         "api.parameters.localization" :'',
#         "api.parameters.listing_status" :'active',
#         "api.parameters.start" :'1',
#         "api.parameters.limit":'5000',
#         "api.parameters.sort":'cmc_rank',
#     },
## COINGEKO
#     {
#         "owner":'coingecko',
#         "category":'historic.prices',
#         "resource.info":'https://www.coingecko.com/en/api/documentation',
#         "api.url":'https://api.coingecko.com/api/v3/coins/{id}/market_chart/range',
#         "api.endpoint":'/coins/{id}/history',
#         "api.headers.accepts":'application/json',
#         "api.headers.method":'',
#         "api.headers.key":'',
#         "api.parameters.localization" :'false',
#         "api.parameters.id" :'',
#         "api.parameters.days":'',
#         "api.parameters.vs_currency":'usd',
#         "api.parameters.interval" :'',
#     },
#     {
#         "owner":'coingecko',
#         "category":'latest.prices',
#         "resource.info":'https://www.coingecko.com/en/api/documentation',
#         "api.url":'https://api.coingecko.com/api/v3/coins/markets',
#         "api.endpoint":'/coins/markets',
#         "api.headers.accepts":'application/json',
#         "api.headers.method":'',
#         "api.headers.key":'',
#         "api.parameters.localization" :'false',
#         "api.parameters.per_page" :'250',
#         "api.parameters.page" :'1',
#         "api.parameters.price_change_percentage" :'1h,24h,7d,14d,30d',
#         "api.parameters.order":'market_cap_desc',
#         "api.parameters.vs_currency":'USD',
#         "api.parameters.sparkline" :'false',
#         "api.parameters.sort":'symbol',
#     },
#     {
#         "owner":'coingecko',
#         "category":'asset.metadata',
#         "resource.info":'https://www.coingecko.com/en/api/documentation',
#         "api.url":'https://api.coingecko.com/api/v3/coins/list',
#         "api.endpoint":'/coins/list',
#         "api.headers.accepts":'application/json',
#         "api.headers.method":'',
#         "api.headers.key":'',
#         "api.parameters.include_platform" :'true',
#     },
]
_uids = ['owner','category']
_database = "tip-data-sources"
_collection = "marketcap.api"

# __keys__ = []
clsNoSQL.connect={'DBAUTHSOURCE':_database}
_collection = clsNoSQL.write_documents(
    db_name=_database,
    db_coll=_collection,
    data=__data__,
    uuid_list=_uids
)
# print([x for x in _collection])
# Out:
# Total 1 documents, duccessful insert count = 0 & modify count = 1

# %%
import re
logpath = os.path.join("/home/nuwan/workspace/rezaware/",
                     "wrangler/logs/assets/etl/app.log")
with open(logpath,'r') as f:
    symbol_list=[]
    for line in f:
        if line.startswith("[WARNING]"):
            m = re.search("etl - (.+?) marketcap", line)
            if m:
                found = m.group(1)
                symbol_list.append(found.replace("'",""))
print(symbol_list)
# Out:
# ['blocksport', 'bobatama', 'bologna-fc-fan-token', 'bomb-money', 'bone-shibaswap', 'boneswap', 'bone-token', 'bontecoin', 'boost', 'brazil-fan-token', 'brick', 'brig-finance', 'bright-token', 'btmiracles', 'btrips', 'bulldog-billionaires', 'burningmoon', 'buying', 'c2x-2', 'caashcow', 'caietf-finance', 'capital-dao-starter-token', 'carbon-credit', 'care-coin', 'cash-tech', 'castweet', 'catbonk', 'ccomp', 'centurion', 'centurion-inu', 'chainlink-wormhole', 'chainpay', 'channels', 'checkdot', 'cherryswap', 'chickenlegs', 'cirus', 'cleardao', 'clover', 'cockapoo', 'cocktailbar', 'codi-finance', 'cogiverse', 'coinary-token', 'coin-fast-alert', 'coinmerge', 'coinweb', 'coinwind', 'collector-coin', 'comfy', 'community-coin-2', 'community-vote-power', 'compound-chainlink-token', 'concertvr', 'constitutiondao-wormhole', 'coreum', 'corgidoge', 'corgi-inu', 'corginftgame', 'corn', 'cosplay-token-2', 'cougar-token', 'covicoin', 'cowry', 'cpucoin', 'cre8r-dao', 'credefi', 'creditcoin-2', 'cronosphere', 'cropbytes', 'cro-predict', 'crown-token', 'crunchy-dao', 'cry-coin', 'cryptobosscoin', 'cryptoclans', 'crypto-classic', 'crypto-development-services', 'crypto-gladiator-shards', 'crypto-inu', 'cryptoperformance-coin', 'cryptoplants', 'crypto-royale', 'cryptowar-xblade', 'cryptyk', 'cult-dao', 'cure-token-v2', 'curio-governance', 'cybertronchain', 'cybervein', 'dairy-money-milk', 'dao-farmer-dfg', 'darkbuild-v2', 'darkcrypto', 'darkcrypto-share', 'dark-energy-crystals', 'dark-frontiers', 'darkmatter', 'dark-matter-defi', 'darkness-share', 'darleygo-essence', 'data-enterprise-chain', 'davis-cup-fan-token', 'deblox', 'decentraland-wormhole', 'decentralized-autonomous-organization', 'decentralized-nations', 'defiato', 'defibox', 'defil', 'defily', 'degate', 'degen-finance', 'dei-token', 'delta-financial', 'deracoin', 'deus-finance-2', 'devour', 'dexira', 'dhabicoin', 'diamond-coin', 'diamond-dnd', 'digital-standard-unit', 'digital-ticks', 'digits-dao', 'dinamo-zagreb-fan-token', 'dingo-token', 'dino', 'dmd', 'dmt-token', 'dogecola', 'dogedi', 'dogelon-mars-wormhole', 'dogemon-go', 'dogeon', 'dogewhale', 'donkey-token', 'donnie-finance', 'dopple-finance', 'dotarcade', 'doubloon', 'dragonsea', 'drc-mobility', 'duckduck-token', 'duckrocket', 'duck-vault-nftx', 'dydx-wormhole', 'dyor', 'ecoin-finance', 'ekta-2', 'elvantis', 'enjinstarter', 'enterdao', 'etherean-socks', 'ethersocks', 'ethtez', 'eve-exchange', 'everdome', 'evrice', 'exponential-capital', 'fabwelt', 'fbomb', 'feg-token-bsc', 'fief', 'filecoin-standard-full-hashrate', 'flamengo-fan-token', 'flamingo-finance', 'floordao', 'florida-man', 'fndz-token', 'forcecowboy', 'forexcoin', 'fortuna-sittard-fan-token', 'fractionalized-wave-999', 'french-digital-reserve', 'friesdao', 'fringe-finance', 'froyo-games', 'frozentomb-lot', 'ftmlaunch', 'ftribe-fighters', 'ftx-wormhole', 'fungie-dao', 'futurecoin', 'fxt-token', 'gains-network', 'galaxy-fight-club', 'game', 'gamecredits', 'gamedao', 'gamefi-token', 'gamer', 'gamerse', 'gamex', 'gami', 'gamifi', 'gami-world', 'gamma', 'gamma-strategies', 'garlic', 'garlicoin', 'gaur-money', 'gear', 'gemlink', 'gencoin-capital', 'gene', 'genesis-mana', 'genesysgo-shadow', 'genopets', 'geocoin', 'geyser', 'ghostmarket', 'gimmer', 'global-aex-token', 'globalcoin', 'global-social-chain', 'global-trust-coin', 'gmcoin', 'goal-token', 'golden-roots', 'goldfinch', 'goldminer', 'good-fire', 'goztepe-s-k-fan-token', 'grain-token', 'grape-2', 'grape-finance', 'grape-token', 'graphene', 'graviton-zero', 'greenair', 'green-chart', 'green-flow', 'green-planet', 'gro-vault-token', 'gunstar-metaverse-currency', 'hakuswap', 'heco-peg-bnb', 'herbalist-token', 'heroeschained', 'hero-inu', 'hierocoin', 'hnk-orijent-1919-token', 'honor-token', 'hubble', 'hummingbot', 'hush', 'hymnode', 'icecream-finance', 'ideas', 'imperium-empires', 'infinitygaming', 'innovaminex', 'integritee', 'inter-milan-fan-token', 'intervalue', 'investdex', 'invox-finance', 'iron-bank', 'iron-finance', 'i ...

# %%
import json

logpath = os.path.join("/home/nuwan/workspace/rezaware/",
                     "wrangler/notebooks/assets/etl/crypto/nft_list.json")
nft_dict=[]
with open(logpath,'r') as f:
    nft_list = json.load(f)
nft_symb_list = [x['symbol'] for x in nft_list]
print(nft_symb_list)
# Out:
# ['KONGZ', 'MZ', 'SYL', 'GAIA', 'SYL', 'BOMUL', 'MIYA', 'SYL', 'SW', 'GAIA', 'BELLYGOM', 'SNKRZ', 'etnah', 'MTDZ', 'DOD', 'Puuvilla', 'GAIA', 'SWC', 'kongz', 'MATE', 'K3K', 'COGO', 'UKKIKKI', 'ArcheWorld_Land', 'SMILEMIYA', 'KDGE', 'VGN', 'TREASURES', 'ArcheWorld_FandomCard', 'SE7EN', 'HT', 'MTM', 'DHB', 'RBL', 'CELPI', 'GAIA', 'GRA', 'chikn', 'BIRDIE CC', 'NRS', 'KROCK', 'LCV1', 'MTG', 'APB', 'BUMZ', 'AOZHEROES', 'KLND', 'TXP', 'FOOTAGE', 'LPV1', 'KLTW', 'UKIDS', 'CT', 'PXL', 'LEMONG 3D', 'BIRDIE', 'bayc', 'SGS', 'PUNK', 'TPC', 'larva', 'KING-KINGS', 'SNKRZ OPEN BOX', '7', 'Puuvillafriends', 'NAC', 'Born Kongz', 'WTBL', 'BK', 'DMONG', 'MEE', 'LIITA', 'DUK', 'KENOME', 'KRBC', 'ROAZ', 'EMATES', 'MAC', 'KLAPES', 'MTDZPET', 'CYECV0', 'EV', 'PG', 'psd', 'CATTP', 'Roostr', 'DHBSRP', 'TMH', 'HDEC75', 'GTU', 'SLIME', 'MAYC', 'MT', 'CMPZPFP', 'RDK', 'ALAP', 'STORKS', 'KONGZ', 'BUMZ', 'MA']

# %%
clsNoSQL.dbType = 'mongodb'
clsNoSQL.dbName = 'tip-historic-marketcap'
clsNoSQL.collections = {"HASINNAME":'btc'}
print(clsNoSQL.collections)
# Out:
# ['coingecko.2022-01-01.wbtc', 'coingecko.2022-07-01.obt', 'coingecko.2022-07-01.btcmt', 'coingecko.2022-04-01.nsbt', 'coingecko.2022-01-01.nsbt', 'coingecko.2022-07-01.btc2', 'coingecko.2022-01-01.bto', 'coingecko.2022-07-01.ibbtc', 'coingecko.2022-01-01.btcred', 'coingecko.2022-01-01.btse', 'coingecko.2022-01-01.btcz', 'coingecko.2022-07-01.btrfly', 'coingecko.2022-01-01.btc', 'coingecko.2022-04-01.btg', 'coingecko.2022-04-01.renbtc', 'coingecko.2022-01-01.btu', 'coingecko.2022-04-01.btx', 'coingecko.2022-04-01.btl', 'coingecko.2022-07-01.wbtc', 'coingecko.2022-04-01.obtc', 'coingecko.2022-07-01.btnt', 'coingecko.2022-07-01.xbtx', 'coingecko.2022-01-01.btcp', 'coingecko.2022-04-01.wbtc', 'coingecko.2022-01-01.hbtc', 'coingecko.2022-07-01.btc', 'coingecko.2022-04-01.xbtx', 'coingecko.2022-01-01.hbt', 'coingecko.2022-04-01.0xbtc', 'coingecko.2022-07-01.btc2x-fli', 'coingecko.2022-01-01.obt', 'coingecko.2022-01-01.yfbt', 'coingecko.2022-07-01.btb', 'coingecko.2022-07-01.btcst', 'coingecko.2022-04-01.btr', 'coingecko.2022-01-01.btg', 'coingecko.2022-07-01.nsbt', 'coingecko.2022-01-01.obtc', 'coingecko.2022-04-01.btcst', 'coingecko.2022-07-01.obtc', 'coingecko.2022-07-01.hbt', 'coingecko.2022-07-01.bta', 'coingecko.2022-04-01.ibbtc', 'coingecko.2022-01-01.btx', 'coingecko.2022-01-01.bts', 'coingecko.2022-07-01.btcz', 'coingecko.2022-04-01.bta', 'coingecko.2022-07-01.btr', 'coingecko.2022-01-01.albt', 'coingecko.2022-04-01.bto', 'coingecko.2022-01-01.btcs', 'coingecko.2022-01-01.bta', 'coingecko.2022-07-01.btc2x-fli-p', 'coingecko.2022-07-01.tbtc', 'coingecko.2022-04-01.btc', 'coingecko.2022-04-01.btu', 'coingecko.2022-04-01.btt', 'coingecko.2022-07-01.iwbtc', 'coingecko.2022-01-01.abt', 'coingecko.2022-01-01.btcone', 'coingecko.2022-04-01.btm', 'coingecko.2022-04-01.btcone', 'coingecko.2022-07-01.btcs', 'coingecko.2022-07-01.yfbt', 'coingecko.2022-07-01.btg', 'coingecko.2022-07-01.sbtc', 'coingecko.2022-04-01.nbt', 'coingecko.2022-01-01.ubt', 'coingecko.2022-07-01.btu', 'coingecko.2022-01-01.pbtc35a', 'coingecko.2022-04-01.btcred', 'coingecko.2022-07-01.btm', 'coingecko.2022-07-01.btsg', 'coingecko.2022-07-01.btcred', 'coingecko.2022-04-01.albt', 'coingecko.2022-01-01.btb', 'coingecko.2022-01-01.0xbtc', 'coingecko.2022-07-01.rbt', 'coingecko.2022-04-01.btb', 'coingecko.2022-07-01.btl', 'coingecko.2022-07-01.btcp', 'coingecko.2022-07-01.albt', 'coingecko.2022-04-01.btsg', 'coingecko.2022-07-01.bto', 'coingecko.2022-01-01.btm', 'coingecko.2022-07-01.renbtc', 'coingecko.2022-07-01.abt', 'coingecko.2022-07-01.pbtc35a', 'coingecko.2022-01-01.btc++', 'coingecko.2022-07-01.nbt', 'coingecko.2022-01-01.cwbtc', 'coingecko.2022-04-01.cwbtc', 'coingecko.2022-07-01.bts', 'coingecko.2022-07-01.0xbtc', 'coingecko.2022-04-01.btcp', 'coingecko.2022-04-01.btcmt', 'coingecko.2022-04-01.btcs', 'coingecko.2022-04-01.pbtc35a', 'coingecko.2022-04-01.obt', 'coingecko.2022-07-01.btc++', 'coingecko.2022-07-01.bkbt', 'coingecko.2022-01-01.renbtc', 'coingecko.2022-07-01.btse', 'coingecko.2022-07-01.btt', 'coingecko.2022-07-01.ibtc-fli-p', 'coingecko.2022-01-01.btc2', 'coingecko.2022-04-01.hbt', 'coingecko.2022-01-01.btcst', 'coingecko.2022-04-01.btc2', 'coingecko.2022-04-01.btc++', 'coingecko.2022-04-01.bkbt', 'coingecko.2022-07-01.ubt', 'coingecko.2022-07-01.btw', 'coingecko.2022-07-01.pbtc', 'coingecko.2022-04-01.btse', 'coingecko.2022-04-01.abt', 'coingecko.2022-07-01.hbtc', 'coingecko.2022-01-01.ibbtc', 'coingecko.2022-01-01.btl', 'coingecko.2022-07-01.btcone', 'coingecko.2022-07-01.cwbtc', 'coingecko.2022-04-01.bts', 'coingecko.2022-01-01.btc2x-fli', 'coingecko.2022-04-01.btc2x-fli', 'coingecko.2022-04-01.btw', 'coingecko.2022-01-01.xbtx', 'coingecko.2022-04-01.ubt', 'coingecko.2022-01-01.bkbt', 'coingecko.2022-04-01.btcz', 'coingecko.2022-04-01.yfbt', 'coingecko.2022-01-01.btw', 'coingecko.2022-07-01.qbt', 'coingecko.2022-04-01.btnt', 'coingecko.2022-07-01.btx', 'coingecko.2022-04-01.hbtc', 'coingecko.2022-01-01.btcmt']

# %% [markdown]
# # Spark Files Read/Write ClassTester
#
# Test the DataIO controller that serves as wrapper to read and write data from and to a particular file system.

# %%
'''
    WARNING CONTROL to display or ignore all warnings
'''
import warnings; warnings.simplefilter('ignore')     #switch betweeb 'default' and 'ignore'
import traceback

''' Set debug flag to view extended error messages; else set it to False to turn off debugging mode '''
debug = True

# %%
import os
import sys

sys.path.insert(1,"/home/nuwan/workspace/rezaware/")
import rezaware as reza
from utils.modules.etl.load import sparkFILEwls as spark
from utils.modules.etl.load.sparkFILEwls import credentials as cred
# from wrangler.modules.ota.scraper import scraperUtils as otaus

''' restart initiate classes '''
if debug:
    import importlib
    reza = importlib.reload(reza)
    spark = importlib.reload(spark)

__desc__ = "read and write files from and to a particular source"
clsSpark = spark.FileWorkLoads(desc=__desc__)
if clsSpark._session:
    clsSpark._session.stop
print("\n%s class initialization and load complete!" % __desc__)
# Out:
# All functional APP-libraries in REZAWARE-package of REZAWARE-module imported successfully!
# All functional FILEWORKLOADS-libraries in LOAD-package of ETL-module imported successfully!
# FileWorkLoads Class initialization complete
#
# read and write files from and to a particular source class initialization and load complete!

# %%
clsSpark.storeMode = "local-fs"
# clsSpark.storeMode = "aws-s3-bucket"
# clsSpark.storeMode = "google-storage"
print("mode =",clsSpark.storeMode)

''' set the driver '''
if clsSpark.storeMode.lower() == "local-fs":
    clsSpark.jarDir = "/opt/spark/jars/postgresql-42.5.0.jar"
elif clsSpark.storeMode.lower() == "aws-s3-bucket":
    clsSpark.jarDir = "/opt/spark/jars/aws-java-sdk-s3-1.12.376.jar"
elif clsSpark.storeMode.lower() == "google-storage":
    clsSpark.jarDir = "/opt/spark/jars/gcs-connector-hadoop3-2.2.10.jar"
else:
    pass
print("jar =",clsSpark.jarDir)
# Out:
# mode = local-fs
# jar = /opt/spark/jars/postgresql-42.5.0.jar

# %%
clsSpark.storeRoot = "/home/nuwan/workspace/rezaware"
# clsSpark.storeRoot = "rezaware-wrangler-source-code"
# clsSpark.storeRoot = "tip-daily-marketcap"   #"rezaware-wrangler-source-code"
print("data_root =",clsSpark.storeRoot)
# Out:
# data_root = /home/nuwan/workspace/rezaware

# %% [markdown]
# ## Read from storage and return as dtype

# %%
__as_type__ = "dict"  # specify data type to return from read file
# folder or key path
__local_folder_path__ = "wrangler/data/ota/scraper/hospitality/bookings/"
# __aws_folder_path__ = "wrangler/data/hospitality/bookings/scraper/"
# __gcs_folder_path__ = "coingeko"
__local_file_name__ = "room_descriptions.csv"  #file name to read from or write data to
# __file_name__ = "scraper-build-scrape-url-list.csv" #"room_descriptions.csv"
# __gcs_file_name__ = "2022-11-21.json"  #file name to read from or write data to
__file_type__ = "csv"   # specify file type to write data to or read from
''' options key value pairs must match the pyspark standard'''
options = {
    "inferSchema":True,
    "header":True,
    "delimiter":",",
}

_data = clsSpark.read_files_to_dtype(
    as_type=__as_type__,
    folder_path=__local_folder_path__,
    file_name=__local_file_name__,
    file_type=__file_type__,
    **options,
)
if __as_type__ == 'pandas':
    print("got back {0} rows with return dtype {1}"
          .format(_data.shape[0],__as_type__))
    print(_data.head(5))
elif __as_type__ == 'spark':
    print("got back {0} rows with return dtype {1}"
          .format(_data.count(),__as_type__))
    print(_data.show(5,truncate=False))
elif __as_type__ == 'dict':
    print("got back {0} rows with return dtype {1}"
          .format(len(_data),__as_type__))
    print(_data)
else:
    print('Unrecognised __as_type__' % __as_type__)
# Out:
# got back 66 rows with return dtype dict
# {0: ['dormitory', None, '*', 'mixed dormitory', None], 1: ['dormitory', None, '*', 'female dormitory', None], 2: ['dormitory', None, '*', 'male dormitory', None], 3: ['double', None, '2', 'double room', None], 4: ['double', 'double', '4', 'double room double beds', None], 5: ['double', 'queen', '2', 'double room queen bed', None], 6: ['double', 'king', '2', 'double room king bed', None], 7: ['deluxe', None, '1', 'deluxe room', None], 8: ['deluxe', 'double', '2', 'deluxe room double bed', None], 9: ['deluxe', 'king', '1', 'deluxe room king bed', None], 10: ['deluxe', 'queen', '1', 'deluxe room queen bed', None], 11: ['deluxe', None, '2', 'deluxe double room', None], 12: ['deluxe', 'double', '4', 'deluxe double room double beds', None], 13: ['deluxe', 'queen', '2', 'deluxe double room queen beds', None], 14: ['deluxe', 'king', '2', 'deluxe double room king beds', None], 15: ['guest', 'double', '2', 'guest room double bed', None], 16: ['guest', 'king', '1', 'guest room king bed', None], 17: ['guest', 'queen', '1', 'guest room queen bed', None], 18: ['luxury', None, '1', 'luxury room', None], 19: ['luxury', 'double', '2', 'luxury room double bed', None], 20: ['luxury', 'king', '1', 'luxury room king bed', None], 21: ['luxury', 'queen', '1', 'luxury room queen bed', None], 22: ['shared', None, '*', 'single shared room', None], 23: ['standard', None, '1', 'standard room', None], 24: ['standard', 'king', '1', 'standard room king bed', None], 25: ['standard', 'king', '2', 'standard room two king beds', None], 26: ['standard', 'double', '2', 'standard room double bed', None], 27: ['standard', 'queen', '1', 'standard room queen beds', None], 28: ['standard', 'queen', '2', 'standard room two queen beds', None], 29: ['standard', 'double', '2', 'standard double room', None], 30: ['standard', 'double', '4', 'standard double room two double beds', None], 31: ['standard', 'queen', '3', 'standard double room two queen beds', None], 32: ['standard', 'king', '3', 'standard double room two king beds', None], 33: ['studio', None, '1', 'studio apartment', None], 34: ['studio', 'double', '2', 'studio apartment double bed', None], 35: ['studio', 'queen', '1', 'studio apartment queen bed', None], 36: ['studio', 'king', '1', 'studio apartment king bed', None], 37: ['studio', None, '2', 'studio apartment two beds', None], 38: ['studio', 'double', '4', 'studio apartment two double bed', None], 39: ['studio', 'queen', '2', 'studio apartment two queen bed', None], 40: ['studio', 'king', '2', 'studio apartment two king bed', None], 41: ['suite', None, '1', 'suite', None], 42: ['suite', 'king', '1', 'suite king bed', None], 43: ['suite', 'queen', '1', 'suite queen bed', None], 44: ['suite', 'double', '2', 'suite double beds', None], 45: ['suite', 'king', '2', 'suite two king beds', None], 46: ['suite', 'queen', '2', 'suite two queen beds', None], 47: ['suite', None, '1', 'suite guest room', None], 48: ['one bedroom suite', None, '1', 'suite one bedroom', None], 49: ['one bedroom suite', 'double', '2', 'suite one bedroom double beds', None], 50: ['one bedroom suite', 'queen', '1', 'suite one bedroom queen beds', None], 51: ['one bedroom suite', 'king', '1', 'suite one bedroom king beds', None], 52: ['two bedroom suite', None, '2', 'suite two bedrooms', None], 53: ['two bedroom suite', 'double', '4', 'suite two bedroom double beds', None], 54: ['two bedroom suite', 'queen', '2', 'suite two bedroom queen beds', None], 55: ['two bedroom suite', 'king', '2', 'suite two bedroom king beds', None], 56: ['superior', None, '1', 'superior room', None], 57: ['superior', 'double', '2', 'superior room double bed', None], 58: ['superior', 'king', '1', 'superior room king bed', None], 59: ['superior', 'queen', '1', 'superior room queen bed', None], 60: ['two bedroom superio', None, '2', 'superior double room', None], 61: ['two bedroom superio', 'double', '4', 'superior double room double beds', None], 62: ['two bedroom superio', 'queen', '2', 'superior double room queen bed ...

# %% [markdown]
# ## File data in storage location

# %%
type(_data)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
import pandas as pd
__file_name__="dummy.csv"
# __folder_path__ = "wrangler/data/hospitality/bookings/scraper/tmp"
__folder_path__="wrangler/data/ota/scraper/hospitality/bookings/tmp"
__file_path__ = os.path.join("/home/nuwan/workspace/rezaware",
                             "wrangler/data/ota/scraper/hospitality/bookings/tmp",
                             "scraper-build-scrape-url-list.csv")
__data__= pd.read_csv(__file_path__)
write_data=clsRW.export_data(__file_name__,__folder_path__,__data__)

write_data
# Out:
#             ota  destination_id     checkin  page_offset  \
# 0   booking.com        20079110  2022-10-24            0
# 1   booking.com        20079110  2022-10-24           10
# 2   booking.com        20088325  2022-10-24            0
# 3   booking.com        20088325  2022-10-24           10
# 4   booking.com        20061717  2022-10-24            0
# 5   booking.com        20061717  2022-10-24           10
# 6   booking.com        20023488  2022-10-24            0
# 7   booking.com        20023488  2022-10-24           10
# 8   booking.com        20050264  2022-10-24            0
# 9   booking.com        20050264  2022-10-24           10
# 10  booking.com        20030916  2022-10-24            0
# 11  booking.com        20030916  2022-10-24           10
# 12  booking.com        20033173  2022-10-24            0
# 13  booking.com        20033173  2022-10-24           10
# 14  booking.com        20135442  2022-10-24            0
# 15  booking.com        20135442  2022-10-24           10
# 16  booking.com        20131185  2022-10-24            0
# 17  booking.com        20131185  2022-10-24           10
# 18  booking.com        20090971  2022-10-24            0
# 19  booking.com        20090971  2022-10-24           10
# 20  booking.com        20023181  2022-10-24            0
# 21  booking.com        20023181  2022-10-24           10
# 22  booking.com        20014181  2022-10-24            0
# 23  booking.com        20014181  2022-10-24           10
# 24  booking.com        20015732  2022-10-24            0
# 25  booking.com        20015732  2022-10-24           10
# 26  booking.com        20021296  2022-10-24            0
# 27  booking.com        20021296  2022-10-24           10
#
#                                                   url
# 0   https://www.booking.com/searchresults.en-gb.ht...
# 1   https://www.booking.com/searchresults.en-gb.ht...
# 2   https://www.booking.com/searchresults.en-gb.ht...
# 3   https://www.booking.com/searchresults.en-gb.ht...
# 4   https://www.booking.com/searchresults.en-gb.ht...
# 5   https://www.booking.com/searchresults.en-gb.ht...
# 6   https://www.booking.com/searchresults.en-gb.ht...
# 7   https://www.booking.com/searchresults.en-gb.ht...
# 8   https://www.booking.com/searchresults.en-gb.ht...
# 9   https://www.booking.com/searchresults.en-gb.ht...
# 10  https://www.booking.com/searchresults.en-gb.ht...
# 11  https://www.booking.com/searchresults.en-gb.ht...
# 12  https://www.booking.com/searchresults.en-gb.ht...
# 13  https://www.booking.com/searchresults.en-gb.ht...
# 14  https://www.booking.com/searchresults.en-gb.ht...
# 15  https://www.booking.com/searchresults.en-gb.ht...
# 16  https://www.booking.com/searchresults.en-gb.ht...
# 17  https://www.booking.com/searchresults.en-gb.ht...
# 18  https://www.booking.com/searchresults.en-gb.ht...
# 19  https://www.booking.com/searchresults.en-gb.ht...
# 20  https://www.booking.com/searchresults.en-gb.ht...
# 21  https://www.booking.com/searchresults.en-gb.ht...
# 22  https://www.booking.com/searchresults.en-gb.ht...
# 23  https://www.booking.com/searchresults.en-gb.ht...
# 24  https://www.booking.com/searchresults.en-gb.ht...
# 25  https://www.booking.com/searchresults.en-gb.ht...
# 26  https://www.booking.com/searchresults.en-gb.ht...
# 27  https://www.booking.com/searchresults.en-gb.ht...

# %%
from google.cloud import storage


def write_read(bucket_name, blob_name):
    """Write and read a blob from GCS using file-like IO"""
    # The ID of your GCS bucket
    # bucket_name = "your-bucket-name"

    # The ID of your new GCS object
    # blob_name = "storage-object-name"

    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(blob_name)

    # Mode can be specified as wb/rb for bytes mode.
    # See: https://docs.python.org/3/library/io.html
#     with blob.open("w") as f:
#         f.write("Hello world")

    with blob.open("r") as f:
        print(f.read())

# %%
write_read(clsRW.storeRoot,'dummy.csv')
# Out:
# Hello world

# %%
from google.cloud import storage


def list_blobs(bucket_name):
    """Lists all the blobs in the bucket."""
    # bucket_name = "your-bucket-name"

    storage_client = storage.Client()

    # Note: Client.list_blobs requires at least package version 1.17.0.
    blobs = storage_client.list_blobs(bucket_name)

    # Note: The call returns a response only when the iterator is consumed.
    for blob in blobs:
        print(blob.name)

# %%
list_blobs(clsRW.storeRoot)
